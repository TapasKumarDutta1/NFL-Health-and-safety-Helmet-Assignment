# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/IEEE-CIS-Fraud/blob/master/simple_model_focal_loss_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_USERNAME'] = "tapaskd123" # username from the json file
os.environ['KAGGLE_KEY'] = "aba8dc1f085221111d925003fe5a88ed" # key from the json file
# !kaggle competitions download -c ieee-fraud-detection
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading test_transaction.csv.zip to /content
#  96% 50.0M/52.2M [00:01<00:00, 27.9MB/s]
# 100% 52.2M/52.2M [00:01<00:00, 37.3MB/s]
# Downloading test_identity.csv.zip to /content
#   0% 0.00/3.21M [00:00<?, ?B/s]
# 100% 3.21M/3.21M [00:00<00:00, 107MB/s]
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/1.14M [00:00<?, ?B/s]
# 100% 1.14M/1.14M [00:00<00:00, 160MB/s]
# Downloading train_transaction.csv.zip to /content
#  98% 57.0M/58.3M [00:00<00:00, 79.9MB/s]
# 100% 58.3M/58.3M [00:00<00:00, 91.9MB/s]
# Downloading train_identity.csv.zip to /content
#   0% 0.00/3.26M [00:00<?, ?B/s]
# 100% 3.26M/3.26M [00:00<00:00, 224MB/s]

# %%
n_fold=5
lr=0.001

# %%
import pandas as pd
trn=pd.read_csv('/content/gdrive/My Drive/fraud/train.csv')
tst=pd.read_csv('/content/gdrive/My Drive/fraud/test.csv')
ls=list(trn.filter(regex='V'))
trn=trn.drop(ls,1)
tst=tst.drop(ls,1)

# %%
from tensorflow.keras.layers import *
import tensorflow as tf
import random, os, sys
import numpy as np
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
import tensorflow as tf

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np


class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
from sklearn.preprocessing import LabelEncoder
cols=list(trn.select_dtypes(include=object))
for col in cols:
  le=LabelEncoderExt()
  le.fit(trn[col].astype(str))
  trn[col]=le.transform(trn[col].astype(str))
  tst[col] = tst[col].map(lambda s: '<unknown>' if s not in le.classes_ else s)
  tst[col]=le.transform(tst[col].astype(str))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   import sys

# %%
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from keras.layers import *
from keras.optimizers import *
from keras.models import *
from keras import backend as K
ss=StandardScaler()
frd=trn['isFraud']
ls=list(trn)
trn=ss.fit_transform(trn.drop(['isFraud'],1))
trn=pd.DataFrame(trn)

# %%
ls.remove('isFraud')
trn.columns=ls
trn['isFraud']=frd

ls=list(tst)
tst=ss.fit_transform(tst)
tst=pd.DataFrame(tst)
tst.columns=ls

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df
trn=reduce_mem_usage(trn)
tst=reduce_mem_usage(tst)
# Out:
# Memory usage of dataframe is 860.54 MB
# Memory usage after optimization is: 215.14 MB
# Decreased by 75.0%
# Memory usage of dataframe is 734.49 MB
# Memory usage after optimization is: 183.62 MB
# Decreased by 75.0%

# %%
trn_n=pd.read_csv('train_transaction.csv.zip')
tst_n=pd.read_csv('test_transaction.csv.zip')
trn['month']=trn_n['TransactionDT']//(86400*30)
trn_n.head()
trn_ls=list(trn_n)
tst_ls=list(tst_n)
for col in trn:
  if col in trn_ls:
    trn[col+'_isna']=trn_n[col].isna().astype('uint8')
for col in tst:
  if col in tst_ls:
    tst[col+'_isna']=tst_n[col].isna().astype('uint8')
import gc
del([trn_n,tst_n])
gc.collect()
# Out:
# 0

# %%
trn=trn.drop(['isFraud_isna'],1)

# %%
from sklearn.metrics import roc_auc_score
from keras.callbacks import Callback
class RocCallback(Callback):
    def __init__(self,validation_data):
        self.x_val = validation_data[0]
        self.y_val = validation_data[1]
        self.ep=0

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        self.ep+=1
        if self.ep%10==0:
          y_pred_val = self.model.predict(self.x_val)
          roc_val = roc_auc_score(self.y_val, y_pred_val)
          print('roc-auc_val: %s' % str(round(roc_val,4)))

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %%
1-0.036
# Out:
# 0.964

# %%
def fl():
    def focal_loss(y_true, y_pred):
        gamma=0.8
        alpha=1-0.036
        pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))

        pt_1 = K.clip(pt_1, 1e-3, .999)
        pt_0 = K.clip(pt_0, 1e-3, .999)

        return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0))
    return focal_loss
dk={}
def load_model():
  K.clear_session()
  inp=Input((233,))
  x=Dense(256,activation='relu')(inp)
  x=Dropout(0.3)(x)
  x=BatchNormalization()(x)
  x=Dense(256,activation='relu')(x)
  x=Dropout(0.3)(x)
  x=BatchNormalization()(x)
  x=Dense(256,activation='relu')(x)
  x=Dropout(0.3)(x)
  x=BatchNormalization()(x)
  x=Dense(1,activation='sigmoid')(x)
  mod=Model(inputs=inp,outputs=x)
  return mod
for en,month in enumerate([(4,5),(3,4),(3,5)]):
  train=trn.loc[trn['month']>=month[1]]
  test=trn.loc[trn['month']<=month[0]]
  train=train.drop(['month'],1)
  test=test.drop(['month'],1)
  mod=load_model()
  mod.compile(optimizer=Adam(0.0001,decay=1e-3),loss=fl())
  roc = RocCallback(
                  validation_data=(test.drop(['isFraud'],1), test['isFraud']))
  es=EarlyStopping(monitor='val_loss',min_delta=0.0001,mode='min',restore_best_weights=True,patience=50)
  mod.fit(train.drop(['isFraud'],1),train['isFraud'],validation_data=(test.drop(['isFraud'],1),test['isFraud']),batch_size=2048,epochs=1000,callbacks=[es,roc])
  del([train,test])
  gc.collect()
  df=trn.loc[trn['month']==6].reset_index(drop=True).drop(['month'],1)
  pre=mod.predict(df.drop(['isFraud'],1))
  scr=roc_auc_score(df['isFraud'],pre)
  dk[str(scr)]=mod.predict(tst)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 77.5256 - val_loss: 52.0955
# Epoch 2/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 66.4134 - val_loss: 51.7758
# Epoch 3/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 61.8835 - val_loss: 51.3635
# Epoch 4/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 58.7764 - val_loss: 51.0683
# Epoch 5/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 57.3912 - val_loss: 51.0700
# Epoch 6/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 55.4008 - val_loss: 50.7462
# Epoch 7/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 54.0687 - val_loss: 50.3162
# Epoch 8/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 53.8638 - val_loss: 50.1195
# Epoch 9/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 52.0295 - val_loss: 49.5762
# Epoch 10/1000
# 39/47 [=======================>......] - ETA: 0s - loss: 50.9107roc-auc_val: 0.7741
# 47/47 [==============================] - 13s 282ms/step - loss: 50.5750 - val_loss: 49.3562
# Epoch 11/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 51.2143 - val_loss: 49.2769
# Epoch 12/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 48.9607 - val_loss: 49.0096
# Epoch 13/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 49.5839 - val_loss: 48.9287
# Epoch 14/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 48.3230 - val_loss: 48.8619
# Epoch 15/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 47.6015 - val_loss: 48.7195
# Epoch 16/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 47.6692 - val_loss: 48.5484
# Epoch 17/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 47.1041 - val_loss: 48.5969
# Epoch 18/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 47.2661 - val_loss: 48.4870
# Epoch 19/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 46.6274 - val_loss: 48.4639
# Epoch 20/1000
# 42/47 [=========================>....] - ETA: 0s - loss: 46.6722roc-auc_val: 0.7845
# 47/47 [==============================] - 14s 289ms/step - loss: 46.4630 - val_loss: 48.3700
# Epoch 21/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 46.1376 - val_loss: 48.1965
# Epoch 22/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 45.6332 - val_loss: 48.1234
# Epoch 23/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 45.1464 - val_loss: 48.0555
# Epoch 24/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 44.4030 - val_loss: 47.9623
# Epoch 25/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 44.6902 - val_loss: 47.9889
# Epoch 26/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 44.2659 - val_loss: 47.8823
# Epoch 27/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 43.4895 - val_loss: 47.6633
# Epoch 28/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 43.3827 - val_loss: 47.6522
# Epoch 29/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 42.8018 - val_loss: 47.6440
# Epoch 30/1000
# 38/47 [=======================>......] - ETA: 0s - loss: 43.5158roc-auc_val: 0.79
# 47/47 [==============================] - 14s 296ms/step - loss: 43.3825 - val_loss: 47.6355
# Epoch 31/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 42.7696 - val_loss: 47.5503
# Epoch 32/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 42.6649 - val_loss: 47.5689
# Epoch 33/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 43.0313 - val_loss: 47.6480
# Epoch 34/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 42.5888 - val_loss: 47.6277
# Epoch 35/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 41.7406 - val_loss: 47.5799
# Epoch 36/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 42.0934 - val_loss: 47.4961
# Epoch 37/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 41.9833 - val_loss: 47.4435
# Epoch 38/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 41.7526 - val_loss: 47.3886
# Epoch 39/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 41.0513 - val_loss: 47.3834
# Epoch 40/1000
# 41/47 [=========================>....] - ETA: 0s - loss: 41.7521roc-auc_val: 0.7931
# 47/47 [==============================] - 13s 281ms/step - loss: 41.2924 - val_loss: 47.3893
# Epoch 41/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 40.7039 - val_loss: 47.3442
# Epoch 42/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 40.8852 - val_loss: 47.3964
# Epoch 43/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 41.2563 - val_loss: 47.3935
# Epoch 44/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 40.3759 - val_loss: 47.3846
# Epoch 45/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 40.7195 - val_loss: 47.4206
# Epoch 46/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 40.2713 - val_loss: 47.4147
# Epoch 47/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 40.2066 - val_loss: 47.4002
# Epoch 48/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 40.6553 - val_loss: 47.3759
# Epoch 49/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 39.4867 - val_loss: 47.3124
# Epoch 50/1000
# 43/47 [==========================>...] - ETA: 0s - loss: 39.5413roc-auc_val: 0.7953
# 47/47 [==============================] - 13s 280ms/step - loss: 39.4180 - val_loss: 47.2359
# Epoch 51/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 39.8545 - val_loss: 47.2287
# Epoch 52/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 39.7117 - val_loss: 47.2380
# Epoch 53/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 39.6996 - val_loss: 47.2466
# Epoch 54/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 39.2286 - val_loss: 47.2127
# Epoch 55/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 39.8056 - val_loss: 47.2090
# Epoch 56/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 39.4994 - val_loss: 47.2204
# Epoch 57/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 38.9043 - val_loss: 47.1971
# Epoch 58/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 39.0697 - val_loss: 47.2010
# Epoch 59/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 38.9432 - val_loss: 47.1676
# Epoch 60/1000
# 42/47 [=========================>....] - ETA: 0s - loss: 38.4964roc-auc_val: 0.7971
# 47/47 [==============================] - 13s 281ms/step - loss: 38.7286 - val_loss: 47.1132
# Epoch 61/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 39.1533 - val_loss: 47.1258
# Epoch 62/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 38.2844 - val_loss: 47.0615
# Epoch 63/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 38.6446 - val_loss: 47.0446
# Epoch 64/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 38.2137 - val_loss: 47.1115
# Epoch 65/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 38.2944 - val_loss: 47.0193
# Epoch 66/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 38.6114 - val_loss: 47.0465
# Epoch 67/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 38.3252 - val_loss: 47.0247
# Epoch 68/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 37.3930 - val_loss: 47.0433
# Epoch 69/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 38.2506 - val_loss: 47.0749
# Epoch 70/1000
# 43/47 [==========================>...] - ETA: 0s - loss: 38.1876roc-auc_val: 0.7989
# 47/47 [==============================] - 13s 277ms/step - loss: 37.8109 - val_loss: 47.0581
# Epoch 71/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 37.9456 - val_loss: 47.0408
# Epoch 72/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 38.0538 - val_loss: 47.0425
# Epoch 73/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 38.1807 - val_loss: 46.9871
# Epoch 74/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 37.1069 - val_loss: 46.9326
# Epoch 75/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 37.5216 - val_loss: 46.9614
# Epoch 76/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 37.8617 - val_loss: 46.9648
# Epoch 77/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 37.1132 - val_loss: 46.9584
# Epoch 78/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 37.6181 - val_loss: 47.0003
# Epoch 79/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 37.1001 - val_loss: 47.0615
# Epoch 80/1000
# 41/47 [=========================>....] - ETA: 0s - loss: 36.8262roc-auc_val: 0.7994
# 47/47 [==============================] - 13s 280ms/step - loss: 36.8790 - val_loss: 47.1131
# Epoch 81/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.9310 - val_loss: 47.0768
# Epoch 82/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 37.1462 - val_loss: 47.0724
# Epoch 83/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.9584 - val_loss: 47.0729
# Epoch 84/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 37.0000 - val_loss: 47.0915
# Epoch 85/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.8863 - val_loss: 47.0330
# Epoch 86/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.6748 - val_loss: 47.0929
# Epoch 87/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.3255 - val_loss: 47.0606
# Epoch 88/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.8562 - val_loss: 47.1361
# Epoch 89/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.6322 - val_loss: 47.1679
# Epoch 90/1000
# 38/47 [=======================>......] - ETA: 0s - loss: 36.3280roc-auc_val: 0.7998
# 47/47 [==============================] - 13s 283ms/step - loss: 36.3549 - val_loss: 47.1879
# Epoch 91/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.3009 - val_loss: 47.1407
# Epoch 92/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.6937 - val_loss: 47.1878
# Epoch 93/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.3536 - val_loss: 47.1652
# Epoch 94/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.3689 - val_loss: 47.1347
# Epoch 95/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.2672 - val_loss: 47.0684
# Epoch 96/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.4286 - val_loss: 47.1035
# Epoch 97/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.8033 - val_loss: 47.0458
# Epoch 98/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.1474 - val_loss: 47.0650
# Epoch 99/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 36.1236 - val_loss: 47.1354
# Epoch 100/1000
# 40/47 [========================>.....] - ETA: 0s - loss: 35.7476roc-auc_val: 0.8011
# 47/47 [==============================] - 13s 281ms/step - loss: 35.7915 - val_loss: 47.1587
# Epoch 101/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.7438 - val_loss: 47.1547
# Epoch 102/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.0046 - val_loss: 47.1219
# Epoch 103/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.6966 - val_loss: 47.1329
# Epoch 104/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 36.0583 - val_loss: 47.1063
# Epoch 105/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.5551 - val_loss: 47.1128
# Epoch 106/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.5649 - val_loss: 47.1446
# Epoch 107/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.7216 - val_loss: 47.1392
# Epoch 108/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.4273 - val_loss: 47.1990
# Epoch 109/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.5265 - val_loss: 47.1990
# Epoch 110/1000
# 40/47 [========================>.....] - ETA: 0s - loss: 35.4934roc-auc_val: 0.8018
# 47/47 [==============================] - 13s 280ms/step - loss: 35.5437 - val_loss: 47.1709
# Epoch 111/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.6983 - val_loss: 47.1497
# Epoch 112/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.4247 - val_loss: 47.1729
# Epoch 113/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.1214 - val_loss: 47.1813
# Epoch 114/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.3397 - val_loss: 47.2061
# Epoch 115/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 35.1855 - val_loss: 47.2284
# Epoch 116/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 34.9830 - val_loss: 47.2000
# Epoch 117/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 35.3354 - val_loss: 47.2293
# Epoch 118/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 35.4564 - val_loss: 47.2282
# Epoch 119/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 35.0580 - val_loss: 47.2095
# Epoch 120/1000
# 37/47 [======================>.......] - ETA: 0s - loss: 34.3593roc-auc_val: 0.8024
# 47/47 [==============================] - 14s 299ms/step - loss: 34.7667 - val_loss: 47.2085
# Epoch 121/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 35.1042 - val_loss: 47.1907
# Epoch 122/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 34.6360 - val_loss: 47.2202
# Epoch 123/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 34.6606 - val_loss: 47.2238
# Epoch 124/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 34.5580 - val_loss: 47.2254
# Epoch 1/1000
# 88/88 [==============================] - 1s 15ms/step - loss: 70.7977 - val_loss: 49.3375
# Epoch 2/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 60.8622 - val_loss: 48.0296
# Epoch 3/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 56.2980 - val_loss: 47.7634
# Epoch 4/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 54.9896 - val_loss: 47.3720
# Epoch 5/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 52.6675 - val_loss: 47.0201
# Epoch 6/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 52.4780 - val_loss: 46.8920
# Epoch 7/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 50.7807 - val_loss: 46.7566
# Epoch 8/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 49.4391 - val_loss: 46.5868
# Epoch 9/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 48.6432 - val_loss: 46.4547
# Epoch 10/1000
# 83/88 [===========================>..] - ETA: 0s - loss: 48.4312roc-auc_val: 0.7934
# 88/88 [==============================] - 11s 127ms/step - loss: 48.3218 - val_loss: 46.2343
# Epoch 11/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 47.6865 - val_loss: 46.1601
# Epoch 12/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 46.5679 - val_loss: 45.9985
# Epoch 13/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 46.2969 - val_loss: 45.9141
# Epoch 14/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 45.3752 - val_loss: 45.8717
# Epoch 15/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 46.0542 - val_loss: 45.7628
# Epoch 16/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 45.2035 - val_loss: 45.6639
# Epoch 17/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 44.5375 - val_loss: 45.6047
# Epoch 18/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 43.9364 - val_loss: 45.5228
# Epoch 19/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 44.6875 - val_loss: 45.5088
# Epoch 20/1000
# 80/88 [==========================>...] - ETA: 0s - loss: 44.1985roc-auc_val: 0.8031
# 88/88 [==============================] - 11s 128ms/step - loss: 44.2307 - val_loss: 45.4496
# Epoch 21/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 43.6453 - val_loss: 45.4135
# Epoch 22/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 43.5087 - val_loss: 45.4039
# Epoch 23/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 43.1062 - val_loss: 45.3276
# Epoch 24/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 42.8301 - val_loss: 45.2549
# Epoch 25/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 42.4993 - val_loss: 45.2270
# Epoch 26/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 42.4891 - val_loss: 45.1827
# Epoch 27/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 42.2992 - val_loss: 45.1397
# Epoch 28/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 42.4435 - val_loss: 45.0723
# Epoch 29/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 42.0595 - val_loss: 45.0274
# Epoch 30/1000
# 79/88 [=========================>....] - ETA: 0s - loss: 41.9721roc-auc_val: 0.8082
# 88/88 [==============================] - 11s 126ms/step - loss: 41.9742 - val_loss: 45.0090
# Epoch 31/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 41.5795 - val_loss: 44.9545
# Epoch 32/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 41.6379 - val_loss: 44.9150
# Epoch 33/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 40.9674 - val_loss: 44.8922
# Epoch 34/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 41.0841 - val_loss: 44.8371
# Epoch 35/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 40.9403 - val_loss: 44.8218
# Epoch 36/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 40.8417 - val_loss: 44.8236
# Epoch 37/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 41.2975 - val_loss: 44.7911
# Epoch 38/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 40.5162 - val_loss: 44.7636
# Epoch 39/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 40.6765 - val_loss: 44.7325
# Epoch 40/1000
# 83/88 [===========================>..] - ETA: 0s - loss: 39.9182roc-auc_val: 0.8115
# 88/88 [==============================] - 11s 126ms/step - loss: 39.8340 - val_loss: 44.6960
# Epoch 41/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 40.0915 - val_loss: 44.7115
# Epoch 42/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 40.0719 - val_loss: 44.7039
# Epoch 43/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 40.3989 - val_loss: 44.6445
# Epoch 44/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 40.1353 - val_loss: 44.6038
# Epoch 45/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 39.7198 - val_loss: 44.5969
# Epoch 46/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 39.8377 - val_loss: 44.5982
# Epoch 47/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 39.5301 - val_loss: 44.5882
# Epoch 48/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 40.0355 - val_loss: 44.6095
# Epoch 49/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 39.1778 - val_loss: 44.5678
# Epoch 50/1000
# 82/88 [==========================>...] - ETA: 0s - loss: 39.2028roc-auc_val: 0.8133
# 88/88 [==============================] - 11s 128ms/step - loss: 39.0750 - val_loss: 44.6002
# Epoch 51/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 39.3697 - val_loss: 44.5773
# Epoch 52/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 39.5352 - val_loss: 44.5366
# Epoch 53/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 39.5865 - val_loss: 44.4972
# Epoch 54/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.9746 - val_loss: 44.4925
# Epoch 55/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 39.1700 - val_loss: 44.4855
# Epoch 56/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.5868 - val_loss: 44.4699
# Epoch 57/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.9270 - val_loss: 44.4708
# Epoch 58/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.7514 - val_loss: 44.4588
# Epoch 59/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 39.0131 - val_loss: 44.4610
# Epoch 60/1000
# 79/88 [=========================>....] - ETA: 0s - loss: 38.5872roc-auc_val: 0.8152
# 88/88 [==============================] - 11s 129ms/step - loss: 38.4510 - val_loss: 44.4450
# Epoch 61/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.7875 - val_loss: 44.4487
# Epoch 62/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.4600 - val_loss: 44.4168
# Epoch 63/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.4183 - val_loss: 44.3844
# Epoch 64/1000
# 88/88 [==============================] - 1s 9ms/step - loss: 38.7878 - val_loss: 44.3810
# Epoch 65/1000
# 88/88 [==============================] - 1s 9ms/step - loss: 38.2732 - val_loss: 44.3575
# Epoch 66/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.3453 - val_loss: 44.3679
# Epoch 67/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.3302 - val_loss: 44.3675
# Epoch 68/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.3285 - val_loss: 44.3446
# Epoch 69/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.0279 - val_loss: 44.3101
# Epoch 70/1000
# 79/88 [=========================>....] - ETA: 0s - loss: 38.1941roc-auc_val: 0.8165
# 88/88 [==============================] - 11s 126ms/step - loss: 38.0404 - val_loss: 44.3252
# Epoch 71/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.0339 - val_loss: 44.3265
# Epoch 72/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.8795 - val_loss: 44.3098
# Epoch 73/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.9222 - val_loss: 44.3120
# Epoch 74/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.2405 - val_loss: 44.2965
# Epoch 75/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.6695 - val_loss: 44.2812
# Epoch 76/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 38.0179 - val_loss: 44.2739
# Epoch 77/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.7031 - val_loss: 44.2524
# Epoch 78/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.6329 - val_loss: 44.2675
# Epoch 79/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.6836 - val_loss: 44.2556
# Epoch 80/1000
# 88/88 [==============================] - ETA: 0s - loss: 37.1502roc-auc_val: 0.8176
# 88/88 [==============================] - 11s 129ms/step - loss: 37.1502 - val_loss: 44.2558
# Epoch 81/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.3589 - val_loss: 44.2494
# Epoch 82/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.5438 - val_loss: 44.2508
# Epoch 83/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.3737 - val_loss: 44.2616
# Epoch 84/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.3293 - val_loss: 44.2535
# Epoch 85/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.9388 - val_loss: 44.2385
# Epoch 86/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.9678 - val_loss: 44.2349
# Epoch 87/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.1856 - val_loss: 44.2176
# Epoch 88/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.0832 - val_loss: 44.2197
# Epoch 89/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.1591 - val_loss: 44.2149
# Epoch 90/1000
# 82/88 [==========================>...] - ETA: 0s - loss: 37.0221roc-auc_val: 0.8185
# 88/88 [==============================] - 11s 127ms/step - loss: 36.8744 - val_loss: 44.2020
# Epoch 91/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.9911 - val_loss: 44.1935
# Epoch 92/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.7363 - val_loss: 44.1755
# Epoch 93/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.7029 - val_loss: 44.1754
# Epoch 94/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.6387 - val_loss: 44.1934
# Epoch 95/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 37.0078 - val_loss: 44.1894
# Epoch 96/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.8532 - val_loss: 44.2012
# Epoch 97/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.7670 - val_loss: 44.2062
# Epoch 98/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.6225 - val_loss: 44.2131
# Epoch 99/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.4408 - val_loss: 44.1987
# Epoch 100/1000
# 83/88 [===========================>..] - ETA: 0s - loss: 36.5262roc-auc_val: 0.8191
# 88/88 [==============================] - 11s 128ms/step - loss: 36.5616 - val_loss: 44.2203
# Epoch 101/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.5994 - val_loss: 44.2156
# Epoch 102/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.3976 - val_loss: 44.2151
# Epoch 103/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.3767 - val_loss: 44.1962
# Epoch 104/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.5450 - val_loss: 44.1890
# Epoch 105/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.4760 - val_loss: 44.1792
# Epoch 106/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.2318 - val_loss: 44.1989
# Epoch 107/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.2243 - val_loss: 44.2031
# Epoch 108/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.3715 - val_loss: 44.2057
# Epoch 109/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.2589 - val_loss: 44.1952
# Epoch 110/1000
# 80/88 [==========================>...] - ETA: 0s - loss: 36.1657roc-auc_val: 0.8196
# 88/88 [==============================] - 11s 129ms/step - loss: 36.2003 - val_loss: 44.2076
# Epoch 111/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.1730 - val_loss: 44.1966
# Epoch 112/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.1207 - val_loss: 44.1854
# Epoch 113/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.3473 - val_loss: 44.1788
# Epoch 114/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.2189 - val_loss: 44.1948
# Epoch 115/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.9214 - val_loss: 44.1851
# Epoch 116/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.2331 - val_loss: 44.1898
# Epoch 117/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.0634 - val_loss: 44.1926
# Epoch 118/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.8372 - val_loss: 44.2069
# Epoch 119/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.1114 - val_loss: 44.2150
# Epoch 120/1000
# 80/88 [==========================>...] - ETA: 0s - loss: 36.2834roc-auc_val: 0.82
# 88/88 [==============================] - 11s 126ms/step - loss: 36.0518 - val_loss: 44.1999
# Epoch 121/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 36.0245 - val_loss: 44.2124
# Epoch 122/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.8040 - val_loss: 44.2108
# Epoch 123/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.6376 - val_loss: 44.1893
# Epoch 124/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.8510 - val_loss: 44.1912
# Epoch 125/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.7545 - val_loss: 44.1829
# Epoch 126/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.6882 - val_loss: 44.1902
# Epoch 127/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.6917 - val_loss: 44.1965
# Epoch 128/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.7625 - val_loss: 44.1880
# Epoch 129/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.5127 - val_loss: 44.1836
# Epoch 130/1000
# 82/88 [==========================>...] - ETA: 0s - loss: 35.5788roc-auc_val: 0.8206
# 88/88 [==============================] - 11s 127ms/step - loss: 35.6048 - val_loss: 44.1683
# Epoch 131/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.2154 - val_loss: 44.1720
# Epoch 132/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.7975 - val_loss: 44.1814
# Epoch 133/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.5302 - val_loss: 44.1616
# Epoch 134/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.3659 - val_loss: 44.1568
# Epoch 135/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.6931 - val_loss: 44.1547
# Epoch 136/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.4484 - val_loss: 44.1794
# Epoch 137/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.4039 - val_loss: 44.1785
# Epoch 138/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.2518 - val_loss: 44.1658
# Epoch 139/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.5189 - val_loss: 44.1515
# Epoch 140/1000
# 80/88 [==========================>...] - ETA: 0s - loss: 35.4892roc-auc_val: 0.821
# 88/88 [==============================] - 11s 126ms/step - loss: 35.3820 - val_loss: 44.1519
# Epoch 141/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.2195 - val_loss: 44.1625
# Epoch 142/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.4032 - val_loss: 44.1645
# Epoch 143/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.2492 - val_loss: 44.1677
# Epoch 144/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.3392 - val_loss: 44.1758
# Epoch 145/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.3031 - val_loss: 44.1792
# Epoch 146/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.0190 - val_loss: 44.1716
# Epoch 147/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.3197 - val_loss: 44.1864
# Epoch 148/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.3878 - val_loss: 44.1952
# Epoch 149/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.9426 - val_loss: 44.1770
# Epoch 150/1000
# 78/88 [=========================>....] - ETA: 0s - loss: 34.7822roc-auc_val: 0.8214
# 88/88 [==============================] - 11s 129ms/step - loss: 34.9666 - val_loss: 44.1715
# Epoch 151/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.2637 - val_loss: 44.1955
# Epoch 152/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.1790 - val_loss: 44.1974
# Epoch 153/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.0013 - val_loss: 44.1972
# Epoch 154/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.4154 - val_loss: 44.1944
# Epoch 155/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.0410 - val_loss: 44.1988
# Epoch 156/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.1750 - val_loss: 44.2089
# Epoch 157/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.9669 - val_loss: 44.2127
# Epoch 158/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.7757 - val_loss: 44.2110
# Epoch 159/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.8169 - val_loss: 44.1978
# Epoch 160/1000
# 81/88 [==========================>...] - ETA: 0s - loss: 35.2218roc-auc_val: 0.8216
# 88/88 [==============================] - 12s 138ms/step - loss: 35.1018 - val_loss: 44.1898
# Epoch 161/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.7763 - val_loss: 44.1930
# Epoch 162/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.6936 - val_loss: 44.2009
# Epoch 163/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.9964 - val_loss: 44.1947
# Epoch 164/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.7227 - val_loss: 44.1968
# Epoch 165/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.1831 - val_loss: 44.1880
# Epoch 166/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.8921 - val_loss: 44.2048
# Epoch 167/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.7778 - val_loss: 44.2156
# Epoch 168/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.7071 - val_loss: 44.2082
# Epoch 169/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 35.1140 - val_loss: 44.2034
# Epoch 170/1000
# 82/88 [==========================>...] - ETA: 0s - loss: 34.7344roc-auc_val: 0.8219
# 88/88 [==============================] - 11s 126ms/step - loss: 34.5611 - val_loss: 44.2181
# Epoch 171/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.8241 - val_loss: 44.2144
# Epoch 172/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.6197 - val_loss: 44.2168
# Epoch 173/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.5412 - val_loss: 44.2296
# Epoch 174/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.7577 - val_loss: 44.2196
# Epoch 175/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.2661 - val_loss: 44.2246
# Epoch 176/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.4020 - val_loss: 44.2202
# Epoch 177/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.3997 - val_loss: 44.2233
# Epoch 178/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.4070 - val_loss: 44.2270
# Epoch 179/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.3162 - val_loss: 44.2248
# Epoch 180/1000
# 81/88 [==========================>...] - ETA: 0s - loss: 34.1407roc-auc_val: 0.8221
# 88/88 [==============================] - 11s 127ms/step - loss: 34.2903 - val_loss: 44.2375
# Epoch 181/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.4116 - val_loss: 44.2491
# Epoch 182/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.1385 - val_loss: 44.2404
# Epoch 183/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.4811 - val_loss: 44.2343
# Epoch 184/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.4622 - val_loss: 44.2502
# Epoch 185/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.5148 - val_loss: 44.2267
# Epoch 186/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.6568 - val_loss: 44.2327
# Epoch 187/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.5416 - val_loss: 44.2274
# Epoch 188/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.4068 - val_loss: 44.2273
# Epoch 189/1000
# 88/88 [==============================] - 1s 8ms/step - loss: 34.4126 - val_loss: 44.2208
# Epoch 1/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 72.7654 - val_loss: 50.0866
# Epoch 2/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 64.6982 - val_loss: 48.5818
# Epoch 3/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 61.2246 - val_loss: 47.7338
# Epoch 4/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 58.5009 - val_loss: 47.6848
# Epoch 5/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 56.4944 - val_loss: 47.5738
# Epoch 6/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 54.3744 - val_loss: 47.7693
# Epoch 7/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 53.8988 - val_loss: 47.8069
# Epoch 8/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 52.1822 - val_loss: 47.4960
# Epoch 9/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 51.4831 - val_loss: 47.5266
# Epoch 10/1000
# 37/47 [======================>.......] - ETA: 0s - loss: 52.0186roc-auc_val: 0.7743
# 47/47 [==============================] - 11s 236ms/step - loss: 51.2627 - val_loss: 47.5153
# Epoch 11/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 50.5480 - val_loss: 47.3374
# Epoch 12/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 49.1107 - val_loss: 47.2966
# Epoch 13/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 49.0842 - val_loss: 47.3061
# Epoch 14/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 48.4403 - val_loss: 47.1349
# Epoch 15/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 47.3116 - val_loss: 47.1559
# Epoch 16/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 47.2462 - val_loss: 47.0876
# Epoch 17/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 46.3809 - val_loss: 47.1292
# Epoch 18/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 46.3650 - val_loss: 47.1753
# Epoch 19/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 45.8129 - val_loss: 47.1337
# Epoch 20/1000
# 41/47 [=========================>....] - ETA: 0s - loss: 45.7380roc-auc_val: 0.7865
# 47/47 [==============================] - 11s 242ms/step - loss: 45.5431 - val_loss: 47.0419
# Epoch 21/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 45.2999 - val_loss: 46.9452
# Epoch 22/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 44.9430 - val_loss: 46.9161
# Epoch 23/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 44.1252 - val_loss: 46.9253
# Epoch 24/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 44.2518 - val_loss: 46.9718
# Epoch 25/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 44.5943 - val_loss: 46.8608
# Epoch 26/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 43.4876 - val_loss: 46.9469
# Epoch 27/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 44.0373 - val_loss: 46.9375
# Epoch 28/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 42.9578 - val_loss: 46.9604
# Epoch 29/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 43.2508 - val_loss: 46.8984
# Epoch 30/1000
# 41/47 [=========================>....] - ETA: 0s - loss: 43.1619roc-auc_val: 0.7914
# 47/47 [==============================] - 11s 236ms/step - loss: 43.0905 - val_loss: 46.8733
# Epoch 31/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 42.7131 - val_loss: 46.8888
# Epoch 32/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 42.7778 - val_loss: 46.9263
# Epoch 33/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 42.2790 - val_loss: 46.8941
# Epoch 34/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 42.3698 - val_loss: 46.9566
# Epoch 35/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 42.3297 - val_loss: 47.1166
# Epoch 36/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 41.4900 - val_loss: 47.0895
# Epoch 37/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 41.7291 - val_loss: 47.0478
# Epoch 38/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 41.0414 - val_loss: 47.0192
# Epoch 39/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 41.3030 - val_loss: 47.0645
# Epoch 40/1000
# 38/47 [=======================>......] - ETA: 0s - loss: 41.0926roc-auc_val: 0.7942
# 47/47 [==============================] - 11s 234ms/step - loss: 41.1650 - val_loss: 46.9848
# Epoch 41/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 40.5970 - val_loss: 47.0444
# Epoch 42/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 40.6895 - val_loss: 47.0269
# Epoch 43/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 40.8147 - val_loss: 47.0058
# Epoch 44/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 40.1705 - val_loss: 47.0263
# Epoch 45/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 41.3475 - val_loss: 47.1259
# Epoch 46/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 40.5850 - val_loss: 47.0622
# Epoch 47/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 39.2555 - val_loss: 46.9713
# Epoch 48/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 40.9332 - val_loss: 47.0555
# Epoch 49/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 39.7463 - val_loss: 47.0261
# Epoch 50/1000
# 42/47 [=========================>....] - ETA: 0s - loss: 39.7734roc-auc_val: 0.7962
# 47/47 [==============================] - 12s 245ms/step - loss: 39.6425 - val_loss: 47.0743
# Epoch 51/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 39.2155 - val_loss: 47.0341
# Epoch 52/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 39.6574 - val_loss: 46.9961
# Epoch 53/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 38.9122 - val_loss: 47.0499
# Epoch 54/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 39.0801 - val_loss: 47.0238
# Epoch 55/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 39.1081 - val_loss: 47.0960
# Epoch 56/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 38.6908 - val_loss: 47.0171
# Epoch 57/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 39.2255 - val_loss: 47.0360
# Epoch 58/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 38.8387 - val_loss: 47.1119
# Epoch 59/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 38.5758 - val_loss: 47.1516
# Epoch 60/1000
# 38/47 [=======================>......] - ETA: 0s - loss: 39.1063roc-auc_val: 0.7974
# 47/47 [==============================] - 11s 241ms/step - loss: 38.9348 - val_loss: 47.2018
# Epoch 61/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 38.2429 - val_loss: 47.2005
# Epoch 62/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 38.3496 - val_loss: 47.1848
# Epoch 63/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 38.2288 - val_loss: 47.1795
# Epoch 64/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 39.0824 - val_loss: 47.2142
# Epoch 65/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 38.0858 - val_loss: 47.1626
# Epoch 66/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 38.2781 - val_loss: 47.2431
# Epoch 67/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 37.8734 - val_loss: 47.2104
# Epoch 68/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 38.0263 - val_loss: 47.2760
# Epoch 69/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 37.8278 - val_loss: 47.2585
# Epoch 70/1000
# 39/47 [=======================>......] - ETA: 0s - loss: 38.3372roc-auc_val: 0.7985
# 47/47 [==============================] - 11s 235ms/step - loss: 37.8554 - val_loss: 47.2864
# Epoch 71/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 37.7953 - val_loss: 47.2874
# Epoch 72/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 37.8423 - val_loss: 47.2991
# Epoch 73/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 37.8628 - val_loss: 47.2973
# Epoch 74/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 37.2430 - val_loss: 47.3049
# Epoch 75/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 37.2269 - val_loss: 47.3706

# %%
import seaborn as sns
from matplotlib import pyplot as plt
for i in dk.keys():
  sns.distplot(dk[i])
  plt.show()

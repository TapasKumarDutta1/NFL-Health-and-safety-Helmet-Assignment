# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/IEEE-CIS-Fraud/blob/master/autoenc_prep_with_id_without_V.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading Libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from keras.layers import *
from keras.optimizers import *
from keras.models import *
from keras import backend as K
import keras
import random
import tensorflow as tf
import keras.backend as K

from keras.models import Model
from keras.layers import Dense, Input, Dropout, BatchNormalization, Activation
from keras.utils.generic_utils import get_custom_objects
from keras.optimizers import Adam, Nadam
from keras.callbacks import Callback
from sklearn.metrics import roc_auc_score

import gc

# %% [markdown]
# Loading data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Mounted at /content/gdrive

# %% [markdown]
# Load dataframe and drop Vs

# %%
trn=pd.read_csv('/content/gdrive/My Drive/fraud/train.csv')
tst=pd.read_csv('/content/gdrive/My Drive/fraud/test.csv')
ls=list(trn.filter(regex='V'))
trn=trn.drop(ls,1)
tst=tst.drop(ls,1)
trn=trn.drop(['isFraud'],1)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (210,222) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Divide data as numerical and categorical and create grouped mean and std with numerical and drop id

# %%
dum=list(trn.filter(regex='dum'))
cat=list(trn.select_dtypes(include=object))
cat.remove('id')
isna=list(trn.filter(regex='isna'))

tot=dum+cat+isna+['day','month','week']
num=[ i for i in list(trn) if i not in tot]

num.remove('id')
for col in num:
  trn[col+'_mean']=trn.groupby(['id'])[col].transform('mean')
  trn[col+'_std']=trn.groupby(['id'])[col].transform('std')
  
  tst[col+'_mean']=tst.groupby(['id'])[col].transform('mean')
  tst[col+'_std']=tst.groupby(['id'])[col].transform('std')
trn=trn.drop(['id'],1)
tst=tst.drop(['id'],1)

num=[ i for i in list(trn) if i not in tot]

# %% [markdown]
# Label encode categorical columns

# %%
class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm
cols=list(trn.select_dtypes(include=object))
for col in tqdm(cols):
  le=LabelEncoderExt()
  le.fit(trn[col].astype(str))
  trn[col]=le.transform(trn[col].astype(str))
  tst[col] = tst[col].map(lambda s: '<unknown>' if s not in le.classes_ else s)
  tst[col]=le.transform(tst[col].astype(str))
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# 100%|██████████| 21/21 [01:13<00:00,  3.49s/it]

# %% [markdown]
# Reduce memory used

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df
trn=reduce_mem_usage(trn)
tst=reduce_mem_usage(tst)
# Out:
# Memory usage of dataframe is 1239.00 MB
# Memory usage after optimization is: 309.75 MB
# Decreased by 75.0%
# Memory usage of dataframe is 1063.08 MB
# Memory usage after optimization is: 265.29 MB
# Decreased by 75.0%

# %%
np.random.seed(42) # NumPy
random.seed(42) # Python

# %%
def custom_gelu(x):
    return 0.5 * x * (1 + tf.tanh(tf.sqrt(2 / np.pi) * (x + 0.044715 * tf.pow(x, 3))))

# %% [markdown]
# Make the final dataset

# %%
X=pd.concat([trn,tst],0)
del([trn,tst])
gc.collect()
# Out:
# 174

# %% [markdown]
# Scale the data

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
numerical=pd.DataFrame(ss.fit_transform(X[tot]))
numerical.columns=tot
categorical=pd.DataFrame(ss.fit_transform(X[num]))
categorical.columns=num
X=pd.concat([categorical,numerical],1)
X=reduce_mem_usage(X)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/extmath.py:765: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/extmath.py:706: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = op(x, *args, **kwargs)
# Memory usage of dataframe is 1590.53 MB
# Memory usage after optimization is: 594.36 MB
# Decreased by 62.6%

# %%
0.99**50
# Out:
# 0.6050060671375364

# %% [markdown]
# Create warmup lr

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as K


class WarmUpLearningRateScheduler(keras.callbacks.Callback):
    """Warmup learning rate scheduler
    """

    def __init__(self, warmup_batches, init_lr, verbose=0):
        """Constructor for warmup learning rate scheduler

        Arguments:
            warmup_batches {int} -- Number of batch for warmup.
            init_lr {float} -- Learning rate after warmup.

        Keyword Arguments:
            verbose {int} -- 0: quiet, 1: update messages. (default: {0})
        """

        super(WarmUpLearningRateScheduler, self).__init__()
        self.warmup_batches = warmup_batches
        self.init_lr = init_lr
        self.verbose = verbose
        self.batch_count = 0
        self.learning_rates = []

    def on_batch_end(self, batch, logs=None):
        self.batch_count = self.batch_count + 1
        lr = K.get_value(self.model.optimizer.lr)
        self.learning_rates.append(lr)

    def on_batch_begin(self, batch, logs=None):
        if self.batch_count <= self.warmup_batches:
            lr = self.batch_count*self.init_lr/self.warmup_batches
            K.set_value(self.model.optimizer.lr, lr)
            if self.verbose > 0:
                print('\nBatch %05d: WarmUpLearningRateScheduler setting learning '
                      'rate to %s.' % (self.batch_count + 1, lr))
warm_up_lr = WarmUpLearningRateScheduler(400, init_lr=0.005)

# %% [markdown]
# Create data generator

# %%
from keras.utils import Sequence
class DAESequence(Sequence):
    def __init__(self,df,no_dum,frac=0.15,dumm=range(911),batch_size=2048):
        self.batch_size=batch_size
        self.frac=0.15
        self.dumm=dumm
        self.df=df
        self.cat_data=df[dumm].values
        self.num_data=df[no_dum].values
        self.no_dumm=no_dum
        self.len_data=df.shape[0]
        self.columns=df.shape[1]
        self.data=df
        self.idx=[]
        
        
        
    def __len__(self):
        return int(ceil(self.len_data/self.batch_size))
    
    
    
    def __getitem__(self,idx):
        self.idx.append(idx)
        last=min((idx+1)*self.batch_size,self.len_data)
        idx=idx*self.batch_size
        size=last-idx
        
        
        inps=[]
        outs=[]
        output_x=self.data.iloc[idx:last]
        
        
        
        
        data=output_x[self.no_dumm].values
        noise_x=data.copy()
        for i in range(len(self.no_dumm)):
            to=np.random.randint(0,size,int(size*self.frac))
            frm=np.random.randint(0,size,int(size*self.frac))
            noise_x[to,i]=noise_x[frm,i]
            
        inps.append(noise_x)
        outs.append(data)
        
        data=output_x[self.dumm].values
        noise_x=data.copy()
        for i in range(len(self.dumm)):
            to=np.random.randint(0,size,int(size*self.frac))
            frm=np.random.randint(0,size,int(size*self.frac))
            noise_x[to,i]=noise_x[frm,i]
        
        
        
        inps.append(noise_x)
        outs.append(data)
        
        
        
        
        
        return inps,outs

# %% [markdown]
# Fill the std columns and drop columns having nan mean

# %%
from tqdm import tqdm
a=X.isna().sum()
a=a[a>0]
cls=list(X)
for col in tqdm(list(a.index)):
  if col in cls:
    X[col]=X[col].fillna(X[col].mean())
a=X.isna().sum()
a=a[a>0]
for col in tqdm(list(a.index)):
  X=X.drop([col],1)
# Out:
# 100%|██████████| 37/37 [00:01<00:00, 29.56it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.23it/s]

# %% [markdown]
# Create model

# %%
from keras.layers import concatenate
from keras.optimizers import Adam
def create_model():
    K.clear_session()
    num_inp = Input(shape=(num_shape,))
    cat_inp = Input(shape=(cat_shape,))
    inps = concatenate([num_inp, cat_inp])
    x = Dense(512, activation=custom_gelu)(inps)
    a = Dense(256, activation=custom_gelu)(x)
    b = Dense(512, activation = custom_gelu)(a)
    x = Dropout(.2)(b)
    cat_out = Dense(cat_shape, activation = "linear")(x)
    num_out = Dense(num_shape, activation = "linear")(x)
    model = Model(inputs=[num_inp,cat_inp], outputs=[num_out, cat_out])
    model.compile(
        optimizer=Adam(.05, clipnorm = 1, clipvalue = 1),
        loss=["mse", "mse"]
    )
    return model

# %% [markdown]
# Fitting the model

# %%
num=[ i for i in list(X) if i not in tot]
batch_size=2048
auto_ckpt = ModelCheckpoint("ae.model", monitor='loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min', period=1)
warm_up_lr = WarmUpLearningRateScheduler(400, init_lr=0.0001)
num_shape=len(num)
cat_shape=len(tot)
model_mse = create_model()
from math import *
gc.collect()
epochs = 1000
batch_size=2048
train_gen=DAESequence(X,num,batch_size=batch_size,dumm=tot)
hist = model_mse.fit_generator(train_gen, steps_per_epoch=len(X)//batch_size, epochs=epochs,
                           verbose=1, workers=-1,
                           use_multiprocessing=True,
                              callbacks=[auto_ckpt, warm_up_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:From <ipython-input-16-1046a2493808>:17: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/1000
# 534/535 [============================>.] - ETA: 0s - loss: 1.4020 - dense_4_loss: 0.5853 - dense_3_loss: 0.8167
# Epoch 00001: loss improved from inf to 1.40821, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 1.4082 - dense_4_loss: 0.5892 - dense_3_loss: 0.8190
# Epoch 2/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.7016 - dense_4_loss: 0.2483 - dense_3_loss: 0.4533
# Epoch 00002: loss improved from 1.40821 to 0.70120, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.7012 - dense_4_loss: 0.2481 - dense_3_loss: 0.4531
# Epoch 3/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5266 - dense_4_loss: 0.1934 - dense_3_loss: 0.3332
# Epoch 00003: loss improved from 0.70120 to 0.52661, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.5266 - dense_4_loss: 0.1934 - dense_3_loss: 0.3332
# Epoch 4/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.4475 - dense_4_loss: 0.1673 - dense_3_loss: 0.2802
# Epoch 00004: loss improved from 0.52661 to 0.44743, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.4474 - dense_4_loss: 0.1672 - dense_3_loss: 0.2802
# Epoch 5/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4039 - dense_4_loss: 0.1520 - dense_3_loss: 0.2519
# Epoch 00005: loss improved from 0.44743 to 0.40395, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.4039 - dense_4_loss: 0.1520 - dense_3_loss: 0.2519
# Epoch 6/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.3772 - dense_4_loss: 0.1408 - dense_3_loss: 0.2364
# Epoch 00006: loss improved from 0.40395 to 0.37721, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.3772 - dense_4_loss: 0.1408 - dense_3_loss: 0.2364
# Epoch 7/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.3575 - dense_4_loss: 0.1340 - dense_3_loss: 0.2235
# Epoch 00007: loss improved from 0.37721 to 0.35738, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.3574 - dense_4_loss: 0.1339 - dense_3_loss: 0.2234
# Epoch 8/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.3466 - dense_4_loss: 0.1283 - dense_3_loss: 0.2183
# Epoch 00008: loss improved from 0.35738 to 0.34660, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.3466 - dense_4_loss: 0.1283 - dense_3_loss: 0.2183
# Epoch 9/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.3323 - dense_4_loss: 0.1219 - dense_3_loss: 0.2104
# Epoch 00009: loss improved from 0.34660 to 0.33211, saving model to ae.model
# 535/535 [==============================] - 13s 23ms/step - loss: 0.3321 - dense_4_loss: 0.1218 - dense_3_loss: 0.2103
# Epoch 10/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.3258 - dense_4_loss: 0.1196 - dense_3_loss: 0.2062
# Epoch 00010: loss improved from 0.33211 to 0.32576, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.3258 - dense_4_loss: 0.1196 - dense_3_loss: 0.2062
# Epoch 11/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.3183 - dense_4_loss: 0.1175 - dense_3_loss: 0.2008
# Epoch 00011: loss improved from 0.32576 to 0.31816, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.3182 - dense_4_loss: 0.1174 - dense_3_loss: 0.2007
# Epoch 12/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.3107 - dense_4_loss: 0.1131 - dense_3_loss: 0.1975
# Epoch 00012: loss improved from 0.31816 to 0.31067, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.3107 - dense_4_loss: 0.1131 - dense_3_loss: 0.1975
# Epoch 13/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.3037 - dense_4_loss: 0.1110 - dense_3_loss: 0.1926
# Epoch 00013: loss improved from 0.31067 to 0.30355, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.3036 - dense_4_loss: 0.1110 - dense_3_loss: 0.1925
# Epoch 14/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2997 - dense_4_loss: 0.1094 - dense_3_loss: 0.1903
# Epoch 00014: loss improved from 0.30355 to 0.29971, saving model to ae.model
# 535/535 [==============================] - 13s 23ms/step - loss: 0.2997 - dense_4_loss: 0.1094 - dense_3_loss: 0.1903
# Epoch 15/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2965 - dense_4_loss: 0.1081 - dense_3_loss: 0.1884
# Epoch 00015: loss improved from 0.29971 to 0.29692, saving model to ae.model
# 535/535 [==============================] - 13s 23ms/step - loss: 0.2969 - dense_4_loss: 0.1084 - dense_3_loss: 0.1885
# Epoch 16/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2941 - dense_4_loss: 0.1084 - dense_3_loss: 0.1858
# Epoch 00016: loss improved from 0.29692 to 0.29415, saving model to ae.model
# 535/535 [==============================] - 13s 23ms/step - loss: 0.2941 - dense_4_loss: 0.1084 - dense_3_loss: 0.1858
# Epoch 17/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2878 - dense_4_loss: 0.1054 - dense_3_loss: 0.1823
# Epoch 00017: loss improved from 0.29415 to 0.28821, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2882 - dense_4_loss: 0.1055 - dense_3_loss: 0.1827
# Epoch 18/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2870 - dense_4_loss: 0.1055 - dense_3_loss: 0.1815
# Epoch 00018: loss improved from 0.28821 to 0.28703, saving model to ae.model
# 535/535 [==============================] - 13s 23ms/step - loss: 0.2870 - dense_4_loss: 0.1055 - dense_3_loss: 0.1815
# Epoch 19/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2847 - dense_4_loss: 0.1050 - dense_3_loss: 0.1797
# Epoch 00019: loss improved from 0.28703 to 0.28457, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.2846 - dense_4_loss: 0.1050 - dense_3_loss: 0.1796
# Epoch 20/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2802 - dense_4_loss: 0.1034 - dense_3_loss: 0.1768
# Epoch 00020: loss improved from 0.28457 to 0.28020, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.2802 - dense_4_loss: 0.1034 - dense_3_loss: 0.1768
# Epoch 21/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2781 - dense_4_loss: 0.1020 - dense_3_loss: 0.1761
# Epoch 00021: loss improved from 0.28020 to 0.27806, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.2781 - dense_4_loss: 0.1020 - dense_3_loss: 0.1760
# Epoch 22/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2761 - dense_4_loss: 0.1024 - dense_3_loss: 0.1737
# Epoch 00022: loss improved from 0.27806 to 0.27623, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.2762 - dense_4_loss: 0.1023 - dense_3_loss: 0.1739
# Epoch 23/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2742 - dense_4_loss: 0.1008 - dense_3_loss: 0.1734
# Epoch 00023: loss improved from 0.27623 to 0.27422, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2742 - dense_4_loss: 0.1008 - dense_3_loss: 0.1734
# Epoch 24/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2714 - dense_4_loss: 0.1003 - dense_3_loss: 0.1711
# Epoch 00024: loss improved from 0.27422 to 0.27139, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2714 - dense_4_loss: 0.1003 - dense_3_loss: 0.1711
# Epoch 25/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2749 - dense_4_loss: 0.1020 - dense_3_loss: 0.1730
# Epoch 00025: loss did not improve from 0.27139
# 535/535 [==============================] - 12s 23ms/step - loss: 0.2749 - dense_4_loss: 0.1020 - dense_3_loss: 0.1730
# Epoch 26/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2688 - dense_4_loss: 0.0983 - dense_3_loss: 0.1705
# Epoch 00026: loss improved from 0.27139 to 0.26885, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.2688 - dense_4_loss: 0.0983 - dense_3_loss: 0.1705
# Epoch 27/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2667 - dense_4_loss: 0.0994 - dense_3_loss: 0.1673
# Epoch 00027: loss improved from 0.26885 to 0.26670, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.2667 - dense_4_loss: 0.0994 - dense_3_loss: 0.1673
# Epoch 28/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2660 - dense_4_loss: 0.0982 - dense_3_loss: 0.1678
# Epoch 00028: loss improved from 0.26670 to 0.26589, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.2659 - dense_4_loss: 0.0981 - dense_3_loss: 0.1678
# Epoch 29/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2627 - dense_4_loss: 0.0970 - dense_3_loss: 0.1657
# Epoch 00029: loss improved from 0.26589 to 0.26257, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2626 - dense_4_loss: 0.0969 - dense_3_loss: 0.1656
# Epoch 30/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2634 - dense_4_loss: 0.0979 - dense_3_loss: 0.1654
# Epoch 00030: loss did not improve from 0.26257
# 535/535 [==============================] - 12s 23ms/step - loss: 0.2634 - dense_4_loss: 0.0979 - dense_3_loss: 0.1654
# Epoch 31/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2601 - dense_4_loss: 0.0976 - dense_3_loss: 0.1626
# Epoch 00031: loss improved from 0.26257 to 0.26006, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.2601 - dense_4_loss: 0.0976 - dense_3_loss: 0.1625
# Epoch 32/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2614 - dense_4_loss: 0.0973 - dense_3_loss: 0.1641
# Epoch 00032: loss did not improve from 0.26006
# 535/535 [==============================] - 13s 24ms/step - loss: 0.
1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2163 - dense_4_loss: 0.0828 - dense_3_loss: 0.1335
# Epoch 00092: loss did not improve from 0.21587
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2163 - dense_4_loss: 0.0828 - dense_3_loss: 0.1335
# Epoch 93/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2149 - dense_4_loss: 0.0837 - dense_3_loss: 0.1312
# Epoch 00093: loss improved from 0.21587 to 0.21489, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2149 - dense_4_loss: 0.0837 - dense_3_loss: 0.1312
# Epoch 94/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2130 - dense_4_loss: 0.0820 - dense_3_loss: 0.1310
# Epoch 00094: loss improved from 0.21489 to 0.21304, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2130 - dense_4_loss: 0.0820 - dense_3_loss: 0.1310
# Epoch 95/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2136 - dense_4_loss: 0.0821 - dense_3_loss: 0.1316
# Epoch 00095: loss did not improve from 0.21304
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2137 - dense_4_loss: 0.0821 - dense_3_loss: 0.1316
# Epoch 96/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2126 - dense_4_loss: 0.0818 - dense_3_loss: 0.1308
# Epoch 00096: loss improved from 0.21304 to 0.21264, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2126 - dense_4_loss: 0.0818 - dense_3_loss: 0.1308
# Epoch 97/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2139 - dense_4_loss: 0.0821 - dense_3_loss: 0.1318
# Epoch 00097: loss did not improve from 0.21264
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2139 - dense_4_loss: 0.0821 - dense_3_loss: 0.1318
# Epoch 98/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2128 - dense_4_loss: 0.0824 - dense_3_loss: 0.1305
# Epoch 00098: loss did not improve from 0.21264
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2128 - dense_4_loss: 0.0824 - dense_3_loss: 0.1305
# Epoch 99/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2108 - dense_4_loss: 0.0815 - dense_3_loss: 0.1293
# Epoch 00099: loss improved from 0.21264 to 0.21072, saving model to ae.model
# 535/535 [==============================] - 13s 25ms/step - loss: 0.2107 - dense_4_loss: 0.0815 - dense_3_loss: 0.1292
# Epoch 100/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2120 - dense_4_loss: 0.0817 - dense_3_loss: 0.1303
# Epoch 00100: loss did not improve from 0.21072
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2120 - dense_4_loss: 0.0817 - dense_3_loss: 0.1302
# Epoch 101/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2107 - dense_4_loss: 0.0815 - dense_3_loss: 0.1292
# Epoch 00101: loss improved from 0.21072 to 0.21063, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2106 - dense_4_loss: 0.0815 - dense_3_loss: 0.1292
# Epoch 102/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2106 - dense_4_loss: 0.0820 - dense_3_loss: 0.1285
# Epoch 00102: loss improved from 0.21063 to 0.21056, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2106 - dense_4_loss: 0.0820 - dense_3_loss: 0.1285
# Epoch 103/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2126 - dense_4_loss: 0.0825 - dense_3_loss: 0.1301
# Epoch 00103: loss did not improve from 0.21056
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2125 - dense_4_loss: 0.0824 - dense_3_loss: 0.1300
# Epoch 104/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2110 - dense_4_loss: 0.0818 - dense_3_loss: 0.1292
# Epoch 00104: loss did not improve from 0.21056
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2110 - dense_4_loss: 0.0817 - dense_3_loss: 0.1293
# Epoch 105/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2092 - dense_4_loss: 0.0812 - dense_3_loss: 0.1279
# Epoch 00105: loss improved from 0.21056 to 0.20908, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2091 - dense_4_loss: 0.0812 - dense_3_loss: 0.1279
# Epoch 106/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2096 - dense_4_loss: 0.0819 - dense_3_loss: 0.1277
# Epoch 00106: loss did not improve from 0.20908
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2096 - dense_4_loss: 0.0819 - dense_3_loss: 0.1277
# Epoch 107/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2083 - dense_4_loss: 0.0812 - dense_3_loss: 0.1270
# Epoch 00107: loss improved from 0.20908 to 0.20822, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2082 - dense_4_loss: 0.0812 - dense_3_loss: 0.1270
# Epoch 108/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2083 - dense_4_loss: 0.0811 - dense_3_loss: 0.1272
# Epoch 00108: loss did not improve from 0.20822
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2083 - dense_4_loss: 0.0811 - dense_3_loss: 0.1272
# Epoch 109/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2086 - dense_4_loss: 0.0804 - dense_3_loss: 0.1282
# Epoch 00109: loss did not improve from 0.20822
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2086 - dense_4_loss: 0.0804 - dense_3_loss: 0.1282
# Epoch 110/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2076 - dense_4_loss: 0.0806 - dense_3_loss: 0.1270
# Epoch 00110: loss improved from 0.20822 to 0.20761, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2076 - dense_4_loss: 0.0806 - dense_3_loss: 0.1270
# Epoch 111/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2076 - dense_4_loss: 0.0807 - dense_3_loss: 0.1269
# Epoch 00111: loss improved from 0.20761 to 0.20755, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2075 - dense_4_loss: 0.0807 - dense_3_loss: 0.1268
# Epoch 112/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2072 - dense_4_loss: 0.0809 - dense_3_loss: 0.1263
# Epoch 00112: loss improved from 0.20755 to 0.20715, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2072 - dense_4_loss: 0.0809 - dense_3_loss: 0.1263
# Epoch 113/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2068 - dense_4_loss: 0.0803 - dense_3_loss: 0.1266
# Epoch 00113: loss improved from 0.20715 to 0.20683, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2068 - dense_4_loss: 0.0803 - dense_3_loss: 0.1266
# Epoch 114/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2076 - dense_4_loss: 0.0813 - dense_3_loss: 0.1263
# Epoch 00114: loss did not improve from 0.20683
# 535/535 [==============================] - 13s 25ms/step - loss: 0.2076 - dense_4_loss: 0.0813 - dense_3_loss: 0.1263
# Epoch 115/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2068 - dense_4_loss: 0.0806 - dense_3_loss: 0.1262
# Epoch 00115: loss improved from 0.20683 to 0.20674, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2067 - dense_4_loss: 0.0806 - dense_3_loss: 0.1262
# Epoch 116/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2053 - dense_4_loss: 0.0796 - dense_3_loss: 0.1257
# Epoch 00116: loss improved from 0.20674 to 0.20533, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2053 - dense_4_loss: 0.0796 - dense_3_loss: 0.1257
# Epoch 117/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2062 - dense_4_loss: 0.0806 - dense_3_loss: 0.1256
# Epoch 00117: loss did not improve from 0.20533
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2061 - dense_4_loss: 0.0806 - dense_3_loss: 0.1255
# Epoch 118/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2038 - dense_4_loss: 0.0803 - dense_3_loss: 0.1235
# Epoch 00118: loss improved from 0.20533 to 0.20380, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2038 - dense_4_loss: 0.0803 - dense_3_loss: 0.1235
# Epoch 119/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2046 - dense_4_loss: 0.0793 - dense_3_loss: 0.1253
# Epoch 00119: loss did not improve from 0.20380
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2046 - dense_4_loss: 0.0793 - dense_3_loss: 0.1253
# Epoch 120/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2034 - dense_4_loss: 0.0797 - dense_3_loss: 0.1236
# Epoch 00120: loss improved from 0.20380 to 0.20336, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2034 - dense_4_loss: 0.0797 - dense_3_loss: 0.1236
# Epoch 121/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2033 - dense_4_loss: 0.0789 - dense_3_loss: 0.1244
# Epoch 00121: loss did not improve from 0.20336
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2034 - dense_4_loss: 0.0789 - dense_3_loss: 0.1245
# Epoch 122/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2055 - dense_4_loss: 0.0807 - dense_3_loss: 0.1248
# Epoch 00122: loss did not improve from 0.20336
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2055 - dense_4_loss: 0.0807 - dense_3_loss: 0.1247
# Epoch 123/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2023 - dense_4_loss: 0.0791 - dense_3_loss: 0.1232
# Epoch 00123: loss improved from 0.20336 to 0.20231, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2023 - dense_4_loss: 0.0791 - dense_3_loss: 0.1232
# Epoch 124/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2034 - dense_4_loss: 0.0792 - dense_3_loss: 0.1242
# Epoch 00124: loss did not improve from 0.20231
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2034 - dense_4_loss: 0.0792 - dense_3_loss: 0.1242
# Epoch 125/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2034 - dense_4_loss: 0.0791 - dense_3_loss: 0.1243
# Epoch 00125: loss did not improve from 0.20231
# 535/535 [==============================] - 13s 25ms/step - loss: 0.2034 - dense_4_loss: 0.0791 - dense_3_loss: 0.1243
# Epoch 126/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2037 - dense_4_loss: 0.0789 - dense_3_loss: 0.1248
# Epoch 00126: loss did not improve from 0.20231
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2040 - dense_4_loss: 0.0790 - dense_3_loss: 0.1250
# Epoch 127/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2018 - dense_4_loss: 0.0787 - dense_3_loss: 0.1231
# Epoch 00127: loss improved from 0.20231 to 0.20181, saving model to ae.model
# 535/535 [==============================] - 13s 25ms/step - loss: 0.2018 - dense_4_loss: 0.0788 - dense_3_loss: 0.1231
# Epoch 128/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.2023 - dense_4_loss: 0.0800 - dense_3_loss: 0.1223
# Epoch 00128: loss did not improve from 0.20181
# 535/535 [==============================] - 13s 25ms/step - loss: 0.2023 - dense_4_loss: 0.0800 - dense_3_loss: 0.1223
# Epoch 129/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2014 - dense_4_loss: 0.0791 - dense_3_loss: 0.1222
# Epoch 00129: loss improved from 0.20181 to 0.20134, saving model to ae.model
# 535/535 [==============================] - 13s 25ms/step - loss: 0.2013 - dense_4_loss: 0.0792 - dense_3_loss: 0.1222
# Epoch 130/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.2011 - dense_4_loss: 0.0786 - dense_3_loss: 0.1225
# Epoch 00130: loss improved from 0.20134 to 0.20106, saving model to ae.model
# 535/535 [==============================] - 13s 25ms/step - loss: 0.2011 - dense_4_loss: 0.0786 - dense_3_loss: 0.1225
# Epoch 131/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2001 - dense_4_loss: 0.0792 - dense_3_loss: 0.1209
# Epoch 00131: loss improved from 0.20106 to 0.20008, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2001 - dense_4_loss: 0.0792 - dense_3_loss: 0.1209
# Epoch 132/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2004 - dense_4_loss: 0.0783 - dense_3_loss: 0.1221
# Epoch 00132: loss did not improve from 0.20008
# 535/535 [==============================] - 13s 25ms/step - loss: 0.2003 - dense_4_loss: 0.0783 - dense_3_loss: 0.1221
# Epoch 133/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1997 - dense_4_loss: 0.0785 - dense_3_loss: 0.1212
# Epoch 00133: loss improved from 0.20008 to 0.19991, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1999 - dense_4_loss: 0.0785 - dense_3_loss: 0.1214
# Epoch 134/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2007 - dense_4_loss: 0.0795 - dense_3_loss: 0.1212
# Epoch 00134: loss did not improve from 0.19991
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2008 - dense_4_loss: 0.0795 - dense_3_loss: 0.1214
# Epoch 135/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2016 - dense_4_loss: 0.0787 - dense_3_loss: 0.1229
# Epoch 00135: loss did not improve from 0.19991
# 535/535 [==============================] - 13s 24ms/step - loss: 0.2016 - dense_4_loss: 0.0787 - dense_3_loss: 0.1230
# Epoch 136/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.2001 - dense_4_loss: 0.0779 - dense_3_loss: 0.1222
# Epoch 00136: loss did not improve from 0.19991
# 535/535 [==============================] - 13s 25ms/step - loss: 0.2001 - dense_4_loss: 0.0779 - dense_3_loss: 0.1222
# Epoch 137/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1996 - dense_4_loss: 0.0785 - dense_3_loss: 0.1210
# Epoch 00137: loss improved from 0.19991 to 0.19954, saving model to ae.model
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1995 - dense_4_loss: 0.0785 - dense_3_loss: 0.1210
# Epoch 138/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1981 - dense_4_loss: 0.0780 - dense_3_loss: 0.1202
# Epoch 00138: loss improved from 0.19954 to 0.19812, saving model to ae.model
# 535/535 [==============================] - 14s 25ms/step - loss: 0.1981 - dense_4_loss: 0.0780 - dense_3_loss: 0.1202
# Epoch 139/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1972 - dense_4_loss: 0.0772 - dense_3_loss: 0.1200
# Epoch 00139: loss improved from 0.19812 to 0.19726, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1973 - dense_4_loss: 0.0772 - dense_3_loss: 0.1201
# Epoch 140/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1992 - dense_4_loss: 0.0777 - dense_3_loss: 0.1215
# Epoch 00140: loss did not improve from 0.19726
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1993 - dense_4_loss: 0.0776 - dense_3_loss: 0.1217
# Epoch 141/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1978 - dense_4_loss: 0.0770 - dense_3_loss: 0.1208
# Epoch 00141: loss did not improve from 0.19726
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1978 - dense_4_loss: 0.0770 - dense_3_loss: 0.1208
# Epoch 142/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1981 - dense_4_loss: 0.0781 - dense_3_loss: 0.1200
# Epoch 00142: loss did not improve from 0.19726
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1980 - dense_4_loss: 0.0781 - dense_3_loss: 0.1199
# Epoch 143/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1981 - dense_4_loss: 0.0774 - dense_3_loss: 0.1207
# Epoch 00143: loss did not improve from 0.19726
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1982 - dense_4_loss: 0.0774 - dense_3_loss: 0.1208
# Epoch 144/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1959 - dense_4_loss: 0.0774 - dense_3_loss: 0.1186
# Epoch 00144: loss improved from 0.19726 to 0.19585, saving model to ae.model
# 535/535 [==============================] - 13s 23ms/step - loss: 0.1959 - dense_4_loss: 0.0773 - dense_3_loss: 0.1185
# Epoch 145/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1968 - dense_4_loss: 0.0772 - dense_3_loss: 0.1196
# Epoch 00145: loss did not improve from 0.19585
# 535/535 [==============================] - 13s 23ms/step - loss: 0.1967 - dense_4_loss: 0.0772 - dense_3_loss: 0.1195
# Epoch 146/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1961 - dense_4_loss: 0.0767 - dense_3_loss: 0.1195
# Epoch 00146: loss did not improve from 0.19585
# 535/535 [==============================] - 13s 23ms/step - loss: 0.1962 - dense_4_loss: 0.0768 - dense_3_loss: 0.1194
# Epoch 147/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1969 - dense_4_loss: 0.0768 - dense_3_loss: 0.1201
# Epoch 00147: loss did not improve from 0.19585
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1969 - dense_4_loss: 0.0768 - dense_3_loss: 0.1201
# Epoch 148/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1958 - dense_4_loss: 0.0766 - dense_3_loss: 0.1193
# Epoch 00148: loss improved from 0.19585 to 0.19584, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1958 - dense_4_loss: 0.0766 - dense_3_loss: 0.1193
# Epoch 149/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1963 - dense_4_loss: 0.0773 - dense_3_loss: 0.1191
# Epoch 00149: loss did not improve from 0.19584
# 535/535 [==============================] - 13s 23ms/step - loss: 0.1963 - dense_4_loss: 0.0773 - dense_3_loss: 0.1191
# Epoch 150/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1948 - dense_4_loss: 0.0769 - dense_3_loss: 0.1179
# Epoch 00150: loss improved from 0.19584 to 0.19476, saving model to ae.model
# 535/535 [==============================] - 12s 23ms/step - loss: 0.1948 - dense_4_loss: 0.0769 - dense_3_loss: 0.1179
# Epoch 151/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1934 - dense_4_loss: 0.0766 - dense_3_loss: 0.1168
# Epoch 00151: loss improved from 0.19476 to 0.19336, saving model to ae.model
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1934 - dense_4_loss: 0.0766 - dense_3_loss: 0.1167
# Epoch 152/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1952 - dense_4_loss: 0.0765 - dense_3_loss: 0.1188
# Epoch 00152: loss did not improve from 0.19336
# 535/535 [==============================] - 13s 23ms/step - loss: 0.1952 - dense_4_loss: 0.0765 - dense_3_loss: 0.1187
# Epoch 153/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1966 - dense_4_loss: 0.0770 - dense_3_loss: 0.1196
# Epoch 00153: loss did not improve from 0.19336
# 535/535 [==============================] - 12s 23ms/step - loss: 0.1966 - dense_4_loss: 0.0770 - dense_3_loss: 0.1196
# Epoch 154/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1939 - dense_4_loss: 0.0769 - dense_3_loss: 0.1169
# Epoch 00154: loss did not improve from 0.19336
# 535/535 [==============================] - 12s 23ms/step - loss: 0.1939 - dense_4_loss: 0.0769 - dense_3_loss: 0.1169
# Epoch 155/1000
# ...
# Epoch 00946: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1522 - dense_4_loss: 0.0610 - dense_3_loss: 0.0911
# Epoch 947/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1493 - dense_4_loss: 0.0604 - dense_3_loss: 0.0890
# Epoch 00947: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1494 - dense_4_loss: 0.0604 - dense_3_loss: 0.0890
# Epoch 948/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1504 - dense_4_loss: 0.0610 - dense_3_loss: 0.0893
# Epoch 00948: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1504 - dense_4_loss: 0.0611 - dense_3_loss: 0.0893
# Epoch 949/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1489 - dense_4_loss: 0.0608 - dense_3_loss: 0.0881
# Epoch 00949: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1489 - dense_4_loss: 0.0608 - dense_3_loss: 0.0881
# Epoch 950/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1495 - dense_4_loss: 0.0601 - dense_3_loss: 0.0894
# Epoch 00950: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1495 - dense_4_loss: 0.0601 - dense_3_loss: 0.0894
# Epoch 951/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1501 - dense_4_loss: 0.0613 - dense_3_loss: 0.0889
# Epoch 00951: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1501 - dense_4_loss: 0.0613 - dense_3_loss: 0.0889
# Epoch 952/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1504 - dense_4_loss: 0.0608 - dense_3_loss: 0.0895
# Epoch 00952: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 24ms/step - loss: 0.1504 - dense_4_loss: 0.0608 - dense_3_loss: 0.0896
# Epoch 953/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1501 - dense_4_loss: 0.0614 - dense_3_loss: 0.0886
# Epoch 00953: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1500 - dense_4_loss: 0.0614 - dense_3_loss: 0.0886
# Epoch 954/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1499 - dense_4_loss: 0.0607 - dense_3_loss: 0.0893
# Epoch 00954: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1499 - dense_4_loss: 0.0606 - dense_3_loss: 0.0892
# Epoch 955/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1493 - dense_4_loss: 0.0604 - dense_3_loss: 0.0889
# Epoch 00955: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1493 - dense_4_loss: 0.0604 - dense_3_loss: 0.0889
# Epoch 956/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1489 - dense_4_loss: 0.0605 - dense_3_loss: 0.0885
# Epoch 00956: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1492 - dense_4_loss: 0.0604 - dense_3_loss: 0.0888
# Epoch 957/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1489 - dense_4_loss: 0.0605 - dense_3_loss: 0.0885
# Epoch 00957: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1489 - dense_4_loss: 0.0604 - dense_3_loss: 0.0885
# Epoch 958/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1511 - dense_4_loss: 0.0600 - dense_3_loss: 0.0911
# Epoch 00958: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1511 - dense_4_loss: 0.0600 - dense_3_loss: 0.0911
# Epoch 959/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1507 - dense_4_loss: 0.0608 - dense_3_loss: 0.0899
# Epoch 00959: loss did not improve from 0.14859
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1507 - dense_4_loss: 0.0608 - dense_3_loss: 0.0899
# Epoch 960/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1499 - dense_4_loss: 0.0604 - dense_3_loss: 0.0895
# Epoch 00960: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1499 - dense_4_loss: 0.0603 - dense_3_loss: 0.0895
# Epoch 961/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1505 - dense_4_loss: 0.0610 - dense_3_loss: 0.0896
# Epoch 00961: loss did not improve from 0.14859
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1505 - dense_4_loss: 0.0610 - dense_3_loss: 0.0895
# Epoch 962/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1483 - dense_4_loss: 0.0602 - dense_3_loss: 0.0881
# Epoch 00962: loss improved from 0.14859 to 0.14826, saving model to ae.model
# 535/535 [==============================] - 14s 25ms/step - loss: 0.1483 - dense_4_loss: 0.0602 - dense_3_loss: 0.0881
# Epoch 963/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1501 - dense_4_loss: 0.0604 - dense_3_loss: 0.0897
# Epoch 00963: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 25ms/step - loss: 0.1502 - dense_4_loss: 0.0604 - dense_3_loss: 0.0897
# Epoch 964/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1493 - dense_4_loss: 0.0602 - dense_3_loss: 0.0890
# Epoch 00964: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1492 - dense_4_loss: 0.0602 - dense_3_loss: 0.0890
# Epoch 965/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1495 - dense_4_loss: 0.0608 - dense_3_loss: 0.0887
# Epoch 00965: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1495 - dense_4_loss: 0.0608 - dense_3_loss: 0.0887
# Epoch 966/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1507 - dense_4_loss: 0.0609 - dense_3_loss: 0.0897
# Epoch 00966: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1506 - dense_4_loss: 0.0609 - dense_3_loss: 0.0897
# Epoch 967/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1492 - dense_4_loss: 0.0605 - dense_3_loss: 0.0887
# Epoch 00967: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 25ms/step - loss: 0.1492 - dense_4_loss: 0.0605 - dense_3_loss: 0.0887
# Epoch 968/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1513 - dense_4_loss: 0.0612 - dense_3_loss: 0.0901
# Epoch 00968: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1513 - dense_4_loss: 0.0612 - dense_3_loss: 0.0901
# Epoch 969/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1505 - dense_4_loss: 0.0612 - dense_3_loss: 0.0894
# Epoch 00969: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1505 - dense_4_loss: 0.0612 - dense_3_loss: 0.0894
# Epoch 970/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1499 - dense_4_loss: 0.0609 - dense_3_loss: 0.0890
# Epoch 00970: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1499 - dense_4_loss: 0.0609 - dense_3_loss: 0.0890
# Epoch 971/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1488 - dense_4_loss: 0.0606 - dense_3_loss: 0.0882
# Epoch 00971: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1488 - dense_4_loss: 0.0606 - dense_3_loss: 0.0882
# Epoch 972/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1506 - dense_4_loss: 0.0606 - dense_3_loss: 0.0900
# Epoch 00972: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1506 - dense_4_loss: 0.0606 - dense_3_loss: 0.0900
# Epoch 973/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1487 - dense_4_loss: 0.0603 - dense_3_loss: 0.0884
# Epoch 00973: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1487 - dense_4_loss: 0.0603 - dense_3_loss: 0.0884
# Epoch 974/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1495 - dense_4_loss: 0.0601 - dense_3_loss: 0.0894
# Epoch 00974: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1495 - dense_4_loss: 0.0601 - dense_3_loss: 0.0894
# Epoch 975/1000
# 533/535 [============================>.] - ETA: 0s - loss: 0.1502 - dense_4_loss: 0.0608 - dense_3_loss: 0.0894
# Epoch 00975: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1503 - dense_4_loss: 0.0609 - dense_3_loss: 0.0894
# Epoch 976/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1501 - dense_4_loss: 0.0616 - dense_3_loss: 0.0885
# Epoch 00976: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1501 - dense_4_loss: 0.0616 - dense_3_loss: 0.0885
# Epoch 977/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1501 - dense_4_loss: 0.0610 - dense_3_loss: 0.0892
# Epoch 00977: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1502 - dense_4_loss: 0.0610 - dense_3_loss: 0.0892
# Epoch 978/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1502 - dense_4_loss: 0.0608 - dense_3_loss: 0.0893
# Epoch 00978: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1501 - dense_4_loss: 0.0608 - dense_3_loss: 0.0893
# Epoch 979/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1485 - dense_4_loss: 0.0604 - dense_3_loss: 0.0881
# Epoch 00979: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1485 - dense_4_loss: 0.0604 - dense_3_loss: 0.0881
# Epoch 980/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1495 - dense_4_loss: 0.0607 - dense_3_loss: 0.0888
# Epoch 00980: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 25ms/step - loss: 0.1495 - dense_4_loss: 0.0607 - dense_3_loss: 0.0888
# Epoch 981/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1498 - dense_4_loss: 0.0605 - dense_3_loss: 0.0892
# Epoch 00981: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 25ms/step - loss: 0.1497 - dense_4_loss: 0.0605 - dense_3_loss: 0.0892
# Epoch 982/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1511 - dense_4_loss: 0.0608 - dense_3_loss: 0.0904
# Epoch 00982: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1511 - dense_4_loss: 0.0608 - dense_3_loss: 0.0903
# Epoch 983/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1491 - dense_4_loss: 0.0602 - dense_3_loss: 0.0888
# Epoch 00983: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1490 - dense_4_loss: 0.0602 - dense_3_loss: 0.0888
# Epoch 984/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1505 - dense_4_loss: 0.0606 - dense_3_loss: 0.0899
# Epoch 00984: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1505 - dense_4_loss: 0.0606 - dense_3_loss: 0.0899
# Epoch 985/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1498 - dense_4_loss: 0.0607 - dense_3_loss: 0.0890
# Epoch 00985: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 25ms/step - loss: 0.1498 - dense_4_loss: 0.0607 - dense_3_loss: 0.0890
# Epoch 986/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1507 - dense_4_loss: 0.0612 - dense_3_loss: 0.0894
# Epoch 00986: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1509 - dense_4_loss: 0.0613 - dense_3_loss: 0.0896
# Epoch 987/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1504 - dense_4_loss: 0.0600 - dense_3_loss: 0.0903
# Epoch 00987: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1504 - dense_4_loss: 0.0601 - dense_3_loss: 0.0903
# Epoch 988/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1499 - dense_4_loss: 0.0609 - dense_3_loss: 0.0890
# Epoch 00988: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1499 - dense_4_loss: 0.0609 - dense_3_loss: 0.0890
# Epoch 989/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1491 - dense_4_loss: 0.0610 - dense_3_loss: 0.0881
# Epoch 00989: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1490 - dense_4_loss: 0.0610 - dense_3_loss: 0.0880
# Epoch 990/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1497 - dense_4_loss: 0.0608 - dense_3_loss: 0.0889
# Epoch 00990: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1497 - dense_4_loss: 0.0608 - dense_3_loss: 0.0889
# Epoch 991/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1498 - dense_4_loss: 0.0604 - dense_3_loss: 0.0894
# Epoch 00991: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 25ms/step - loss: 0.1497 - dense_4_loss: 0.0603 - dense_3_loss: 0.0894
# Epoch 992/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1504 - dense_4_loss: 0.0607 - dense_3_loss: 0.0897
# Epoch 00992: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1504 - dense_4_loss: 0.0607 - dense_3_loss: 0.0897
# Epoch 993/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1488 - dense_4_loss: 0.0610 - dense_3_loss: 0.0878
# Epoch 00993: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 25ms/step - loss: 0.1488 - dense_4_loss: 0.0610 - dense_3_loss: 0.0878
# Epoch 994/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1511 - dense_4_loss: 0.0614 - dense_3_loss: 0.0897
# Epoch 00994: loss did not improve from 0.14826
# 535/535 [==============================] - 14s 26ms/step - loss: 0.1511 - dense_4_loss: 0.0614 - dense_3_loss: 0.0897
# Epoch 995/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1498 - dense_4_loss: 0.0603 - dense_3_loss: 0.0894
# Epoch 00995: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1497 - dense_4_loss: 0.0603 - dense_3_loss: 0.0894
# Epoch 996/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1499 - dense_4_loss: 0.0604 - dense_3_loss: 0.0895
# Epoch 00996: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1499 - dense_4_loss: 0.0604 - dense_3_loss: 0.0895
# Epoch 997/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1496 - dense_4_loss: 0.0607 - dense_3_loss: 0.0889
# Epoch 00997: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1496 - dense_4_loss: 0.0607 - dense_3_loss: 0.0889
# Epoch 998/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1497 - dense_4_loss: 0.0615 - dense_3_loss: 0.0883
# Epoch 00998: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1497 - dense_4_loss: 0.0614 - dense_3_loss: 0.0882
# Epoch 999/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.1494 - dense_4_loss: 0.0605 - dense_3_loss: 0.0889
# Epoch 00999: loss did not improve from 0.14826
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1494 - dense_4_loss: 0.0605 - dense_3_loss: 0.0889
# Epoch 1000/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.1481 - dense_4_loss: 0.0600 - dense_3_loss: 0.0881
# Epoch 01000: loss improved from 0.14826 to 0.14810, saving model to ae.model
# 535/535 [==============================] - 13s 25ms/step - loss: 0.1481 - dense_4_loss: 0.0600 - dense_3_loss: 0.0881

# %%
mod=Model(inputs=model_mse.inputs,outputs=model_mse.layers[4].output)
mod.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 170)]        0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 270)          0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          138752      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      dense[0][0]
# ==================================================================================================
# Total params: 270,080
# Trainable params: 270,080
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pre=mod.predict((X[num],X[tot]))
pre.shape
# Out:
# (1097231, 256)

# %%
np.save('/content/gdrive/My Drive/fraud/with_id_withpoutV.npy',pre)

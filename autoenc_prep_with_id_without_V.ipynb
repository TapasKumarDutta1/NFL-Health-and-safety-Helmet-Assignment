# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/IEEE-CIS-Fraud/blob/master/autoenc_prep_with_id_without_V.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading Libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from keras.layers import *
from keras.optimizers import *
from keras.models import *
from keras import backend as K
import keras
import random
import tensorflow as tf
import keras.backend as K

from keras.models import Model
from keras.layers import Dense, Input, Dropout, BatchNormalization, Activation
from keras.utils.generic_utils import get_custom_objects
from keras.optimizers import Adam, Nadam
from keras.callbacks import Callback
from sklearn.metrics import roc_auc_score
from tqdm import tqdm
import gc

# %% [markdown]
# Loading data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Mounted at /content/gdrive

# %% [markdown]
# Load dataframe and drop Vs

# %%
trn=pd.read_csv('/content/gdrive/My Drive/fraud/train.csv')
tst=pd.read_csv('/content/gdrive/My Drive/fraud/test.csv')
trn=trn.drop(['isFraud'],trn=trn.drop(['Unnamed: 0'],1)
tst=tst.drop(['Unnamed: 0'],1)1)

# %%
trn=trn.drop(['Unnamed: 0'],1)
tst=tst.drop(['Unnamed: 0'],1)

# %% [markdown]
# Divide data as numerical and categorical and create grouped mean and std with numerical and drop id

# %%
dum=[str(i) for i in range(444)]
isna=list(trn.filter(regex='isna'))



tot=list(set(dum+isna))
num=[ i for i in list(trn) if i not in tot]

# %%
num.remove('id')
for col in tqdm(num):
  cols=[col+'_mean',col+'_std']
  trn[col+'_mean']=trn.groupby(['id'])[col].transform('mean')
  trn[col+'_std']=trn.groupby(['id'])[col].transform('std')
  
  tst[col+'_mean']=tst.groupby(['id'])[col].transform('mean')
  tst[col+'_std']=tst.groupby(['id'])[col].transform('std')
  for c in cols:
    if trn[c].skew()>1:
      trn[c]=np.log10(trn[c])
      tst[c]=np.log10(tst[c])
    mn=trn[c].mean()
    std=trn[c].std()
    trn[c]=(trn[c]-mn)/std
    tst[c]=(tst[c]-mn)/std 
trn=trn.drop(['id'],1)
tst=tst.drop(['id'],1)

num=[ i for i in list(trn) if i not in tot]
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
#   3%|▎         | 1/34 [00:01<00:54,  1.65s/it]
#   6%|▌         | 2/34 [00:03<00:54,  1.71s/it]
#   9%|▉         | 3/34 [00:05<00:55,  1.78s/it]
#  12%|█▏        | 4/34 [00:07<00:55,  1.84s/it]
#  15%|█▍        | 5/34 [00:09<00:53,  1.85s/it]
#  18%|█▊        | 6/34 [00:11<00:52,  1.86s/it]
#  21%|██        | 7/34 [00:13<00:50,  1.87s/it]
#  24%|██▎       | 8/34 [00:14<00:49,  1.89s/it]
#  26%|██▋       | 9/34 [00:16<00:47,  1.89s/it]
#  29%|██▉       | 10/34 [00:18<00:45,  1.89s/it]
#  32%|███▏      | 11/34 [00:20<00:43,  1.90s/it]
#  35%|███▌      | 12/34 [00:22<00:41,  1.91s/it]
#  38%|███▊      | 13/34 [00:24<00:39,  1.90s/it]
#  41%|████      | 14/34 [00:26<00:37,  1.90s/it]
#  44%|████▍     | 15/34 [00:28<00:36,  1.90s/it]
#  47%|████▋     | 16/34 [00:30<00:34,  1.91s/it]
#  50%|█████     | 17/34 [00:32<00:32,  1.93s/it]
#  53%|█████▎    | 18/34 [00:34<00:30,  1.93s/it]
#  56%|█████▌    | 19/34 [00:36<00:28,  1.92s/it]
#  59%|█████▉    | 20/34 [00:38<00:27,  1.95s/it]
#  62%|██████▏   | 21/34 [00:40<00:25,  1.99s/it]
#  65%|██████▍   | 22/34 [00:42<00:23,  1.97s/it]
#  68%|██████▊   | 23/34 [00:44<00:21,  1.99s/it]
#  71%|███████   | 24/34 [00:46<00:20,  2.02s/it]
#  74%|███████▎  | 25/34 [00:48<00:18,  2.04s/it]
#  76%|███████▋  | 26/34 [00:50<00:16,  2.04s/it]
#  79%|███████▉  | 27/34 [00:52<00:14,  2.06s/it]
#  82%|████████▏ | 28/34 [00:54<00:12,  2.06s/it]
#  85%|████████▌ | 29/34 [00:56<00:10,  2.08s/it]
#  88%|████████▊ | 30/34 [00:58<00:08,  2.10s/it]
#  91%|█████████ | 31/34 [01:00<00:06,  2.11s/it]
#  94%|█████████▍| 32/34 [01:02<00:04,  2.11s/it]
#  97%|█████████▋| 33/34 [01:05<00:02,  2.11s/it]
# 100%|██████████| 34/34 [01:07<00:00,  1.98s/it]

# %%
dum=[str(i) for i in range(444)]
isna=list(X.filter(regex='isna'))



tot=list(set(dum+isna))
num=[ i for i in list(X) if i not in tot]

# %% [markdown]
# Reduce memory used

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df
trn=reduce_mem_usage(trn)
tst=reduce_mem_usage(tst)
# Out:
# Memory usage of dataframe is 626.26 MB
# Memory usage after optimization is: 734.39 MB
# Decreased by -17.3%
# Memory usage of dataframe is 537.34 MB
# Memory usage after optimization is: 630.12 MB
# Decreased by -17.3%

# %%
np.random.seed(42) # NumPy
random.seed(42) # Python

# %%
def custom_gelu(x):
    return 0.5 * x * (1 + tf.tanh(tf.sqrt(2 / np.pi) * (x + 0.044715 * tf.pow(x, 3))))

# %% [markdown]
# Make the final dataset

# %%
X=pd.concat([trn,tst],0)
del([trn,tst])
gc.collect()
# Out:
# 2256

# %%
from tqdm import tqdm
X=X.replace([np.inf,-np.inf],np.nan)
a=X.isna().sum()
a=a[a>0]
cls=list(X)
for col in tqdm(list(a.index)):
  if col in cls:
    X[col]=X[col].fillna(X[col].mean())
a=X.isna().sum()
a=a[a>0]
for col in tqdm(list(a.index)):
    X[col]=X[col].fillna(0)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
#  41%|████      | 13/32 [00:00<00:00, 126.27it/s]
# 100%|██████████| 32/32 [00:00<00:00, 125.36it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#  47%|████▋     | 15/32 [00:00<00:00, 146.59it/s]
# 100%|██████████| 32/32 [00:00<00:00, 143.89it/s]

# %% [markdown]
# Scale the data

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
numerical=pd.DataFrame(ss.fit_transform(X[tot]))
numerical.columns=tot
categorical=pd.DataFrame(ss.fit_transform(X[num]))
categorical.columns=num
X=pd.concat([categorical,numerical],1)
X=reduce_mem_usage(X)
# Out:
# Memory usage of dataframe is 1822.83 MB
# Memory usage after optimization is: 1182.43 MB
# Decreased by 35.1%

# %% [markdown]
# Create warmup lr

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as K


class WarmUpLearningRateScheduler(keras.callbacks.Callback):
    """Warmup learning rate scheduler
    """

    def __init__(self, warmup_batches, init_lr, verbose=0):
        """Constructor for warmup learning rate scheduler

        Arguments:
            warmup_batches {int} -- Number of batch for warmup.
            init_lr {float} -- Learning rate after warmup.

        Keyword Arguments:
            verbose {int} -- 0: quiet, 1: update messages. (default: {0})
        """

        super(WarmUpLearningRateScheduler, self).__init__()
        self.warmup_batches = warmup_batches
        self.init_lr = init_lr
        self.verbose = verbose
        self.batch_count = 0
        self.learning_rates = []

    def on_batch_end(self, batch, logs=None):
        self.batch_count = self.batch_count + 1
        lr = K.get_value(self.model.optimizer.lr)
        self.learning_rates.append(lr)

    def on_batch_begin(self, batch, logs=None):
        if self.batch_count <= self.warmup_batches:
            lr = self.batch_count*self.init_lr/self.warmup_batches
            K.set_value(self.model.optimizer.lr, lr)
            if self.verbose > 0:
                print('\nBatch %05d: WarmUpLearningRateScheduler setting learning '
                      'rate to %s.' % (self.batch_count + 1, lr))
warm_up_lr = WarmUpLearningRateScheduler(400, init_lr=0.005)

# %% [markdown]
# Create data generator

# %%
from keras.utils import Sequence
class DAESequence(Sequence):
    def __init__(self,df,no_dum,frac=0.15,dumm=range(911),batch_size=2048):
        self.batch_size=batch_size
        self.frac=0.15
        self.dumm=dumm
        self.df=df
        self.cat_data=df[dumm].values
        self.num_data=df[no_dum].values
        self.no_dumm=no_dum
        self.len_data=df.shape[0]
        self.columns=df.shape[1]
        self.data=df
        self.idx=[]
        
        
        
    def __len__(self):
        return int(ceil(self.len_data/self.batch_size))
    
    
    
    def __getitem__(self,idx):
        self.idx.append(idx)
        last=min((idx+1)*self.batch_size,self.len_data)
        idx=idx*self.batch_size
        size=last-idx
        
        
        inps=[]
        outs=[]
        output_x=self.data.iloc[idx:last]
        
        
        
        
        data=output_x[self.no_dumm].values
        noise_x=data.copy()
        for i in range(len(self.no_dumm)):
            to=np.random.randint(0,size,int(size*self.frac))
            frm=np.random.randint(0,size,int(size*self.frac))
            noise_x[to,i]=noise_x[frm,i]
            
        inps.append(noise_x)
        outs.append(data)
        
        data=output_x[self.dumm].values
        noise_x=data.copy()
        for i in range(len(self.dumm)):
            to=np.random.randint(0,size,int(size*self.frac))
            frm=np.random.randint(0,size,int(size*self.frac))
            noise_x[to,i]=noise_x[frm,i]
        
        
        
        inps.append(noise_x)
        outs.append(data)
        
        
        
        
        
        return inps,outs

# %% [markdown]
# Fill the std columns and drop columns having nan mean

# %% [markdown]
# Create model

# %%
from keras.layers import concatenate
from keras.optimizers import Adam
def create_model():
    K.clear_session()
    num_inp = Input(shape=(num_shape,))
    cat_inp = Input(shape=(cat_shape,))
    inps = concatenate([num_inp, cat_inp])
    x = Dense(512, activation=custom_gelu)(inps)
    a = Dense(256, activation=custom_gelu)(x)
    b = Dense(512, activation = custom_gelu)(a)
    x = Dropout(.2)(b)
    cat_out = Dense(cat_shape, activation = "linear")(x)
    num_out = Dense(num_shape, activation = "linear")(x)
    model = Model(inputs=[num_inp,cat_inp], outputs=[num_out, cat_out])
    model.compile(
        optimizer=Adam(.05, clipnorm = 1, clipvalue = 1),
        loss=["mse", "mse"]
    )
    return model

# %%
len(num),len(tot),X.shape
# Out:
# (102, 463, (1097231, 565))

# %% [markdown]
# Fitting the model

# %%
num=[ i for i in list(X) if i not in tot]
batch_size=2048
auto_ckpt = ModelCheckpoint("ae.model", monitor='loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min', period=1)
warm_up_lr = WarmUpLearningRateScheduler(400, init_lr=0.0003)
num_shape=len(num)
cat_shape=len(tot)
model_mse = create_model()
from math import *
gc.collect()
epochs = 1000
batch_size=2048
train_gen=DAESequence(X,num,batch_size=batch_size,dumm=tot)
hist = model_mse.fit_generator(train_gen, steps_per_epoch=len(X)//batch_size, epochs=epochs,
                           verbose=1, workers=-1,
                           use_multiprocessing=True,
                              callbacks=[auto_ckpt, warm_up_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/1000
# 535/535 [==============================] - ETA: 0s - loss: 1.3079 - dense_4_loss: 0.4192 - dense_3_loss: 0.8888
# Epoch 00001: loss improved from inf to 1.30795, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 1.3079 - dense_4_loss: 0.4192 - dense_3_loss: 0.8888
# Epoch 2/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.8264 - dense_4_loss: 0.2030 - dense_3_loss: 0.6233
# Epoch 00002: loss improved from 1.30795 to 0.82597, saving model to ae.model
# 535/535 [==============================] - 24s 46ms/step - loss: 0.8260 - dense_4_loss: 0.2030 - dense_3_loss: 0.6230
# Epoch 3/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.7253 - dense_4_loss: 0.1891 - dense_3_loss: 0.5363
# Epoch 00003: loss improved from 0.82597 to 0.72534, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.7253 - dense_4_loss: 0.1891 - dense_3_loss: 0.5363
# Epoch 4/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.6824 - dense_4_loss: 0.1854 - dense_3_loss: 0.4970
# Epoch 00004: loss improved from 0.72534 to 0.68208, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.6821 - dense_4_loss: 0.1853 - dense_3_loss: 0.4968
# Epoch 5/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.6546 - dense_4_loss: 0.1811 - dense_3_loss: 0.4736
# Epoch 00005: loss improved from 0.68208 to 0.65443, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.6544 - dense_4_loss: 0.1810 - dense_3_loss: 0.4735
# Epoch 6/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.6428 - dense_4_loss: 0.1829 - dense_3_loss: 0.4600
# Epoch 00006: loss improved from 0.65443 to 0.64319, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.6432 - dense_4_loss: 0.1829 - dense_3_loss: 0.4603
# Epoch 7/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.6226 - dense_4_loss: 0.1757 - dense_3_loss: 0.4469
# Epoch 00007: loss improved from 0.64319 to 0.62366, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.6237 - dense_4_loss: 0.1757 - dense_3_loss: 0.4480
# Epoch 8/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.6277 - dense_4_loss: 0.1844 - dense_3_loss: 0.4433
# Epoch 00008: loss did not improve from 0.62366
# 535/535 [==============================] - 24s 44ms/step - loss: 0.6277 - dense_4_loss: 0.1844 - dense_3_loss: 0.4433
# Epoch 9/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.6090 - dense_4_loss: 0.1747 - dense_3_loss: 0.4342
# Epoch 00009: loss improved from 0.62366 to 0.60872, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.6087 - dense_4_loss: 0.1747 - dense_3_loss: 0.4340
# Epoch 10/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.6076 - dense_4_loss: 0.1774 - dense_3_loss: 0.4303
# Epoch 00010: loss improved from 0.60872 to 0.60731, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.6073 - dense_4_loss: 0.1773 - dense_3_loss: 0.4300
# Epoch 11/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5974 - dense_4_loss: 0.1726 - dense_3_loss: 0.4248
# Epoch 00011: loss improved from 0.60731 to 0.59740, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5974 - dense_4_loss: 0.1726 - dense_3_loss: 0.4248
# Epoch 12/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5899 - dense_4_loss: 0.1700 - dense_3_loss: 0.4200
# Epoch 00012: loss improved from 0.59740 to 0.58994, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5899 - dense_4_loss: 0.1700 - dense_3_loss: 0.4200
# Epoch 13/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5835 - dense_4_loss: 0.1665 - dense_3_loss: 0.4170
# Epoch 00013: loss improved from 0.58994 to 0.58345, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5835 - dense_4_loss: 0.1665 - dense_3_loss: 0.4170
# Epoch 14/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5769 - dense_4_loss: 0.1636 - dense_3_loss: 0.4134
# Epoch 00014: loss improved from 0.58345 to 0.57746, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5775 - dense_4_loss: 0.1636 - dense_3_loss: 0.4138
# Epoch 15/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5805 - dense_4_loss: 0.1682 - dense_3_loss: 0.4123
# Epoch 00015: loss did not improve from 0.57746
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5806 - dense_4_loss: 0.1682 - dense_3_loss: 0.4124
# Epoch 16/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5731 - dense_4_loss: 0.1650 - dense_3_loss: 0.4081
# Epoch 00016: loss improved from 0.57746 to 0.57277, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5728 - dense_4_loss: 0.1649 - dense_3_loss: 0.4078
# Epoch 17/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5704 - dense_4_loss: 0.1645 - dense_3_loss: 0.4059
# Epoch 00017: loss improved from 0.57277 to 0.57054, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5705 - dense_4_loss: 0.1646 - dense_3_loss: 0.4059
# Epoch 18/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5637 - dense_4_loss: 0.1634 - dense_3_loss: 0.4003
# Epoch 00018: loss improved from 0.57054 to 0.56366, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5637 - dense_4_loss: 0.1634 - dense_3_loss: 0.4003
# Epoch 19/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5622 - dense_4_loss: 0.1615 - dense_3_loss: 0.4007
# Epoch 00019: loss improved from 0.56366 to 0.56219, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5622 - dense_4_loss: 0.1615 - dense_3_loss: 0.4007
# Epoch 20/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5559 - dense_4_loss: 0.1589 - dense_3_loss: 0.3970
# Epoch 00020: loss improved from 0.56219 to 0.55575, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5558 - dense_4_loss: 0.1588 - dense_3_loss: 0.3969
# Epoch 21/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5557 - dense_4_loss: 0.1612 - dense_3_loss: 0.3944
# Epoch 00021: loss improved from 0.55575 to 0.55567, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5557 - dense_4_loss: 0.1612 - dense_3_loss: 0.3944
# Epoch 22/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5542 - dense_4_loss: 0.1574 - dense_3_loss: 0.3968
# Epoch 00022: loss improved from 0.55567 to 0.55422, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5542 - dense_4_loss: 0.1574 - dense_3_loss: 0.3968
# Epoch 23/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5532 - dense_4_loss: 0.1622 - dense_3_loss: 0.3910
# Epoch 00023: loss improved from 0.55422 to 0.55319, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5532 - dense_4_loss: 0.1622 - dense_3_loss: 0.3910
# Epoch 24/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5523 - dense_4_loss: 0.1617 - dense_3_loss: 0.3906
# Epoch 00024: loss improved from 0.55319 to 0.55234, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5523 - dense_4_loss: 0.1617 - dense_3_loss: 0.3906
# Epoch 25/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5488 - dense_4_loss: 0.1613 - dense_3_loss: 0.3874
# Epoch 00025: loss improved from 0.55234 to 0.54878, saving model to ae.model
# 535/535 [==============================] - 23s 44ms/step - loss: 0.5488 - dense_4_loss: 0.1613 - dense_3_loss: 0.3874
# Epoch 26/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5417 - dense_4_loss: 0.1541 - dense_3_loss: 0.3876
# Epoch 00026: loss improved from 0.54878 to 0.54172, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5417 - dense_4_loss: 0.1541 - dense_3_loss: 0.3876
# Epoch 27/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5451 - dense_4_loss: 0.1572 - dense_3_loss: 0.3878
# Epoch 00027: loss did not improve from 0.54172
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5451 - dense_4_loss: 0.1572 - dense_3_loss: 0.3878
# Epoch 28/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5420 - dense_4_loss: 0.1567 - dense_3_loss: 0.3854
# Epoch 00028: loss did not improve from 0.54172
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5420 - dense_4_loss: 0.1567 - dense_3_loss: 0.3854
# Epoch 29/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5380 - dense_4_loss: 0.1544 - dense_3_loss: 0.3836
# Epoch 00029: loss improved from 0.54172 to 0.53782, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5378 - dense_4_loss: 0.1544 - dense_3_loss: 0.3835
# Epoch 30/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5314 - dense_4_loss: 0.1523 - dense_3_loss: 0.3792
# Epoch 00030: loss improved from 0.53782 to 0.53144, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5314 - dense_4_loss: 0.1523 - dense_3_loss: 0.3792
# Epoch 31/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5362 - dense_4_loss: 0.1559 - dense_3_loss: 0.3804
# Epoch 00031: loss did not improve from 0.53144
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5362 - dense_4_loss: 0.1559 - dense_3_loss: 0.3804
# Epoch 32/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5309 - dense_4_loss: 0.1529 - dense_3_loss: 0.3779
# Epoch 00032: loss did not improve from 0.53144
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5316 - dense_4_loss: 0.1529 - dense_3_loss: 0.3787
# Epoch 33/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5329 - dense_4_loss: 0.1515 - dense_3_loss: 0.3814
# Epoch 00033: loss did not improve from 0.53144
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5327 - dense_4_loss: 0.1515 - dense_3_loss: 0.3813
# Epoch 34/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5320 - dense_4_loss: 0.1532 - dense_3_loss: 0.3788
# Epoch 00034: loss did not improve from 0.53144
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5320 - dense_4_loss: 0.1532 - dense_3_loss: 0.3788
# Epoch 35/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5318 - dense_4_loss: 0.1559 - dense_3_loss: 0.3759
# Epoch 00035: loss did not improve from 0.53144
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5316 - dense_4_loss: 0.1558 - dense_3_loss: 0.3757
# Epoch 36/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5234 - dense_4_loss: 0.1490 - dense_3_loss: 0.3744
# Epoch 00036: loss improved from 0.53144 to 0.52341, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5234 - dense_4_loss: 0.1490 - dense_3_loss: 0.3744
# Epoch 37/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5355 - dense_4_loss: 0.1580 - dense_3_loss: 0.3775
# Epoch 00037: loss did not improve from 0.52341
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5355 - dense_4_loss: 0.1580 - dense_3_loss: 0.3775
# Epoch 38/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5206 - dense_4_loss: 0.1501 - dense_3_loss: 0.3705
# Epoch 00038: loss improved from 0.52341 to 0.52060, saving model to ae.model
# 535/535 [==============================] - 23s 44ms/step - loss: 0.5206 - dense_4_loss: 0.1501 - dense_3_loss: 0.3705
# Epoch 39/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5202 - dense_4_loss: 0.1475 - dense_3_loss: 0.3728
# Epoch 00039: loss improved from 0.52060 to 0.52025, saving model to ae.model
# 535/535 [==============================] - 23s 44ms/step - loss: 0.5202 - dense_4_loss: 0.1475 - dense_3_loss: 0.3728
# Epoch 40/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5226 - dense_4_loss: 0.1513 - dense_3_loss: 0.3713
# Epoch 00040: loss did not improve from 0.52025
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5223 - dense_4_loss: 0.1512 - dense_3_loss: 0.3711
# Epoch 41/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5187 - dense_4_loss: 0.1492 - dense_3_loss: 0.3695
# Epoch 00041: loss improved from 0.52025 to 0.51849, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5185 - dense_4_loss: 0.1492 - dense_3_loss: 0.3693
# Epoch 42/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5233 - dense_4_loss: 0.1566 - dense_3_loss: 0.3667
# Epoch 00042: loss did not improve from 0.51849
# 535/535 [==============================] - 23s 44ms/step - loss: 0.5233 - dense_4_loss: 0.1566 - dense_3_loss: 0.3667
# Epoch 43/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5212 - dense_4_loss: 0.1535 - dense_3_loss: 0.3678
# Epoch 00043: loss did not improve from 0.51849
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5212 - dense_4_loss: 0.1535 - dense_3_loss: 0.3678
# Epoch 44/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5154 - dense_4_loss: 0.1498 - dense_3_loss: 0.3656
# Epoch 00044: loss improved from 0.51849 to 0.51543, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5154 - dense_4_loss: 0.1498 - dense_3_loss: 0.3656
# Epoch 45/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5142 - dense_4_loss: 0.1462 - dense_3_loss: 0.3680
# Epoch 00045: loss improved from 0.51543 to 0.51423, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5142 - dense_4_loss: 0.1462 - dense_3_loss: 0.3680
# Epoch 46/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5080 - dense_4_loss: 0.1451 - dense_3_loss: 0.3629
# Epoch 00046: loss improved from 0.51423 to 0.50846, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5085 - dense_4_loss: 0.1451 - dense_3_loss: 0.3633
# Epoch 47/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5079 - dense_4_loss: 0.1430 - dense_3_loss: 0.3648
# Epoch 00047: loss improved from 0.50846 to 0.50819, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5082 - dense_4_loss: 0.1432 - dense_3_loss: 0.3650
# Epoch 48/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5077 - dense_4_loss: 0.1451 - dense_3_loss: 0.3626
# Epoch 00048: loss improved from 0.50819 to 0.50753, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5075 - dense_4_loss: 0.1451 - dense_3_loss: 0.3624
# Epoch 49/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5088 - dense_4_loss: 0.1448 - dense_3_loss: 0.3640
# Epoch 00049: loss did not improve from 0.50753
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5086 - dense_4_loss: 0.1448 - dense_3_loss: 0.3639
# Epoch 50/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5078 - dense_4_loss: 0.1440 - dense_3_loss: 0.3638
# Epoch 00050: loss did not improve from 0.50753
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5078 - dense_4_loss: 0.1440 - dense_3_loss: 0.3638
# Epoch 51/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5111 - dense_4_loss: 0.1463 - dense_3_loss: 0.3648
# Epoch 00051: loss did not improve from 0.50753
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5111 - dense_4_loss: 0.1463 - dense_3_loss: 0.3648
# Epoch 52/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5108 - dense_4_loss: 0.1475 - dense_3_loss: 0.3633
# Epoch 00052: loss did not improve from 0.50753
# 535/535 [==============================] - 23s 44ms/step - loss: 0.5108 - dense_4_loss: 0.1475 - dense_3_loss: 0.3633
# Epoch 53/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5110 - dense_4_loss: 0.1461 - dense_3_loss: 0.3649
# Epoch 00053: loss did not improve from 0.50753
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5109 - dense_4_loss: 0.1461 - dense_3_loss: 0.3648
# Epoch 54/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5081 - dense_4_loss: 0.1488 - dense_3_loss: 0.3594
# Epoch 00054: loss did not improve from 0.50753
# 535/535 [==============================] - 24s 46ms/step - loss: 0.5079 - dense_4_loss: 0.1487 - dense_3_loss: 0.3592
# Epoch 55/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5014 - dense_4_loss: 0.1428 - dense_3_loss: 0.3585
# Epoch 00055: loss improved from 0.50753 to 0.50137, saving model to ae.model
# 535/535 [==============================] - 24s 46ms/step - loss: 0.5014 - dense_4_loss: 0.1428 - dense_3_loss: 0.3585
# Epoch 56/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5047 - dense_4_loss: 0.1461 - dense_3_loss: 0.3586
# Epoch 00056: loss did not improve from 0.50137
# 535/535 [==============================] - 25s 46ms/step - loss: 0.5047 - dense_4_loss: 0.1461 - dense_3_loss: 0.3586
# Epoch 57/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5080 - dense_4_loss: 0.1521 - dense_3_loss: 0.3559
# Epoch 00057: loss did not improve from 0.50137
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5078 - dense_4_loss: 0.1520 - dense_3_loss: 0.3558
# Epoch 58/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5054 - dense_4_loss: 0.1480 - dense_3_loss: 0.3574
# Epoch 00058: loss did not improve from 0.50137
# 535/535 [==============================] - 24s 45ms/step - loss: 0.5051 - dense_4_loss: 0.1479 - dense_3_loss: 0.3573
# Epoch 59/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.5022 - dense_4_loss: 0.1467 - dense_3_loss: 0.3554
# Epoch 00059: loss did not improve from 0.50137
# 535/535 [==============================] - 23s 44ms/step - loss: 0.5022 - dense_4_loss: 0.1467 - dense_3_loss: 0.3554
# Epoch 60/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5080 - dense_4_loss: 0.1474 - dense_3_loss: 0.3606
# Epoch 00060: loss did not improve from 0.50137
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5078 - dense_4_loss: 0.1474 - dense_3_loss: 0.3604
# Epoch 61/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.5042 - dense_4_loss: 0.1476 - dense_3_loss: 0.3566
# Epoch 00061: loss did not improve from 0.50137
# 535/535 [==============================] - 24s 44ms/step - loss: 0.5044 - dense_4_loss: 0.1476 - dense_3_loss: 0.3568
# Epoch 62/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4970 - dense_4_loss: 0.1443 - dense_3_loss: 0.3527
# Epoch 00062: loss improved from 0.50137 to 0.49697, saving model to ae.model
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4970 - dense_4_loss: 0.1443 - dense_3_loss: 0.3527
# Epoch 63/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4977 - dense_4_loss: 0.1430 - dense_3_loss: 0.3547
# Epoch 00063: loss did not improve from 0.49697
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4976 - dense_4_loss: 0.1430 - dense_3_loss: 0.3546
# Epoch 64/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4994 - dense_4_loss: 0.1467 - dense_3_loss: 0.3527
# Epoch 00064: loss did not improve from 0.49697
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4994 - dense_4_loss: 0.1467 - dense_3_loss: 0.3527
# Epoch 65/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4990 - dense_4_loss: 0.1471 - dense_3_loss: 0.3519
# Epoch 00065: loss did not improve from 0.49697
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4990 - dense_4_loss: 0.1471 - dense_3_loss: 0.3519
# Epoch 66/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4958 - dense_4_loss: 0.1408 - dense_3_loss: 0.3550
# Epoch 00066: loss improved from 0.49697 to 0.49576, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4958 - dense_4_loss: 0.1408 - dense_3_loss: 0.3550
# Epoch 67/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4971 - dense_4_loss: 0.1457 - dense_3_loss: 0.3515
# Epoch 00067: loss did not improve from 0.49576
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4969 - dense_4_loss: 0.1456 - dense_3_loss: 0.3513
# Epoch 68/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4968 - dense_4_loss: 0.1417 - dense_3_loss: 0.3551
# Epoch 00068: loss did not improve from 0.49576
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4968 - dense_4_loss: 0.1417 - dense_3_loss: 0.3551
# Epoch 69/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4900 - dense_4_loss: 0.1413 - dense_3_loss: 0.3487
# Epoch 00069: loss improved from 0.49576 to 0.49018, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4902 - dense_4_loss: 0.1414 - dense_3_loss: 0.3488
# Epoch 70/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4882 - dense_4_loss: 0.1410 - dense_3_loss: 0.3472
# Epoch 00070: loss improved from 0.49018 to 0.48819, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4882 - dense_4_loss: 0.1410 - dense_3_loss: 0.3472
# Epoch 71/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4830 - dense_4_loss: 0.1354 - dense_3_loss: 0.3476
# Epoch 00071: loss did not improve from 0.48819
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4911 - dense_4_loss: 0.1428 - dense_3_loss: 0.3484
# Epoch 72/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4923 - dense_4_loss: 0.1450 - dense_3_loss: 0.3474
# Epoch 00072: loss did not improve from 0.48819
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4922 - dense_4_loss: 0.1449 - dense_3_loss: 0.3473
# Epoch 73/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4933 - dense_4_loss: 0.1451 - dense_3_loss: 0.3482
# Epoch 00073: loss did not improve from 0.48819
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4933 - dense_4_loss: 0.1451 - dense_3_loss: 0.3482
# Epoch 74/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4911 - dense_4_loss: 0.1410 - dense_3_loss: 0.3501
# Epoch 00074: loss did not improve from 0.48819
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4910 - dense_4_loss: 0.1410 - dense_3_loss: 0.3500
# Epoch 75/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4969 - dense_4_loss: 0.1478 - dense_3_loss: 0.3491
# Epoch 00075: loss did not improve from 0.48819
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4968 - dense_4_loss: 0.1478 - dense_3_loss: 0.3490
# Epoch 76/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4889 - dense_4_loss: 0.1420 - dense_3_loss: 0.3470
# Epoch 00076: loss did not improve from 0.48819
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4889 - dense_4_loss: 0.1420 - dense_3_loss: 0.3470
# Epoch 77/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4873 - dense_4_loss: 0.1425 - dense_3_loss: 0.3448
# Epoch 00077: loss improved from 0.48819 to 0.48711, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4871 - dense_4_loss: 0.1425 - dense_3_loss: 0.3446
# Epoch 78/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4874 - dense_4_loss: 0.1379 - dense_3_loss: 0.3495
# Epoch 00078: loss did not improve from 0.48711
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4873 - dense_4_loss: 0.1379 - dense_3_loss: 0.3494
# Epoch 79/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4845 - dense_4_loss: 0.1379 - dense_3_loss: 0.3466
# Epoch 00079: loss improved from 0.48711 to 0.48448, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4845 - dense_4_loss: 0.1379 - dense_3_loss: 0.3466
# Epoch 80/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4850 - dense_4_loss: 0.1376 - dense_3_loss: 0.3474
# Epoch 00080: loss did not improve from 0.48448
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4851 - dense_4_loss: 0.1375 - dense_3_loss: 0.3475
# Epoch 81/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4872 - dense_4_loss: 0.1396 - dense_3_loss: 0.3476
# Epoch 00081: loss did not improve from 0.48448
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4872 - dense_4_loss: 0.1396 - dense_3_loss: 0.3476
# Epoch 82/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4933 - dense_4_loss: 0.1452 - dense_3_loss: 0.3481
# Epoch 00082: loss did not improve from 0.48448
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4933 - dense_4_loss: 0.1452 - dense_3_loss: 0.3481
# Epoch 83/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4861 - dense_4_loss: 0.1411 - dense_3_loss: 0.3450
# Epoch 00083: loss did not improve from 0.48448
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4861 - dense_4_loss: 0.1411 - dense_3_loss: 0.3450
# Epoch 84/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4846 - dense_4_loss: 0.1415 - dense_3_loss: 0.3431
# Epoch 00084: loss did not improve from 0.48448
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4846 - dense_4_loss: 0.1415 - dense_3_loss: 0.3431
# Epoch 85/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4808 - dense_4_loss: 0.1388 - dense_3_loss: 0.3420
# Epoch 00085: loss improved from 0.48448 to 0.48089, saving model to ae.model
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4809 - dense_4_loss: 0.1388 - dense_3_loss: 0.3421
# Epoch 86/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4791 - dense_4_loss: 0.1381 - dense_3_loss: 0.3410
# Epoch 00086: loss improved from 0.48089 to 0.47893, saving model to ae.model
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4789 - dense_4_loss: 0.1381 - dense_3_loss: 0.3409
# Epoch 87/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4846 - dense_4_loss: 0.1387 - dense_3_loss: 0.3459
# Epoch 00087: loss did not improve from 0.47893
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4846 - dense_4_loss: 0.1387 - dense_3_loss: 0.3459
# Epoch 88/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4913 - dense_4_loss: 0.1468 - dense_3_loss: 0.3445
# Epoch 00088: loss did not improve from 0.47893
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4913 - dense_4_loss: 0.1468 - dense_3_loss: 0.3445
# Epoch 89/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4826 - dense_4_loss: 0.1400 - dense_3_loss: 0.3427
# Epoch 00089: loss did not improve from 0.47893
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4826 - dense_4_loss: 0.1400 - dense_3_loss: 0.3427
# Epoch 90/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4757 - dense_4_loss: 0.1354 - dense_3_loss: 0.3403
# Epoch 00090: loss improved from 0.47893 to 0.47571, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4757 - dense_4_loss: 0.1354 - dense_3_loss: 0.3403
# Epoch 91/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4888 - dense_4_loss: 0.1387 - dense_3_loss: 0.3500
# Epoch 00091: loss did not improve from 0.47571
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4888 - dense_4_loss: 0.1387 - dense_3_loss: 0.3500
# Epoch 92/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4833 - dense_4_loss: 0.1387 - dense_3_loss: 0.3447
# Epoch 00092: loss did not improve from 0.47571
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4833 - dense_4_loss: 0.1387 - dense_3_loss: 0.3447
# Epoch 93/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4823 - dense_4_loss: 0.1425 - dense_3_loss: 0.3399
# Epoch 00093: loss did not improve from 0.47571
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4823 - dense_4_loss: 0.1425 - dense_3_loss: 0.3398
# Epoch 94/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4792 - dense_4_loss: 0.1387 - dense_3_loss: 0.3405
# Epoch 00094: loss did not improve from 0.47571
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4792 - dense_4_loss: 0.1387 - dense_3_loss: 0.3405
# Epoch 95/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4812 - dense_4_loss: 0.1370 - dense_3_loss: 0.3442
# Epoch 00095: loss did not improve from 0.47571
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4812 - dense_4_loss: 0.1370 - dense_3_loss: 0.3442
# Epoch 96/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4800 - dense_4_loss: 0.1413 - dense_3_loss: 0.3388
# Epoch 00096: loss did not improve from 0.47571
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4800 - dense_4_loss: 0.1413 - dense_3_loss: 0.3388
# Epoch 97/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4744 - dense_4_loss: 0.1343 - dense_3_loss: 0.3402
# Epoch 00097: loss improved from 0.47571 to 0.47442, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4744 - dense_4_loss: 0.1343 - dense_3_loss: 0.3402
# Epoch 98/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4738 - dense_4_loss: 0.1334 - dense_3_loss: 0.3403
# Epoch 00098: loss improved from 0.47442 to 0.47415, saving model to ae.model
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4742 - dense_4_loss: 0.1334 - dense_3_loss: 0.3407
# Epoch 99/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4835 - dense_4_loss: 0.1407 - dense_3_loss: 0.3428
# Epoch 00099: loss did not improve from 0.47415
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4835 - dense_4_loss: 0.1407 - dense_3_loss: 0.3428
# Epoch 100/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4787 - dense_4_loss: 0.1407 - dense_3_loss: 0.3380
# Epoch 00100: loss did not improve from 0.47415
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4784 - dense_4_loss: 0.1406 - dense_3_loss: 0.3378
# Epoch 101/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4740 - dense_4_loss: 0.1355 - dense_3_loss: 0.3385
# Epoch 00101: loss did not improve from 0.47415
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4744 - dense_4_loss: 0.1355 - dense_3_loss: 0.3388
# Epoch 102/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4782 - dense_4_loss: 0.1405 - dense_3_loss: 0.3376
# Epoch 00102: loss did not improve from 0.47415
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4783 - dense_4_loss: 0.1407 - dense_3_loss: 0.3376
# Epoch 103/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4731 - dense_4_loss: 0.1352 - dense_3_loss: 0.3379
# Epoch 00103: loss improved from 0.47415 to 0.47355, saving model to ae.model
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4735 - dense_4_loss: 0.1351 - dense_3_loss: 0.3384
# Epoch 104/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4707 - dense_4_loss: 0.1319 - dense_3_loss: 0.3388
# Epoch 00104: loss improved from 0.47355 to 0.47072, saving model to ae.model
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4707 - dense_4_loss: 0.1319 - dense_3_loss: 0.3388
# Epoch 105/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4779 - dense_4_loss: 0.1405 - dense_3_loss: 0.3374
# Epoch 00105: loss did not improve from 0.47072
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4779 - dense_4_loss: 0.1405 - dense_3_loss: 0.3374
# Epoch 106/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4746 - dense_4_loss: 0.1387 - dense_3_loss: 0.3359
# Epoch 00106: loss did not improve from 0.47072
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4746 - dense_4_loss: 0.1387 - dense_3_loss: 0.3359
# Epoch 107/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4778 - dense_4_loss: 0.1377 - dense_3_loss: 0.3401
# Epoch 00107: loss did not improve from 0.47072
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4777 - dense_4_loss: 0.1377 - dense_3_loss: 0.3400
# Epoch 108/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4685 - dense_4_loss: 0.1349 - dense_3_loss: 0.3336
# Epoch 00108: loss improved from 0.47072 to 0.46843, saving model to ae.model
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4684 - dense_4_loss: 0.1349 - dense_3_loss: 0.3335
# Epoch 109/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4704 - dense_4_loss: 0.1345 - dense_3_loss: 0.3359
# Epoch 00109: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4704 - dense_4_loss: 0.1345 - dense_3_loss: 0.3359
# Epoch 110/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4786 - dense_4_loss: 0.1409 - dense_3_loss: 0.3377
# Epoch 00110: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4786 - dense_4_loss: 0.1409 - dense_3_loss: 0.3377
# Epoch 111/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4747 - dense_4_loss: 0.1362 - dense_3_loss: 0.3385
# Epoch 00111: loss did not improve from 0.46843
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4745 - dense_4_loss: 0.1361 - dense_3_loss: 0.3384
# Epoch 112/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4709 - dense_4_loss: 0.1363 - dense_3_loss: 0.3346
# Epoch 00112: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4709 - dense_4_loss: 0.1363 - dense_3_loss: 0.3346
# Epoch 113/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4737 - dense_4_loss: 0.1371 - dense_3_loss: 0.3366
# Epoch 00113: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4737 - dense_4_loss: 0.1372 - dense_3_loss: 0.3366
# Epoch 114/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4733 - dense_4_loss: 0.1325 - dense_3_loss: 0.3408
# Epoch 00114: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4733 - dense_4_loss: 0.1325 - dense_3_loss: 0.3408
# Epoch 115/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4726 - dense_4_loss: 0.1376 - dense_3_loss: 0.3350
# Epoch 00115: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4726 - dense_4_loss: 0.1376 - dense_3_loss: 0.3350
# Epoch 116/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4699 - dense_4_loss: 0.1345 - dense_3_loss: 0.3354
# Epoch 00116: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4699 - dense_4_loss: 0.1345 - dense_3_loss: 0.3354
# Epoch 117/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4747 - dense_4_loss: 0.1381 - dense_3_loss: 0.3366
# Epoch 00117: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4747 - dense_4_loss: 0.1381 - dense_3_loss: 0.3366
# Epoch 118/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4753 - dense_4_loss: 0.1388 - dense_3_loss: 0.3365
# Epoch 00118: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4752 - dense_4_loss: 0.1388 - dense_3_loss: 0.3364
# Epoch 119/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4729 - dense_4_loss: 0.1374 - dense_3_loss: 0.3356
# Epoch 00119: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4729 - dense_4_loss: 0.1374 - dense_3_loss: 0.3356
# Epoch 120/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4747 - dense_4_loss: 0.1396 - dense_3_loss: 0.3351
# Epoch 00120: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4747 - dense_4_loss: 0.1396 - dense_3_loss: 0.3351
# Epoch 121/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4755 - dense_4_loss: 0.1426 - dense_3_loss: 0.3329
# Epoch 00121: loss did not improve from 0.46843
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4755 - dense_4_loss: 0.1426 - dense_3_loss: 0.3329
# Epoch 122/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4616 - dense_4_loss: 0.1326 - dense_3_loss: 0.3290
# Epoch 00122: loss improved from 0.46843 to 0.46138, saving model to ae.model
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4614 - dense_4_loss: 0.1326 - dense_3_loss: 0.3288
# Epoch 123/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4733 - dense_4_loss: 0.1389 - dense_3_loss: 0.3344
# Epoch 00123: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4731 - dense_4_loss: 0.1388 - dense_3_loss: 0.3342
# Epoch 124/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4701 - dense_4_loss: 0.1386 - dense_3_loss: 0.3315
# Epoch 00124: loss did not improve from 0.46138
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4701 - dense_4_loss: 0.1386 - dense_3_loss: 0.3315
# Epoch 125/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4704 - dense_4_loss: 0.1372 - dense_3_loss: 0.3332
# Epoch 00125: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4704 - dense_4_loss: 0.1372 - dense_3_loss: 0.3332
# Epoch 126/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4631 - dense_4_loss: 0.1322 - dense_3_loss: 0.3308
# Epoch 00126: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4631 - dense_4_loss: 0.1322 - dense_3_loss: 0.3308
# Epoch 127/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4652 - dense_4_loss: 0.1354 - dense_3_loss: 0.3298
# Epoch 00127: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4651 - dense_4_loss: 0.1353 - dense_3_loss: 0.3298
# Epoch 128/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4691 - dense_4_loss: 0.1381 - dense_3_loss: 0.3310
# Epoch 00128: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4691 - dense_4_loss: 0.1381 - dense_3_loss: 0.3309
# Epoch 129/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4663 - dense_4_loss: 0.1351 - dense_3_loss: 0.3312
# Epoch 00129: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4663 - dense_4_loss: 0.1351 - dense_3_loss: 0.3313
# Epoch 130/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4661 - dense_4_loss: 0.1321 - dense_3_loss: 0.3340
# Epoch 00130: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4661 - dense_4_loss: 0.1321 - dense_3_loss: 0.3340
# Epoch 131/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4750 - dense_4_loss: 0.1385 - dense_3_loss: 0.3365
# Epoch 00131: loss did not improve from 0.46138
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4748 - dense_4_loss: 0.1384 - dense_3_loss: 0.3363
# Epoch 132/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4679 - dense_4_loss: 0.1372 - dense_3_loss: 0.3307
# Epoch 00132: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4679 - dense_4_loss: 0.1371 - dense_3_loss: 0.3307
# Epoch 133/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4666 - dense_4_loss: 0.1368 - dense_3_loss: 0.3298
# Epoch 00133: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4666 - dense_4_loss: 0.1368 - dense_3_loss: 0.3298
# Epoch 134/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4655 - dense_4_loss: 0.1326 - dense_3_loss: 0.3329
# Epoch 00134: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4655 - dense_4_loss: 0.1326 - dense_3_loss: 0.3329
# Epoch 135/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4629 - dense_4_loss: 0.1294 - dense_3_loss: 0.3335
# Epoch 00135: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4629 - dense_4_loss: 0.1294 - dense_3_loss: 0.3335
# Epoch 136/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4736 - dense_4_loss: 0.1411 - dense_3_loss: 0.3325
# Epoch 00136: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4734 - dense_4_loss: 0.1410 - dense_3_loss: 0.3324
# Epoch 137/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4684 - dense_4_loss: 0.1369 - dense_3_loss: 0.3315
# Epoch 00137: loss did not improve from 0.46138
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4684 - dense_4_loss: 0.1369 - dense_3_loss: 0.3315
# Epoch 138/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4695 - dense_4_loss: 0.1396 - dense_3_loss: 0.3299
# Epoch 00138: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4694 - dense_4_loss: 0.1396 - dense_3_loss: 0.3299
# Epoch 139/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4695 - dense_4_loss: 0.1377 - dense_3_loss: 0.3318
# Epoch 00139: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4693 - dense_4_loss: 0.1376 - dense_3_loss: 0.3317
# Epoch 140/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4629 - dense_4_loss: 0.1322 - dense_3_loss: 0.3307
# Epoch 00140: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4628 - dense_4_loss: 0.1322 - dense_3_loss: 0.3306
# Epoch 141/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4632 - dense_4_loss: 0.1335 - dense_3_loss: 0.3297
# Epoch 00141: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4630 - dense_4_loss: 0.1334 - dense_3_loss: 0.3296
# Epoch 142/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4616 - dense_4_loss: 0.1299 - dense_3_loss: 0.3317
# Epoch 00142: loss did not improve from 0.46138
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4616 - dense_4_loss: 0.1299 - dense_3_loss: 0.3317
# Epoch 143/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4604 - dense_4_loss: 0.1311 - dense_3_loss: 0.3294
# Epoch 00143: loss did not improve from 0.46138
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4619 - dense_4_loss: 0.1311 - dense_3_loss: 0.3308
# Epoch 144/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4623 - dense_4_loss: 0.1320 - dense_3_loss: 0.3303
# Epoch 00144: loss did not improve from 0.46138
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4622 - dense_4_loss: 0.1320 - dense_3_loss: 0.3303
# Epoch 145/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4670 - dense_4_loss: 0.1374 - dense_3_loss: 0.3296
# Epoch 00145: loss did not improve from 0.46138
# 535/535 [==============================] - 24s 45ms/step - loss: 0.4670 - dense_4_loss: 0.1374 - dense_3_loss: 0.3296
# Epoch 146/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4666 - dense_4_loss: 0.1406 - dense_3_loss: 0.3259
# Epoch 00146: loss did not improve from 0.46138
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4664 - dense_4_loss: 0.1406 - dense_3_loss: 0.3258
# Epoch 147/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4627 - dense_4_loss: 0.1352 - dense_3_loss: 0.3275
# Epoch 00147: loss did not improve from 0.46138
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4626 - dense_4_loss: 0.1352 - dense_3_loss: 0.3274
# Epoch 148/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4578 - dense_4_loss: 0.1322 - dense_3_loss: 0.3256
# Epoch 00148: loss improved from 0.46138 to 0.45779, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4578 - dense_4_loss: 0.1322 - dense_3_loss: 0.3256
# Epoch 149/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4590 - dense_4_loss: 0.1328 - dense_3_loss: 0.3262
# Epoch 00149: loss did not improve from 0.45779
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4590 - dense_4_loss: 0.1328 - dense_3_loss: 0.3262
# Epoch 150/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4610 - dense_4_loss: 0.1304 - dense_3_loss: 0.3305
# Epoch 00150: loss did not improve from 0.45779
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4610 - dense_4_loss: 0.1304 - dense_3_loss: 0.3305
# Epoch 151/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4711 - dense_4_loss: 0.1411 - dense_3_loss: 0.3300
# Epoch 00151: loss did not improve from 0.45779
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4711 - dense_4_loss: 0.1411 - dense_3_loss: 0.3300
# Epoch 152/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4655 - dense_4_loss: 0.1364 - dense_3_loss: 0.3292
# Epoch 00152: loss did not improve from 0.45779
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4655 - dense_4_loss: 0.1364 - dense_3_loss: 0.3292
# Epoch 153/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4563 - dense_4_loss: 0.1297 - dense_3_loss: 0.3266
# Epoch 00153: loss improved from 0.45779 to 0.45628, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4563 - dense_4_loss: 0.1297 - dense_3_loss: 0.3266
# Epoch 154/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4588 - dense_4_loss: 0.1303 - dense_3_loss: 0.3285
# Epoch 00154: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4588 - dense_4_loss: 0.1303 - dense_3_loss: 0.3285
# Epoch 155/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4581 - dense_4_loss: 0.1329 - dense_3_loss: 0.3252
# Epoch 00155: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4581 - dense_4_loss: 0.1329 - dense_3_loss: 0.3252
# Epoch 156/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4613 - dense_4_loss: 0.1344 - dense_3_loss: 0.3269
# Epoch 00156: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4612 - dense_4_loss: 0.1344 - dense_3_loss: 0.3268
# Epoch 157/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4622 - dense_4_loss: 0.1360 - dense_3_loss: 0.3262
# Epoch 00157: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4622 - dense_4_loss: 0.1360 - dense_3_loss: 0.3262
# Epoch 158/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4642 - dense_4_loss: 0.1388 - dense_3_loss: 0.3255
# Epoch 00158: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4644 - dense_4_loss: 0.1388 - dense_3_loss: 0.3256
# Epoch 159/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4587 - dense_4_loss: 0.1313 - dense_3_loss: 0.3274
# Epoch 00159: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4586 - dense_4_loss: 0.1313 - dense_3_loss: 0.3274
# Epoch 160/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4607 - dense_4_loss: 0.1323 - dense_3_loss: 0.3284
# Epoch 00160: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4607 - dense_4_loss: 0.1323 - dense_3_loss: 0.3284
# Epoch 161/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4575 - dense_4_loss: 0.1292 - dense_3_loss: 0.3283
# Epoch 00161: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4573 - dense_4_loss: 0.1292 - dense_3_loss: 0.3282
# Epoch 162/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4578 - dense_4_loss: 0.1312 - dense_3_loss: 0.3266
# Epoch 00162: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4580 - dense_4_loss: 0.1313 - dense_3_loss: 0.3267
# Epoch 163/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4653 - dense_4_loss: 0.1404 - dense_3_loss: 0.3248
# Epoch 00163: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4651 - dense_4_loss: 0.1404 - dense_3_loss: 0.3247
# Epoch 164/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4567 - dense_4_loss: 0.1338 - dense_3_loss: 0.3229
# Epoch 00164: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4567 - dense_4_loss: 0.1338 - dense_3_loss: 0.3229
# Epoch 165/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4646 - dense_4_loss: 0.1390 - dense_3_loss: 0.3256
# Epoch 00165: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4646 - dense_4_loss: 0.1390 - dense_3_loss: 0.3256
# Epoch 166/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4608 - dense_4_loss: 0.1328 - dense_3_loss: 0.3280
# Epoch 00166: loss did not improve from 0.45628
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4608 - dense_4_loss: 0.1328 - dense_3_loss: 0.3280
# Epoch 167/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4544 - dense_4_loss: 0.1295 - dense_3_loss: 0.3249
# Epoch 00167: loss improved from 0.45628 to 0.45427, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4543 - dense_4_loss: 0.1294 - dense_3_loss: 0.3248
# Epoch 168/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4598 - dense_4_loss: 0.1354 - dense_3_loss: 0.3244
# Epoch 00168: loss did not improve from 0.45427
# 535/535 [==============================] - 23s 44ms/step - loss: 0.4598 - dense_4_loss: 0.1354 - dense_3_loss: 0.3244
# Epoch 169/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4540 - dense_4_loss: 0.1302 - dense_3_loss: 0.3238
# Epoch 00169: loss improved from 0.45427 to 0.45401, saving model to ae.model
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4540 - dense_4_loss: 0.1302 - dense_3_loss: 0.3238
# Epoch 170/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4567 - dense_4_loss: 0.1334 - dense_3_loss: 0.3232
# Epoch 00170: loss did not improve from 0.45401
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4565 - dense_4_loss: 0.1334 - dense_3_loss: 0.3231
# Epoch 171/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4588 - dense_4_loss: 0.1342 - dense_3_loss: 0.3246
# Epoch 00171: loss did not improve from 0.45401
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4589 - dense_4_loss: 0.1343 - dense_3_loss: 0.3246
# Epoch 172/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4585 - dense_4_loss: 0.1348 - dense_3_loss: 0.3236
# Epoch 00172: loss did not improve from 0.45401
# 535/535 [==============================] - 24s 44ms/step - loss: 0.4585 - dense_4_loss: 0.1348 - dense_3_loss: 0.3236
# Epoch 173/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4575 - dense_4_loss: 0.1328 - dense_3_loss: 0.3247
# Epoch 00173: loss did not improve from 0.45401
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4574 - dense_4_loss: 0.1327 - dense_3_loss: 0.3247
# Epoch 174/1000
# 535/535 [==============================] - ETA: 0s - loss: 0.4605 - dense_4_loss: 0.1308 - dense_3_loss: 0.3297
# Epoch 00174: loss did not improve from 0.45401
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4605 - dense_4_loss: 0.1308 - dense_3_loss: 0.3297
# Epoch 175/1000
# 534/535 [============================>.] - ETA: 0s - loss: 0.4541 - dense_4_loss: 0.1287 - dense_3_loss: 0.3254
# Epoch 00175: loss improved from 0.45401 to 0.45394, saving model to ae.model
# 535/535 [==============================] - 23s 43ms/step - loss: 0.4539 - dense_4_loss: 0.1287 - dense_3_loss: 0.3253
# Epoch 176/1000
# 447/535 [========================>.....] - ETA: 3s - loss: 0.4490 - dense_4_loss: 0.1278 - dense_3_loss: 0.3213
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-783115eb8100> in <module>()
#      15                            verbose=1, workers=-1,
#      16                            use_multiprocessing=True,
# ---> 17                               callbacks=[auto_ckpt, warm_up_lr])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1827         use_multiprocessing=use_multiprocessing,
#    1828         shuffle=shuffle,
# -> 1829         initial_epoch=initial_epoch)
#    1830
#    1831   @deprecation.deprecated(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
mod=Model(inputs=model_mse.inputs,outputs=model_mse.layers[4].output)
mod.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 102)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 463)]        0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 565)          0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          289792      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      dense[0][0]
# ==================================================================================================
# Total params: 421,120
# Trainable params: 421,120
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pre=mod.predict((X[num],X[tot]))
pre.shape

# %%
np.save('/content/gdrive/My Drive/fraud/with_id_withpoutV.npy',pre)

# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/IEEE-CIS-Fraud/blob/master/simple_model_focal_loss_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_USERNAME'] = "tapaskd123" # username from the json file
os.environ['KAGGLE_KEY'] = "aba8dc1f085221111d925003fe5a88ed" # key from the json file
# !kaggle competitions download -c ieee-fraud-detection
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/1.14M [00:00<?, ?B/s]
# 100% 1.14M/1.14M [00:00<00:00, 79.5MB/s]
# Downloading test_identity.csv.zip to /content
#   0% 0.00/3.21M [00:00<?, ?B/s]
# 100% 3.21M/3.21M [00:00<00:00, 106MB/s]
# Downloading test_transaction.csv.zip to /content
#  94% 49.0M/52.2M [00:00<00:00, 89.8MB/s]
# 100% 52.2M/52.2M [00:00<00:00, 118MB/s]
# Downloading train_identity.csv.zip to /content
#   0% 0.00/3.26M [00:00<?, ?B/s]
# 100% 3.26M/3.26M [00:00<00:00, 222MB/s]
# Downloading train_transaction.csv.zip to /content
#  94% 55.0M/58.3M [00:00<00:00, 86.9MB/s]
# 100% 58.3M/58.3M [00:00<00:00, 108MB/s]

# %%
n_fold=5
lr=0.001

# %%
import pandas as pd
trn=pd.read_csv('/content/gdrive/My Drive/fraud/train.csv')
tst=pd.read_csv('/content/gdrive/My Drive/fraud/test.csv')
ls=list(trn.filter(regex='V'))
trn=trn.drop(ls,1)
tst=tst.drop(ls,1)

# %%
from tensorflow.keras.layers import *
import tensorflow as tf
import random, os, sys
import numpy as np
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
import tensorflow as tf

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np


class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
from sklearn.preprocessing import LabelEncoder
cols=list(trn.select_dtypes(include=object))
for col in cols:
  le=LabelEncoderExt()
  le.fit(trn[col].astype(str))
  trn[col]=le.transform(trn[col].astype(str))
  tst[col] = tst[col].map(lambda s: '<unknown>' if s not in le.classes_ else s)
  tst[col]=le.transform(tst[col].astype(str))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   import sys

# %%
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from keras.layers import *
from keras.optimizers import *
from keras.models import *
from keras import backend as K
ss=StandardScaler()
frd=trn['isFraud']
ls=list(trn)
trn=ss.fit_transform(trn.drop(['isFraud'],1))
trn=pd.DataFrame(trn)

# %%
ls.remove('isFraud')
trn.columns=ls
trn['isFraud']=frd

ls=list(tst)
tst=ss.fit_transform(tst)
tst=pd.DataFrame(tst)
tst.columns=ls

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df
trn=reduce_mem_usage(trn)
tst=reduce_mem_usage(tst)
# Out:
# Memory usage of dataframe is 860.54 MB
# Memory usage after optimization is: 215.14 MB
# Decreased by 75.0%
# Memory usage of dataframe is 734.49 MB
# Memory usage after optimization is: 183.62 MB
# Decreased by 75.0%

# %%
trn_n=pd.read_csv('train_transaction.csv.zip')
tst_n=pd.read_csv('test_transaction.csv.zip')
trn['month']=trn_n['TransactionDT']//(86400*30)
trn_n.head()
trn_ls=list(trn_n)
tst_ls=list(tst_n)
for col in trn:
  if col in trn_ls:
    trn[col+'_isna']=trn_n[col].isna().astype('uint8')
for col in tst:
  if col in tst_ls:
    tst[col+'_isna']=tst_n[col].isna().astype('uint8')
import gc
del([trn_n,tst_n])
gc.collect()
# Out:
# 0

# %%
trn=trn.drop(['isFraud_isna'],1)

# %%
from sklearn.metrics import roc_auc_score
from keras.callbacks import Callback
class RocCallback(Callback):
    def __init__(self,validation_data):
        self.x_val = validation_data[0]
        self.y_val = validation_data[1]
        self.ep=0

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        self.ep+=1
        if self.ep%10==0:
          y_pred_val = self.model.predict(self.x_val)
          roc_val = roc_auc_score(self.y_val, y_pred_val)
          print('roc-auc_val: %s' % str(round(roc_val,4)))

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %%
1-0.036
# Out:
# 0.964

# %%
def fl():
    def focal_loss(y_true, y_pred):
        gamma=3
        alpha=1-0.036
        pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))

        pt_1 = K.clip(pt_1, 1e-3, .999)
        pt_0 = K.clip(pt_0, 1e-3, .999)

        return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0))
    return focal_loss
dk={}
def load_model():
  K.clear_session()
  inp=Input((233,))
  x=Dense(256,activation='relu')(inp)
  x=Dropout(0.3)(x)
  x=BatchNormalization()(x)
  x=Dense(256,activation='relu')(x)
  x=Dropout(0.3)(x)
  x=BatchNormalization()(x)
  x=Dense(256,activation='relu')(x)
  x=Dropout(0.3)(x)
  x=BatchNormalization()(x)
  x=Dense(1,activation='sigmoid')(x)
  mod=Model(inputs=inp,outputs=x)
  return mod
for en,month in enumerate([(4,5),(3,4),(3,5)]):
  train=trn.loc[trn['month']>=month[1]]
  test=trn.loc[trn['month']<=month[0]]
  train=train.drop(['month'],1)
  test=test.drop(['month'],1)
  mod=load_model()
  mod.compile(optimizer=Adam(0.0001,decay=1e-3),loss=fl())
  roc = RocCallback(
                  validation_data=(test.drop(['isFraud'],1), test['isFraud']))
  es=EarlyStopping(monitor='val_loss',min_delta=0.0001,mode='min',restore_best_weights=True,patience=50)
  mod.fit(train.drop(['isFraud'],1),train['isFraud'],validation_data=(test.drop(['isFraud'],1),test['isFraud']),batch_size=2048,epochs=1000,callbacks=[es,roc])
  del([train,test])
  gc.collect()
  df=trn.loc[trn['month']==6].reset_index(drop=True).drop(['month'],1)
  pre=mod.predict(df.drop(['isFraud'],1))
  scr=roc_auc_score(df['isFraud'],pre)
  dk[str(scr)]=mod.predict(tst)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 31ms/step - loss: 37.5979 - val_loss: 12.2138
# Epoch 2/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 30.7640 - val_loss: 12.3804
# Epoch 3/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 26.5088 - val_loss: 12.4880
# Epoch 4/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 25.1178 - val_loss: 12.7279
# Epoch 5/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 25.0084 - val_loss: 12.8313
# Epoch 6/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 23.0562 - val_loss: 12.9000
# Epoch 7/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 21.8748 - val_loss: 12.9680
# Epoch 8/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 20.7056 - val_loss: 13.0237
# Epoch 9/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 20.0162 - val_loss: 13.1190
# Epoch 10/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 20.0359roc-auc_val: 0.7509
# 47/47 [==============================] - 17s 362ms/step - loss: 19.8885 - val_loss: 13.2045
# Epoch 11/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 18.8218 - val_loss: 13.1752
# Epoch 12/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 18.8442 - val_loss: 13.1834
# Epoch 13/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 18.0580 - val_loss: 13.1180
# Epoch 14/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 17.7106 - val_loss: 13.0896
# Epoch 15/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 17.7656 - val_loss: 13.0541
# Epoch 16/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 16.8242 - val_loss: 13.0165
# Epoch 17/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 16.4900 - val_loss: 12.9542
# Epoch 18/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 15.9833 - val_loss: 12.9595
# Epoch 19/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 15.9461 - val_loss: 12.9171
# Epoch 20/1000
# 40/47 [========================>.....] - ETA: 0s - loss: 16.2875roc-auc_val: 0.7641
# 47/47 [==============================] - 17s 361ms/step - loss: 16.0821 - val_loss: 12.9231
# Epoch 21/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 15.2822 - val_loss: 12.8389
# Epoch 22/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 15.4224 - val_loss: 12.7769
# Epoch 23/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 15.0546 - val_loss: 12.7957
# Epoch 24/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 15.4528 - val_loss: 12.8674
# Epoch 25/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 14.9896 - val_loss: 12.9258
# Epoch 26/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 14.0927 - val_loss: 12.8835
# Epoch 27/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 14.1255 - val_loss: 12.7865
# Epoch 28/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 13.7813 - val_loss: 12.8027
# Epoch 29/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 14.2119 - val_loss: 12.7692
# Epoch 30/1000
# 41/47 [=========================>....] - ETA: 0s - loss: 14.1471roc-auc_val: 0.7703
# 47/47 [==============================] - 17s 358ms/step - loss: 14.1016 - val_loss: 12.7771
# Epoch 31/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 13.5232 - val_loss: 12.7316
# Epoch 32/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 13.4696 - val_loss: 12.7019
# Epoch 33/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 13.3332 - val_loss: 12.7316
# Epoch 34/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 12.9163 - val_loss: 12.7035
# Epoch 35/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 12.9664 - val_loss: 12.6794
# Epoch 36/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 12.8940 - val_loss: 12.6681
# Epoch 37/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 12.4765 - val_loss: 12.6396
# Epoch 38/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 12.7170 - val_loss: 12.6272
# Epoch 39/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 12.9171 - val_loss: 12.5705
# Epoch 40/1000
# 44/47 [===========================>..] - ETA: 0s - loss: 12.4521roc-auc_val: 0.7755
# 47/47 [==============================] - 17s 360ms/step - loss: 12.4236 - val_loss: 12.5465
# Epoch 41/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 12.4624 - val_loss: 12.5321
# Epoch 42/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 12.3822 - val_loss: 12.5115
# Epoch 43/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 12.4879 - val_loss: 12.5028
# Epoch 44/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 12.4207 - val_loss: 12.5062
# Epoch 45/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 12.1668 - val_loss: 12.5324
# Epoch 46/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 12.4258 - val_loss: 12.5530
# Epoch 47/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 11.6750 - val_loss: 12.5245
# Epoch 48/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 12.0225 - val_loss: 12.5187
# Epoch 49/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 11.8761 - val_loss: 12.5229
# Epoch 50/1000
# 46/47 [============================>.] - ETA: 0s - loss: 11.5558roc-auc_val: 0.7787
# 47/47 [==============================] - 18s 378ms/step - loss: 11.5124 - val_loss: 12.5064
# Epoch 51/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 11.8913 - val_loss: 12.4582
# Epoch 1/1000
# 88/88 [==============================] - 2s 19ms/step - loss: 36.7565 - val_loss: 11.5162
# Epoch 2/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 28.2833 - val_loss: 11.5248
# Epoch 3/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 24.5254 - val_loss: 11.6514
# Epoch 4/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 22.6002 - val_loss: 11.8219
# Epoch 5/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 21.3219 - val_loss: 11.8698
# Epoch 6/1000
# 88/88 [==============================] - 1s 9ms/step - loss: 20.6730 - val_loss: 11.8791
# Epoch 7/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 19.8505 - val_loss: 11.8037
# Epoch 8/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 18.5799 - val_loss: 11.6338
# Epoch 9/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 18.0753 - val_loss: 11.6736
# Epoch 10/1000
# 85/88 [===========================>..] - ETA: 0s - loss: 17.2328roc-auc_val: 0.7695
# 88/88 [==============================] - 15s 165ms/step - loss: 17.1873 - val_loss: 11.6278
# Epoch 11/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 17.0829 - val_loss: 11.4223
# Epoch 12/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 16.1813 - val_loss: 11.3733
# Epoch 13/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 16.2684 - val_loss: 11.5121
# Epoch 14/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 15.6592 - val_loss: 11.4225
# Epoch 15/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 15.1430 - val_loss: 11.3845
# Epoch 16/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 15.3853 - val_loss: 11.2965
# Epoch 17/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 14.8263 - val_loss: 11.2366
# Epoch 18/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 14.5709 - val_loss: 11.1883
# Epoch 19/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 14.3184 - val_loss: 11.0609
# Epoch 20/1000
# 85/88 [===========================>..] - ETA: 0s - loss: 14.3596roc-auc_val: 0.7801
# 88/88 [==============================] - 14s 164ms/step - loss: 14.3296 - val_loss: 11.0823
# Epoch 21/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 13.9778 - val_loss: 11.0354
# Epoch 22/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 13.5622 - val_loss: 10.9861
# Epoch 23/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 13.8161 - val_loss: 10.9890
# Epoch 24/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 13.6355 - val_loss: 11.0362
# Epoch 25/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 13.2590 - val_loss: 11.0282
# Epoch 26/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 12.7021 - val_loss: 10.9743
# Epoch 27/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 12.9865 - val_loss: 11.0497
# Epoch 28/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 12.7612 - val_loss: 11.0357
# Epoch 29/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 12.6501 - val_loss: 11.0321
# Epoch 30/1000
# 85/88 [===========================>..] - ETA: 0s - loss: 12.3673roc-auc_val: 0.788
# 88/88 [==============================] - 15s 165ms/step - loss: 12.3148 - val_loss: 11.0300
# Epoch 31/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 12.3372 - val_loss: 11.0153
# Epoch 32/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 12.1123 - val_loss: 10.9572
# Epoch 33/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 12.2884 - val_loss: 10.9438
# Epoch 34/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 12.0802 - val_loss: 11.0321
# Epoch 35/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.8442 - val_loss: 11.0240
# Epoch 36/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 12.1543 - val_loss: 11.0387
# Epoch 37/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.6915 - val_loss: 10.9724
# Epoch 38/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.9449 - val_loss: 10.9561
# Epoch 39/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.6946 - val_loss: 10.9759
# Epoch 40/1000
# 85/88 [===========================>..] - ETA: 0s - loss: 11.5964roc-auc_val: 0.7934
# 88/88 [==============================] - 15s 167ms/step - loss: 11.5518 - val_loss: 10.9663
# Epoch 41/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.4137 - val_loss: 10.8918
# Epoch 42/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.3532 - val_loss: 10.8945
# Epoch 43/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.3660 - val_loss: 10.8919
# Epoch 44/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.3289 - val_loss: 10.8626
# Epoch 45/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.1781 - val_loss: 10.8852
# Epoch 46/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.2345 - val_loss: 10.8664
# Epoch 47/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.9883 - val_loss: 10.8790
# Epoch 48/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.2020 - val_loss: 10.8605
# Epoch 49/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 11.1788 - val_loss: 10.8629
# Epoch 50/1000
# 84/88 [===========================>..] - ETA: 0s - loss: 11.0327roc-auc_val: 0.7977
# 88/88 [==============================] - 15s 165ms/step - loss: 10.9949 - val_loss: 10.8589
# Epoch 51/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.8548 - val_loss: 10.8198
# Epoch 52/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.9980 - val_loss: 10.8054
# Epoch 53/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.9116 - val_loss: 10.8392
# Epoch 54/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.7579 - val_loss: 10.8094
# Epoch 55/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.8768 - val_loss: 10.8092
# Epoch 56/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.4943 - val_loss: 10.8598
# Epoch 57/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.7617 - val_loss: 10.8631
# Epoch 58/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.6105 - val_loss: 10.9045
# Epoch 59/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.3898 - val_loss: 10.8858
# Epoch 60/1000
# 86/88 [============================>.] - ETA: 0s - loss: 10.4485roc-auc_val: 0.801
# 88/88 [==============================] - 14s 164ms/step - loss: 10.4312 - val_loss: 10.8524
# Epoch 61/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.4267 - val_loss: 10.8402
# Epoch 62/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.4613 - val_loss: 10.8280
# Epoch 63/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.7091 - val_loss: 10.8552
# Epoch 64/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.2497 - val_loss: 10.8282
# Epoch 65/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.5728 - val_loss: 10.8310
# Epoch 66/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.4764 - val_loss: 10.8045
# Epoch 67/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.2329 - val_loss: 10.7675
# Epoch 68/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.6089 - val_loss: 10.7807
# Epoch 69/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.3064 - val_loss: 10.7978
# Epoch 70/1000
# 83/88 [===========================>..] - ETA: 0s - loss: 10.1572roc-auc_val: 0.804
# 88/88 [==============================] - 14s 164ms/step - loss: 10.1752 - val_loss: 10.7952
# Epoch 71/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.3711 - val_loss: 10.8144
# Epoch 72/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.2031 - val_loss: 10.7965
# Epoch 73/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.3881 - val_loss: 10.8160
# Epoch 74/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.2796 - val_loss: 10.7991
# Epoch 75/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.0340 - val_loss: 10.7756
# Epoch 76/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.0316 - val_loss: 10.7652
# Epoch 77/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.1286 - val_loss: 10.7799
# Epoch 78/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.0713 - val_loss: 10.7902
# Epoch 79/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.0525 - val_loss: 10.7782
# Epoch 80/1000
# 83/88 [===========================>..] - ETA: 0s - loss: 10.1898roc-auc_val: 0.8066
# 88/88 [==============================] - 15s 165ms/step - loss: 10.1639 - val_loss: 10.7708
# Epoch 81/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.6706 - val_loss: 10.7826
# Epoch 82/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.0965 - val_loss: 10.7853
# Epoch 83/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.9914 - val_loss: 10.7772
# Epoch 84/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.0487 - val_loss: 10.7587
# Epoch 85/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 10.0126 - val_loss: 10.7337
# Epoch 86/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.8012 - val_loss: 10.7420
# Epoch 87/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.9029 - val_loss: 10.7569
# Epoch 88/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.8791 - val_loss: 10.7722
# Epoch 89/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.8308 - val_loss: 10.7825
# Epoch 90/1000
# 84/88 [===========================>..] - ETA: 0s - loss: 9.6340roc-auc_val: 0.8078
# 88/88 [==============================] - 14s 164ms/step - loss: 9.5989 - val_loss: 10.7939
# Epoch 91/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.7628 - val_loss: 10.8042
# Epoch 92/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.9123 - val_loss: 10.8009
# Epoch 93/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.8767 - val_loss: 10.8162
# Epoch 94/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.7847 - val_loss: 10.8279
# Epoch 95/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.6807 - val_loss: 10.8027
# Epoch 96/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.6200 - val_loss: 10.7990
# Epoch 97/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.7039 - val_loss: 10.7929
# Epoch 98/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.9244 - val_loss: 10.7908
# Epoch 99/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.5796 - val_loss: 10.8055
# Epoch 100/1000
# 84/88 [===========================>..] - ETA: 0s - loss: 9.6572roc-auc_val: 0.8091
# 88/88 [==============================] - 14s 164ms/step - loss: 9.6234 - val_loss: 10.7965
# Epoch 101/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.6211 - val_loss: 10.8043
# Epoch 102/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.6850 - val_loss: 10.8107
# Epoch 103/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.4949 - val_loss: 10.8160
# Epoch 104/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.5919 - val_loss: 10.8028
# Epoch 105/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.5010 - val_loss: 10.8255
# Epoch 106/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.5666 - val_loss: 10.8310
# Epoch 107/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.5444 - val_loss: 10.8297
# Epoch 108/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.3254 - val_loss: 10.8277
# Epoch 109/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.4016 - val_loss: 10.8364
# Epoch 110/1000
# 84/88 [===========================>..] - ETA: 0s - loss: 9.5540roc-auc_val: 0.8105
# 88/88 [==============================] - 15s 165ms/step - loss: 9.5392 - val_loss: 10.8359
# Epoch 111/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.4999 - val_loss: 10.8538
# Epoch 112/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.3801 - val_loss: 10.8453
# Epoch 113/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.4532 - val_loss: 10.8418
# Epoch 114/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.5104 - val_loss: 10.8577
# Epoch 115/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.4416 - val_loss: 10.8423
# Epoch 116/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.5134 - val_loss: 10.8397
# Epoch 117/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.4800 - val_loss: 10.8438
# Epoch 118/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.4242 - val_loss: 10.8411
# Epoch 119/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.2828 - val_loss: 10.8402
# Epoch 120/1000
# 86/88 [============================>.] - ETA: 0s - loss: 9.3361roc-auc_val: 0.8115
# 88/88 [==============================] - 16s 176ms/step - loss: 9.3268 - val_loss: 10.8380
# Epoch 121/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 9.3050 - val_loss: 10.8418
# Epoch 122/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 9.3847 - val_loss: 10.8271
# Epoch 123/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 9.4319 - val_loss: 10.8197
# Epoch 124/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.3661 - val_loss: 10.8221
# Epoch 125/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.3222 - val_loss: 10.8343
# Epoch 126/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.2548 - val_loss: 10.8479
# Epoch 127/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.1998 - val_loss: 10.8394
# Epoch 128/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.3441 - val_loss: 10.8481
# Epoch 129/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.2203 - val_loss: 10.8551
# Epoch 130/1000
# 84/88 [===========================>..] - ETA: 0s - loss: 9.2292roc-auc_val: 0.8122
# 88/88 [==============================] - 15s 166ms/step - loss: 9.1981 - val_loss: 10.8548
# Epoch 131/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.2441 - val_loss: 10.8499
# Epoch 132/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.3660 - val_loss: 10.8386
# Epoch 133/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.3191 - val_loss: 10.8367
# Epoch 134/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.1716 - val_loss: 10.8460
# Epoch 135/1000
# 88/88 [==============================] - 1s 10ms/step - loss: 9.1214 - val_loss: 10.8399
# Epoch 1/1000
# 47/47 [==============================] - 1s 31ms/step - loss: 39.3824 - val_loss: 13.9734
# Epoch 2/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 31.1192 - val_loss: 14.2475
# Epoch 3/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 27.9652 - val_loss: 14.2020
# Epoch 4/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 26.1666 - val_loss: 14.6146
# Epoch 5/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 23.5803 - val_loss: 14.4547
# Epoch 6/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 22.8130 - val_loss: 14.7616
# Epoch 7/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 22.2126 - val_loss: 14.6914
# Epoch 8/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 21.1385 - val_loss: 14.3286
# Epoch 9/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 19.7041 - val_loss: 14.4655
# Epoch 10/1000
# 44/47 [===========================>..] - ETA: 0s - loss: 20.0624roc-auc_val: 0.7487
# 47/47 [==============================] - 14s 304ms/step - loss: 19.9206 - val_loss: 14.6655
# Epoch 11/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 18.4555 - val_loss: 14.3680
# Epoch 12/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 19.1282 - val_loss: 14.0798
# Epoch 13/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 17.8796 - val_loss: 14.0068
# Epoch 14/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 18.0029 - val_loss: 13.9165
# Epoch 15/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 17.4706 - val_loss: 13.9620
# Epoch 16/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 17.2046 - val_loss: 13.6585
# Epoch 17/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 16.7228 - val_loss: 13.7997
# Epoch 18/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 16.4478 - val_loss: 13.7179
# Epoch 19/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 16.0824 - val_loss: 13.6509
# Epoch 20/1000
# 44/47 [===========================>..] - ETA: 0s - loss: 15.3486roc-auc_val: 0.7616
# 47/47 [==============================] - 14s 304ms/step - loss: 15.3989 - val_loss: 13.5069
# Epoch 21/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 15.5687 - val_loss: 13.5411
# Epoch 22/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 15.4048 - val_loss: 13.4070
# Epoch 23/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 14.8101 - val_loss: 13.4262
# Epoch 24/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 14.6481 - val_loss: 13.3394
# Epoch 25/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 14.2504 - val_loss: 13.2297
# Epoch 26/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 14.2540 - val_loss: 13.1861
# Epoch 27/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 13.7781 - val_loss: 13.1692
# Epoch 28/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 13.9211 - val_loss: 13.0646
# Epoch 29/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 14.0337 - val_loss: 13.0812
# Epoch 30/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 13.6982roc-auc_val: 0.7699
# 47/47 [==============================] - 14s 304ms/step - loss: 13.7026 - val_loss: 13.0226
# Epoch 31/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 13.2909 - val_loss: 13.0294
# Epoch 32/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 13.3565 - val_loss: 13.0049
# Epoch 33/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 13.0887 - val_loss: 13.0556
# Epoch 34/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 12.9692 - val_loss: 12.9663
# Epoch 35/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 13.1852 - val_loss: 12.8791
# Epoch 36/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 13.1373 - val_loss: 12.8592
# Epoch 37/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 13.4685 - val_loss: 12.8718
# Epoch 38/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 12.6552 - val_loss: 12.8265
# Epoch 39/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 12.4744 - val_loss: 12.7674
# Epoch 40/1000
# 44/47 [===========================>..] - ETA: 0s - loss: 12.7051roc-auc_val: 0.7735
# 47/47 [==============================] - 14s 308ms/step - loss: 12.6207 - val_loss: 12.7404
# Epoch 41/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 12.5179 - val_loss: 12.6488
# Epoch 42/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 12.3068 - val_loss: 12.7058
# Epoch 43/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 12.6192 - val_loss: 12.7163
# Epoch 44/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 12.2877 - val_loss: 12.5697
# Epoch 45/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 12.0578 - val_loss: 12.5140
# Epoch 46/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 12.0618 - val_loss: 12.5280
# Epoch 47/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.8405 - val_loss: 12.5936
# Epoch 48/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 11.9817 - val_loss: 12.5833
# Epoch 49/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.6084 - val_loss: 12.5636
# Epoch 50/1000
# 44/47 [===========================>..] - ETA: 0s - loss: 11.8371roc-auc_val: 0.777
# 47/47 [==============================] - 14s 304ms/step - loss: 11.7277 - val_loss: 12.5208
# Epoch 51/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.6359 - val_loss: 12.5300
# Epoch 52/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.4996 - val_loss: 12.5185
# Epoch 53/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.3853 - val_loss: 12.4922
# Epoch 54/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.3822 - val_loss: 12.5525
# Epoch 55/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.4242 - val_loss: 12.5362
# Epoch 56/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.4375 - val_loss: 12.5030
# Epoch 57/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.5295 - val_loss: 12.5359
# Epoch 58/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.3450 - val_loss: 12.4958
# Epoch 59/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.2163 - val_loss: 12.4293
# Epoch 60/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 11.3846roc-auc_val: 0.7788
# 47/47 [==============================] - 14s 302ms/step - loss: 11.3210 - val_loss: 12.4451
# Epoch 61/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 11.2064 - val_loss: 12.4233
# Epoch 62/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.9392 - val_loss: 12.4272
# Epoch 63/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.0061 - val_loss: 12.4288
# Epoch 64/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.9106 - val_loss: 12.4150
# Epoch 65/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.2269 - val_loss: 12.3236
# Epoch 66/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.8631 - val_loss: 12.2635
# Epoch 67/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 11.1268 - val_loss: 12.2899
# Epoch 68/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.6639 - val_loss: 12.3240
# Epoch 69/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.7042 - val_loss: 12.3213
# Epoch 70/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 10.7657roc-auc_val: 0.7811
# 47/47 [==============================] - 14s 304ms/step - loss: 10.7344 - val_loss: 12.2656
# Epoch 71/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 10.7950 - val_loss: 12.2981
# Epoch 72/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.8325 - val_loss: 12.3420
# Epoch 73/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.4609 - val_loss: 12.3589
# Epoch 74/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.4985 - val_loss: 12.2854
# Epoch 75/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.3941 - val_loss: 12.2932
# Epoch 76/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.6647 - val_loss: 12.2898
# Epoch 77/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.3918 - val_loss: 12.2951
# Epoch 78/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.3047 - val_loss: 12.2678
# Epoch 79/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 10.4391 - val_loss: 12.2350
# Epoch 80/1000
# 43/47 [==========================>...] - ETA: 0s - loss: 10.4577roc-auc_val: 0.7829
# 47/47 [==============================] - 14s 304ms/step - loss: 10.4254 - val_loss: 12.1738
# Epoch 81/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.1813 - val_loss: 12.1481
# Epoch 82/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.4876 - val_loss: 12.1274
# Epoch 83/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.5843 - val_loss: 12.1690
# Epoch 84/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.2349 - val_loss: 12.1705
# Epoch 85/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.2743 - val_loss: 12.1725
# Epoch 86/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.3643 - val_loss: 12.1584
# Epoch 87/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 10.5167 - val_loss: 12.1704
# Epoch 88/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.0730 - val_loss: 12.2149
# Epoch 89/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.9310 - val_loss: 12.1981
# Epoch 90/1000
# 43/47 [==========================>...] - ETA: 0s - loss: 10.0574roc-auc_val: 0.7852
# 47/47 [==============================] - 14s 303ms/step - loss: 10.0515 - val_loss: 12.1531
# Epoch 91/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.0364 - val_loss: 12.1488
# Epoch 92/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.2474 - val_loss: 12.1931
# Epoch 93/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.0698 - val_loss: 12.2158
# Epoch 94/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.6641 - val_loss: 12.2061
# Epoch 95/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.7372 - val_loss: 12.2007
# Epoch 96/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.0540 - val_loss: 12.1811
# Epoch 97/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 10.0572 - val_loss: 12.1459
# Epoch 98/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.8015 - val_loss: 12.1501
# Epoch 99/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.7855 - val_loss: 12.1342
# Epoch 100/1000
# 43/47 [==========================>...] - ETA: 0s - loss: 9.8912roc-auc_val: 0.7863
# 47/47 [==============================] - 14s 303ms/step - loss: 9.8240 - val_loss: 12.1096
# Epoch 101/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.7653 - val_loss: 12.1144
# Epoch 102/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.8282 - val_loss: 12.1109
# Epoch 103/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.8268 - val_loss: 12.0916
# Epoch 104/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.8075 - val_loss: 12.0773
# Epoch 105/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.7448 - val_loss: 12.0576
# Epoch 106/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.7074 - val_loss: 12.0822
# Epoch 107/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.6057 - val_loss: 12.0675
# Epoch 108/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.6776 - val_loss: 12.0431
# Epoch 109/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.6662 - val_loss: 12.0418
# Epoch 110/1000
# 42/47 [=========================>....] - ETA: 0s - loss: 9.4170roc-auc_val: 0.7873
# 47/47 [==============================] - 14s 303ms/step - loss: 9.4636 - val_loss: 12.0735
# Epoch 111/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.5401 - val_loss: 12.0450
# Epoch 112/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.6768 - val_loss: 12.0371
# Epoch 113/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.4353 - val_loss: 12.0258
# Epoch 114/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.7129 - val_loss: 11.9973
# Epoch 115/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.5764 - val_loss: 12.0173
# Epoch 116/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.4951 - val_loss: 12.0520
# Epoch 117/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.4949 - val_loss: 12.0437
# Epoch 118/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.4748 - val_loss: 11.9899
# Epoch 119/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.4695 - val_loss: 12.0376
# Epoch 120/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 9.5168roc-auc_val: 0.7882
# 47/47 [==============================] - 14s 308ms/step - loss: 9.4852 - val_loss: 12.0668
# Epoch 121/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.2544 - val_loss: 12.0634
# Epoch 122/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.5655 - val_loss: 12.0571
# Epoch 123/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.5329 - val_loss: 12.0321
# Epoch 124/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.2648 - val_loss: 12.0065
# Epoch 125/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.4019 - val_loss: 12.0070
# Epoch 126/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.5695 - val_loss: 12.0215
# Epoch 127/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.1556 - val_loss: 12.0063
# Epoch 128/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.0875 - val_loss: 11.9750
# Epoch 129/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.1193 - val_loss: 11.9683
# Epoch 130/1000
# 41/47 [=========================>....] - ETA: 0s - loss: 9.4300roc-auc_val: 0.7894
# 47/47 [==============================] - 16s 334ms/step - loss: 9.3724 - val_loss: 11.9713
# Epoch 131/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.3064 - val_loss: 11.9798
# Epoch 132/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.4121 - val_loss: 11.9740
# Epoch 133/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.1089 - val_loss: 11.9424
# Epoch 134/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.1706 - val_loss: 11.9184
# Epoch 135/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.1265 - val_loss: 11.9256
# Epoch 136/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.1896 - val_loss: 11.9266
# Epoch 137/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.2139 - val_loss: 11.9431
# Epoch 138/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.0908 - val_loss: 11.9584
# Epoch 139/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.0211 - val_loss: 11.9519
# Epoch 140/1000
# 43/47 [==========================>...] - ETA: 0s - loss: 9.1904roc-auc_val: 0.7901
# 47/47 [==============================] - 14s 304ms/step - loss: 9.1195 - val_loss: 11.9530
# Epoch 141/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.1557 - val_loss: 11.9533
# Epoch 142/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.2050 - val_loss: 11.9170
# Epoch 143/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.0471 - val_loss: 11.9137
# Epoch 144/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.9722 - val_loss: 11.9231
# Epoch 145/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.1833 - val_loss: 11.9583
# Epoch 146/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.2118 - val_loss: 11.9442
# Epoch 147/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.0638 - val_loss: 11.9302
# Epoch 148/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.0444 - val_loss: 11.9318
# Epoch 149/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.0734 - val_loss: 11.9261
# Epoch 150/1000
# 43/47 [==========================>...] - ETA: 0s - loss: 9.1557roc-auc_val: 0.7908
# 47/47 [==============================] - 14s 306ms/step - loss: 9.1406 - val_loss: 11.9369
# Epoch 151/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.1836 - val_loss: 11.9644
# Epoch 152/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.0791 - val_loss: 11.9677
# Epoch 153/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.7968 - val_loss: 11.9617
# Epoch 154/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 9.0983 - val_loss: 11.9683
# Epoch 155/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.8958 - val_loss: 11.9576
# Epoch 156/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.9907 - val_loss: 11.9597
# Epoch 157/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.9344 - val_loss: 11.9260
# Epoch 158/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.9834 - val_loss: 11.9588
# Epoch 159/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.8066 - val_loss: 11.9688
# Epoch 160/1000
# 42/47 [=========================>....] - ETA: 0s - loss: 9.0724roc-auc_val: 0.7917
# 47/47 [==============================] - 14s 304ms/step - loss: 8.9967 - val_loss: 11.9651
# Epoch 161/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.7766 - val_loss: 11.9841
# Epoch 162/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.9759 - val_loss: 11.9798
# Epoch 163/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.9615 - val_loss: 11.9674
# Epoch 164/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.8943 - val_loss: 11.9770
# Epoch 165/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.7292 - val_loss: 11.9924
# Epoch 166/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.9134 - val_loss: 11.9879
# Epoch 167/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.8334 - val_loss: 11.9731
# Epoch 168/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.7900 - val_loss: 11.9615
# Epoch 169/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.7441 - val_loss: 11.9596
# Epoch 170/1000
# 42/47 [=========================>....] - ETA: 0s - loss: 9.0034roc-auc_val: 0.7926
# 47/47 [==============================] - 14s 305ms/step - loss: 8.9392 - val_loss: 11.9642
# Epoch 171/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.6500 - val_loss: 11.9570
# Epoch 172/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.7063 - val_loss: 11.9748
# Epoch 173/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.8394 - val_loss: 11.9652
# Epoch 174/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.7200 - val_loss: 11.9764
# Epoch 175/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.7934 - val_loss: 11.9929
# Epoch 176/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.8578 - val_loss: 11.9842
# Epoch 177/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.8763 - val_loss: 11.9977
# Epoch 178/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.8564 - val_loss: 12.0136
# Epoch 179/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.9146 - val_loss: 12.0029
# Epoch 180/1000
# 42/47 [=========================>....] - ETA: 0s - loss: 8.6446roc-auc_val: 0.7931
# 47/47 [==============================] - 14s 307ms/step - loss: 8.6181 - val_loss: 11.9985
# Epoch 181/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.6375 - val_loss: 11.9790
# Epoch 182/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.5833 - val_loss: 11.9826
# Epoch 183/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.6060 - val_loss: 11.9853
# Epoch 184/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.5595 - val_loss: 11.9977
# Epoch 185/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.5170 - val_loss: 12.0010
# Epoch 186/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.7781 - val_loss: 12.0049
# Epoch 187/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.6949 - val_loss: 12.0097
# Epoch 188/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.4774 - val_loss: 12.0058
# Epoch 189/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.7756 - val_loss: 11.9916
# Epoch 190/1000
# 42/47 [=========================>....] - ETA: 0s - loss: 8.8012roc-auc_val: 0.7937
# 47/47 [==============================] - 14s 305ms/step - loss: 8.7760 - val_loss: 12.0006
# Epoch 191/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.5148 - val_loss: 12.0034
# Epoch 192/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.6244 - val_loss: 12.0147
# Epoch 193/1000
# 47/47 [==============================] - 1s 14ms/step - loss: 8.5074 - val_loss: 12.0178

# %%
import seaborn as sns
from matplotlib import pyplot as plt
for i in dk.keys():
  sns.distplot(dk[i])
  plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/IEEE-CIS-Fraud/blob/master/simple_model_focal_loss_0_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_USERNAME'] = "tapaskd123" # username from the json file
os.environ['KAGGLE_KEY'] = "aba8dc1f085221111d925003fe5a88ed" # key from the json file
# !kaggle competitions download -c ieee-fraud-detection
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading test_identity.csv.zip to /content
#   0% 0.00/3.21M [00:00<?, ?B/s]
# 100% 3.21M/3.21M [00:00<00:00, 53.2MB/s]
# Downloading test_transaction.csv.zip to /content
#  98% 51.0M/52.2M [00:00<00:00, 98.2MB/s]
# 100% 52.2M/52.2M [00:00<00:00, 132MB/s]
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/1.14M [00:00<?, ?B/s]
# 100% 1.14M/1.14M [00:00<00:00, 36.6MB/s]
# Downloading train_transaction.csv.zip to /content
#  81% 47.0M/58.3M [00:00<00:00, 29.1MB/s]
# 100% 58.3M/58.3M [00:00<00:00, 63.2MB/s]
# Downloading train_identity.csv.zip to /content
#   0% 0.00/3.26M [00:00<?, ?B/s]
# 100% 3.26M/3.26M [00:00<00:00, 107MB/s]

# %%
n_fold=5
lr=0.001

# %%
import pandas as pd
trn=pd.read_csv('/content/gdrive/My Drive/fraud/train.csv')
tst=pd.read_csv('/content/gdrive/My Drive/fraud/test.csv')
ls=list(trn.filter(regex='V'))
trn=trn.drop(ls,1)
tst=tst.drop(ls,1)

# %%
from tensorflow.keras.layers import *
import tensorflow as tf
import random, os, sys
import numpy as np
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
import tensorflow as tf

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np


class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
from sklearn.preprocessing import LabelEncoder
cols=list(trn.select_dtypes(include=object))
for col in cols:
  le=LabelEncoderExt()
  le.fit(trn[col].astype(str))
  trn[col]=le.transform(trn[col].astype(str))
  tst[col] = tst[col].map(lambda s: '<unknown>' if s not in le.classes_ else s)
  tst[col]=le.transform(tst[col].astype(str))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   import sys

# %%
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from keras.layers import *
from keras.optimizers import *
from keras.models import *
from keras import backend as K
ss=StandardScaler()
frd=trn['isFraud']
ls=list(trn)
trn=ss.fit_transform(trn.drop(['isFraud'],1))
trn=pd.DataFrame(trn)

# %%
ls.remove('isFraud')
trn.columns=ls
trn['isFraud']=frd

ls=list(tst)
tst=ss.fit_transform(tst)
tst=pd.DataFrame(tst)
tst.columns=ls

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df
trn=reduce_mem_usage(trn)
tst=reduce_mem_usage(tst)
# Out:
# Memory usage of dataframe is 860.54 MB
# Memory usage after optimization is: 215.14 MB
# Decreased by 75.0%
# Memory usage of dataframe is 734.49 MB
# Memory usage after optimization is: 183.62 MB
# Decreased by 75.0%

# %%
trn_n=pd.read_csv('train_transaction.csv.zip')
tst_n=pd.read_csv('test_transaction.csv.zip')
trn['month']=trn_n['TransactionDT']//(86400*30)
trn_n.head()
trn_ls=list(trn_n)
tst_ls=list(tst_n)
for col in trn:
  if col in trn_ls:
    trn[col+'_isna']=trn_n[col].isna().astype('uint8')
for col in tst:
  if col in tst_ls:
    tst[col+'_isna']=tst_n[col].isna().astype('uint8')
import gc
del([trn_n,tst_n])
gc.collect()
# Out:
# 0

# %%
trn=trn.drop(['isFraud_isna'],1)

# %%
from sklearn.metrics import roc_auc_score
from keras.callbacks import Callback
class RocCallback(Callback):
    def __init__(self,validation_data):
        self.x_val = validation_data[0]
        self.y_val = validation_data[1]
        self.ep=0

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        self.ep+=1
        if self.ep%10==0:
          y_pred_val = self.model.predict(self.x_val)
          roc_val = roc_auc_score(self.y_val, y_pred_val)
          print('roc-auc_val: %s' % str(round(roc_val,4)))

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %%
def fl():
    def focal_loss(y_true, y_pred):
        gamma=0.4
        alpha=1-0.036
        pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))

        pt_1 = K.clip(pt_1, 1e-3, .999)
        pt_0 = K.clip(pt_0, 1e-3, .999)

        return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0))
    return focal_loss
dk={}
def load_model():
  K.clear_session()
  inp=Input((233,))
  x=Dense(256,activation='relu')(inp)
  x=Dropout(0.3)(x)
  x=BatchNormalization()(x)
  x=Dense(256,activation='relu')(x)
  x=Dropout(0.3)(x)
  x=BatchNormalization()(x)
  x=Dense(256,activation='relu')(x)
  x=Dropout(0.3)(x)
  x=BatchNormalization()(x)
  x=Dense(1,activation='sigmoid')(x)
  mod=Model(inputs=inp,outputs=x)
  return mod
for en,month in enumerate([(4,5),(3,4),(3,5)]):
  train=trn.loc[trn['month']>=month[1]]
  test=trn.loc[trn['month']<=month[0]]
  train=train.drop(['month'],1)
  test=test.drop(['month'],1)
  mod=load_model()
  mod.compile(optimizer=Adam(0.0001,decay=1e-3),loss=fl())
  roc = RocCallback(
                  validation_data=(test.drop(['isFraud'],1), test['isFraud']))
  es=EarlyStopping(monitor='val_loss',min_delta=0.0001,mode='min',restore_best_weights=True,patience=50)
  mod.fit(train.drop(['isFraud'],1),train['isFraud'],validation_data=(test.drop(['isFraud'],1),test['isFraud']),batch_size=2048,epochs=1000,callbacks=[es,roc])
  del([train,test])
  gc.collect()
  df=trn.loc[trn['month']==6].reset_index(drop=True).drop(['month'],1)
  pre=mod.predict(df.drop(['isFraud'],1))
  scr=roc_auc_score(df['isFraud'],pre)
  dk[str(scr)]=mod.predict(tst)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 2s 35ms/step - loss: 88.9237 - val_loss: 66.9037
# Epoch 2/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 79.1434 - val_loss: 64.8323
# Epoch 3/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 76.5690 - val_loss: 63.9405
# Epoch 4/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 71.5741 - val_loss: 63.6035
# Epoch 5/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 70.2240 - val_loss: 63.8517
# Epoch 6/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 69.2049 - val_loss: 63.7943
# Epoch 7/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 67.7986 - val_loss: 63.2919
# Epoch 8/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 65.6348 - val_loss: 63.6543
# Epoch 9/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 65.7460 - val_loss: 63.2495
# Epoch 10/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 64.5507roc-auc_val: 0.7758
# 47/47 [==============================] - 18s 377ms/step - loss: 64.5457 - val_loss: 63.3725
# Epoch 11/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 63.6144 - val_loss: 63.1166
# Epoch 12/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 63.2500 - val_loss: 63.0108
# Epoch 13/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 61.8016 - val_loss: 62.9835
# Epoch 14/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 61.7182 - val_loss: 62.5303
# Epoch 15/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 61.4907 - val_loss: 62.3283
# Epoch 16/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 61.5985 - val_loss: 62.2154
# Epoch 17/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 60.0581 - val_loss: 62.3502
# Epoch 18/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 58.8455 - val_loss: 61.7318
# Epoch 19/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 58.2422 - val_loss: 61.8492
# Epoch 20/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 59.4568roc-auc_val: 0.7881
# 47/47 [==============================] - 18s 374ms/step - loss: 59.1140 - val_loss: 61.7778
# Epoch 21/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 57.9111 - val_loss: 61.6407
# Epoch 22/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 58.1032 - val_loss: 61.6467
# Epoch 23/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 55.9002 - val_loss: 61.7160
# Epoch 24/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 56.4730 - val_loss: 61.7331
# Epoch 25/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 56.3713 - val_loss: 61.9126
# Epoch 26/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 55.7725 - val_loss: 61.8902
# Epoch 27/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 56.5116 - val_loss: 62.1111
# Epoch 28/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 57.1619 - val_loss: 61.8167
# Epoch 29/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 55.1263 - val_loss: 61.7099
# Epoch 30/1000
# 46/47 [============================>.] - ETA: 0s - loss: 55.9158roc-auc_val: 0.7926
# 47/47 [==============================] - 18s 386ms/step - loss: 55.7166 - val_loss: 61.5485
# Epoch 31/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 54.5025 - val_loss: 61.4545
# Epoch 32/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 53.8831 - val_loss: 61.5391
# Epoch 33/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 54.1632 - val_loss: 61.6716
# Epoch 34/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 54.0579 - val_loss: 61.6513
# Epoch 35/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 54.4030 - val_loss: 61.5829
# Epoch 36/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 53.1621 - val_loss: 61.5720
# Epoch 37/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 53.7565 - val_loss: 61.4894
# Epoch 38/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 53.7640 - val_loss: 61.4152
# Epoch 39/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 53.9199 - val_loss: 61.4801
# Epoch 40/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 53.5251roc-auc_val: 0.7961
# 47/47 [==============================] - 18s 373ms/step - loss: 53.3206 - val_loss: 61.5402
# Epoch 41/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 52.7224 - val_loss: 61.5045
# Epoch 42/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 51.4860 - val_loss: 61.5103
# Epoch 43/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 53.0623 - val_loss: 61.5277
# Epoch 44/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 52.2524 - val_loss: 61.4747
# Epoch 45/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 51.8886 - val_loss: 61.4781
# Epoch 46/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 51.6309 - val_loss: 61.5661
# Epoch 47/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 51.1596 - val_loss: 61.5532
# Epoch 48/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 51.3049 - val_loss: 61.5529
# Epoch 49/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 51.5438 - val_loss: 61.5522
# Epoch 50/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 51.6945roc-auc_val: 0.799
# 47/47 [==============================] - 18s 374ms/step - loss: 51.4219 - val_loss: 61.5580
# Epoch 51/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 50.7182 - val_loss: 61.5502
# Epoch 52/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 51.5112 - val_loss: 61.5644
# Epoch 53/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 50.7595 - val_loss: 61.5286
# Epoch 54/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 49.9699 - val_loss: 61.6568
# Epoch 55/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 50.9257 - val_loss: 61.6068
# Epoch 56/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 50.6200 - val_loss: 61.5558
# Epoch 57/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 50.6942 - val_loss: 61.5788
# Epoch 58/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 50.5605 - val_loss: 61.6211
# Epoch 59/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 49.8164 - val_loss: 61.6406
# Epoch 60/1000
# 47/47 [==============================] - ETA: 0s - loss: 49.9567roc-auc_val: 0.8006
# 47/47 [==============================] - 18s 375ms/step - loss: 49.9567 - val_loss: 61.6247
# Epoch 61/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 49.7674 - val_loss: 61.5812
# Epoch 62/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 49.5493 - val_loss: 61.5558
# Epoch 63/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 49.6162 - val_loss: 61.6210
# Epoch 64/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 50.0413 - val_loss: 61.6728
# Epoch 65/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.6588 - val_loss: 61.7399
# Epoch 66/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.4332 - val_loss: 61.7455
# Epoch 67/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 49.5212 - val_loss: 61.7851
# Epoch 68/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 49.1589 - val_loss: 61.6632
# Epoch 69/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.5291 - val_loss: 61.7237
# Epoch 70/1000
# 39/47 [=======================>......] - ETA: 0s - loss: 48.6244roc-auc_val: 0.802
# 47/47 [==============================] - 18s 374ms/step - loss: 48.2289 - val_loss: 61.7023
# Epoch 71/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.7060 - val_loss: 61.6407
# Epoch 72/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 49.6471 - val_loss: 61.6606
# Epoch 73/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.6960 - val_loss: 61.6893
# Epoch 74/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 47.9866 - val_loss: 61.6448
# Epoch 75/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.3038 - val_loss: 61.7191
# Epoch 76/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.3552 - val_loss: 61.6849
# Epoch 77/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 47.6779 - val_loss: 61.7591
# Epoch 78/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.2203 - val_loss: 61.7991
# Epoch 79/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 47.7701 - val_loss: 61.8097
# Epoch 80/1000
# 46/47 [============================>.] - ETA: 0s - loss: 47.7253roc-auc_val: 0.8035
# 47/47 [==============================] - 18s 374ms/step - loss: 47.5579 - val_loss: 61.7762
# Epoch 81/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.1125 - val_loss: 61.8167
# Epoch 82/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 47.8250 - val_loss: 61.7976
# Epoch 83/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.1458 - val_loss: 61.7888
# Epoch 84/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 47.8836 - val_loss: 61.7701
# Epoch 85/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 48.0144 - val_loss: 61.8146
# Epoch 86/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 47.6566 - val_loss: 61.7745
# Epoch 87/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 47.5491 - val_loss: 61.7658
# Epoch 88/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 46.5021 - val_loss: 61.8743
# Epoch 1/1000
# 88/88 [==============================] - 2s 21ms/step - loss: 84.5108 - val_loss: 65.9050
# Epoch 2/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 76.0254 - val_loss: 63.5880
# Epoch 3/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 71.4244 - val_loss: 62.4411
# Epoch 4/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 68.3172 - val_loss: 61.9654
# Epoch 5/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 66.3577 - val_loss: 61.4053
# Epoch 6/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 65.6918 - val_loss: 61.2408
# Epoch 7/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 64.2070 - val_loss: 60.9880
# Epoch 8/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 63.0733 - val_loss: 60.5879
# Epoch 9/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 61.8842 - val_loss: 60.4697
# Epoch 10/1000
# 82/88 [==========================>...] - ETA: 0s - loss: 62.0049roc-auc_val: 0.7925
# 88/88 [==============================] - 15s 171ms/step - loss: 61.9242 - val_loss: 60.2521
# Epoch 11/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 61.2389 - val_loss: 60.0604
# Epoch 12/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 60.3230 - val_loss: 59.9107
# Epoch 13/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 59.4849 - val_loss: 59.7502
# Epoch 14/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 58.6713 - val_loss: 59.5710
# Epoch 15/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 58.4350 - val_loss: 59.4005
# Epoch 16/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 57.9723 - val_loss: 59.3405
# Epoch 17/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 57.3053 - val_loss: 59.2325
# Epoch 18/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 57.3456 - val_loss: 59.1963
# Epoch 19/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 56.6446 - val_loss: 59.1233
# Epoch 20/1000
# 82/88 [==========================>...] - ETA: 0s - loss: 56.3558roc-auc_val: 0.8026
# 88/88 [==============================] - 15s 172ms/step - loss: 56.4233 - val_loss: 59.1078
# Epoch 21/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 56.4551 - val_loss: 59.0207
# Epoch 22/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 55.4169 - val_loss: 58.9492
# Epoch 23/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 56.4007 - val_loss: 59.0228
# Epoch 24/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 54.6397 - val_loss: 58.9417
# Epoch 25/1000
# 88/88 [==============================] - 1s 13ms/step - loss: 55.0724 - val_loss: 58.9055
# Epoch 26/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 54.5740 - val_loss: 58.8000
# Epoch 27/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 54.7592 - val_loss: 58.7829
# Epoch 28/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 54.2981 - val_loss: 58.7340
# Epoch 29/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 54.0944 - val_loss: 58.6859
# Epoch 30/1000
# 88/88 [==============================] - ETA: 0s - loss: 54.4786roc-auc_val: 0.8067
# 88/88 [==============================] - 15s 172ms/step - loss: 54.4786 - val_loss: 58.6722
# Epoch 31/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 54.2982 - val_loss: 58.5923
# Epoch 32/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 53.5783 - val_loss: 58.5434
# Epoch 33/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 53.5418 - val_loss: 58.5620
# Epoch 34/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 53.3553 - val_loss: 58.5363
# Epoch 35/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 53.1532 - val_loss: 58.4810
# Epoch 36/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 53.2185 - val_loss: 58.4769
# Epoch 37/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 53.0694 - val_loss: 58.4091
# Epoch 38/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 52.9110 - val_loss: 58.4242
# Epoch 39/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 52.5877 - val_loss: 58.4014
# Epoch 40/1000
# 83/88 [===========================>..] - ETA: 0s - loss: 52.2143roc-auc_val: 0.8098
# 88/88 [==============================] - 15s 174ms/step - loss: 52.1071 - val_loss: 58.2865
# Epoch 41/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 52.3564 - val_loss: 58.2868
# Epoch 42/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 52.0998 - val_loss: 58.2424
# Epoch 43/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 51.7189 - val_loss: 58.2238
# Epoch 44/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 51.9393 - val_loss: 58.1802
# Epoch 45/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 51.7731 - val_loss: 58.2044
# Epoch 46/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 51.5805 - val_loss: 58.2003
# Epoch 47/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 51.6504 - val_loss: 58.1641
# Epoch 48/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 51.2762 - val_loss: 58.1250
# Epoch 49/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 51.3325 - val_loss: 58.0709
# Epoch 50/1000
# 84/88 [===========================>..] - ETA: 0s - loss: 51.1321roc-auc_val: 0.812
# 88/88 [==============================] - 15s 172ms/step - loss: 51.0424 - val_loss: 58.0285
# Epoch 51/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 50.8904 - val_loss: 58.0056
# Epoch 52/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 51.0596 - val_loss: 57.9917
# Epoch 53/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 50.6448 - val_loss: 57.9919
# Epoch 54/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 50.4350 - val_loss: 57.9755
# Epoch 55/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 50.5669 - val_loss: 57.9630
# Epoch 56/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 51.0395 - val_loss: 57.9248
# Epoch 57/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 50.6477 - val_loss: 57.9422
# Epoch 58/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 50.4721 - val_loss: 57.9310
# Epoch 59/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 50.2373 - val_loss: 57.9166
# Epoch 60/1000
# 80/88 [==========================>...] - ETA: 0s - loss: 50.3566roc-auc_val: 0.8132
# 88/88 [==============================] - 15s 166ms/step - loss: 50.3361 - val_loss: 57.9180
# Epoch 61/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 49.9916 - val_loss: 57.9031
# Epoch 62/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 49.5240 - val_loss: 57.8686
# Epoch 63/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 50.1826 - val_loss: 57.8479
# Epoch 64/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 49.7761 - val_loss: 57.8728
# Epoch 65/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 49.4553 - val_loss: 57.8530
# Epoch 66/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 49.6022 - val_loss: 57.8185
# Epoch 67/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 49.7280 - val_loss: 57.8028
# Epoch 68/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 49.4735 - val_loss: 57.7681
# Epoch 69/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 49.0037 - val_loss: 57.7572
# Epoch 70/1000
# 82/88 [==========================>...] - ETA: 0s - loss: 49.3731roc-auc_val: 0.8149
# 88/88 [==============================] - 15s 168ms/step - loss: 49.2064 - val_loss: 57.7386
# Epoch 71/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 49.4348 - val_loss: 57.7753
# Epoch 72/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 49.2821 - val_loss: 57.7734
# Epoch 73/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 49.4440 - val_loss: 57.7874
# Epoch 74/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 48.9625 - val_loss: 57.7449
# Epoch 75/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 49.2374 - val_loss: 57.7515
# Epoch 76/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 49.0859 - val_loss: 57.7490
# Epoch 77/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 48.9630 - val_loss: 57.6955
# Epoch 78/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 48.8051 - val_loss: 57.6830
# Epoch 79/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 48.8291 - val_loss: 57.6895
# Epoch 80/1000
# 87/88 [============================>.] - ETA: 0s - loss: 48.9292roc-auc_val: 0.8152
# 88/88 [==============================] - 15s 172ms/step - loss: 48.8385 - val_loss: 57.7344
# Epoch 81/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 48.6546 - val_loss: 57.7343
# Epoch 82/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 48.2542 - val_loss: 57.6834
# Epoch 83/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 48.5247 - val_loss: 57.6472
# Epoch 84/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 48.4922 - val_loss: 57.6549
# Epoch 85/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 48.5568 - val_loss: 57.6793
# Epoch 86/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 48.5398 - val_loss: 57.6725
# Epoch 87/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.9193 - val_loss: 57.6631
# Epoch 88/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 48.2300 - val_loss: 57.6532
# Epoch 89/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 48.3890 - val_loss: 57.6298
# Epoch 90/1000
# 88/88 [==============================] - ETA: 0s - loss: 48.3681roc-auc_val: 0.8162
# 88/88 [==============================] - 15s 172ms/step - loss: 48.3681 - val_loss: 57.6244
# Epoch 91/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 48.4145 - val_loss: 57.6145
# Epoch 92/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.9784 - val_loss: 57.6170
# Epoch 93/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 47.9878 - val_loss: 57.5938
# Epoch 94/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.9542 - val_loss: 57.5866
# Epoch 95/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.5680 - val_loss: 57.5725
# Epoch 96/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 47.8523 - val_loss: 57.5736
# Epoch 97/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.8474 - val_loss: 57.5726
# Epoch 98/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.3801 - val_loss: 57.5809
# Epoch 99/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 47.9369 - val_loss: 57.5752
# Epoch 100/1000
# 83/88 [===========================>..] - ETA: 0s - loss: 46.8840roc-auc_val: 0.8169
# 88/88 [==============================] - 15s 172ms/step - loss: 46.8678 - val_loss: 57.5638
# Epoch 101/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.7379 - val_loss: 57.5472
# Epoch 102/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.6062 - val_loss: 57.5712
# Epoch 103/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.6148 - val_loss: 57.5607
# Epoch 104/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.3056 - val_loss: 57.5727
# Epoch 105/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.1546 - val_loss: 57.5947
# Epoch 106/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.5414 - val_loss: 57.6030
# Epoch 107/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.6478 - val_loss: 57.5769
# Epoch 108/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.3490 - val_loss: 57.5823
# Epoch 109/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.2375 - val_loss: 57.5813
# Epoch 110/1000
# 82/88 [==========================>...] - ETA: 0s - loss: 46.7648roc-auc_val: 0.8173
# 88/88 [==============================] - 15s 172ms/step - loss: 46.7058 - val_loss: 57.5588
# Epoch 111/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 47.2405 - val_loss: 57.5371
# Epoch 112/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 47.1480 - val_loss: 57.5560
# Epoch 113/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.1836 - val_loss: 57.5668
# Epoch 114/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.0230 - val_loss: 57.5741
# Epoch 115/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.0323 - val_loss: 57.5829
# Epoch 116/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.9897 - val_loss: 57.5804
# Epoch 117/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.0300 - val_loss: 57.5800
# Epoch 118/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.7181 - val_loss: 57.5813
# Epoch 119/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.8926 - val_loss: 57.5562
# Epoch 120/1000
# 88/88 [==============================] - ETA: 0s - loss: 46.7183roc-auc_val: 0.8177
# 88/88 [==============================] - 15s 171ms/step - loss: 46.7183 - val_loss: 57.5462
# Epoch 121/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 46.9744 - val_loss: 57.5539
# Epoch 122/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.5780 - val_loss: 57.5546
# Epoch 123/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.8086 - val_loss: 57.6105
# Epoch 124/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 46.3553 - val_loss: 57.5949
# Epoch 125/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.6802 - val_loss: 57.6067
# Epoch 126/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 46.4472 - val_loss: 57.5641
# Epoch 127/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.6240 - val_loss: 57.5427
# Epoch 128/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 47.0856 - val_loss: 57.5742
# Epoch 129/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.2452 - val_loss: 57.5646
# Epoch 130/1000
# 83/88 [===========================>..] - ETA: 0s - loss: 46.3790roc-auc_val: 0.8176
# 88/88 [==============================] - 15s 174ms/step - loss: 46.3742 - val_loss: 57.6072
# Epoch 131/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.3730 - val_loss: 57.6111
# Epoch 132/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.5735 - val_loss: 57.6060
# Epoch 133/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.5173 - val_loss: 57.5662
# Epoch 134/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.0907 - val_loss: 57.5801
# Epoch 135/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.4776 - val_loss: 57.6090
# Epoch 136/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.3045 - val_loss: 57.6275
# Epoch 137/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.0413 - val_loss: 57.6155
# Epoch 138/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.1903 - val_loss: 57.6227
# Epoch 139/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.2957 - val_loss: 57.6423
# Epoch 140/1000
# 87/88 [============================>.] - ETA: 0s - loss: 46.1719roc-auc_val: 0.8177
# 88/88 [==============================] - 15s 172ms/step - loss: 46.0656 - val_loss: 57.6255
# Epoch 141/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.3137 - val_loss: 57.6134
# Epoch 142/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 46.0514 - val_loss: 57.6161
# Epoch 143/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.0123 - val_loss: 57.6186
# Epoch 144/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.7119 - val_loss: 57.6326
# Epoch 145/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 45.7303 - val_loss: 57.6372
# Epoch 146/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 45.6862 - val_loss: 57.6721
# Epoch 147/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.7931 - val_loss: 57.6744
# Epoch 148/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.9002 - val_loss: 57.6660
# Epoch 149/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 45.9480 - val_loss: 57.6648
# Epoch 150/1000
# 88/88 [==============================] - ETA: 0s - loss: 46.0096roc-auc_val: 0.818
# 88/88 [==============================] - 16s 176ms/step - loss: 46.0096 - val_loss: 57.6601
# Epoch 151/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.6774 - val_loss: 57.6644
# Epoch 152/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.5900 - val_loss: 57.6793
# Epoch 153/1000
# 88/88 [==============================] - 1s 12ms/step - loss: 45.9769 - val_loss: 57.6653
# Epoch 154/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.5980 - val_loss: 57.6227
# Epoch 155/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 46.0336 - val_loss: 57.6313
# Epoch 156/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.4950 - val_loss: 57.6212
# Epoch 157/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.3418 - val_loss: 57.6165
# Epoch 158/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.6402 - val_loss: 57.5897
# Epoch 159/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.0824 - val_loss: 57.5844
# Epoch 160/1000
# 81/88 [==========================>...] - ETA: 0s - loss: 45.6409roc-auc_val: 0.8186
# 88/88 [==============================] - 15s 171ms/step - loss: 45.5907 - val_loss: 57.5976
# Epoch 161/1000
# 88/88 [==============================] - 1s 11ms/step - loss: 45.0055 - val_loss: 57.6150
# Epoch 1/1000
# 47/47 [==============================] - 2s 34ms/step - loss: 85.9809 - val_loss: 69.1044
# Epoch 2/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 76.9953 - val_loss: 67.4752
# Epoch 3/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 72.3699 - val_loss: 66.5914
# Epoch 4/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 69.8698 - val_loss: 65.8007
# Epoch 5/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 68.3584 - val_loss: 65.7106
# Epoch 6/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 66.1821 - val_loss: 65.5021
# Epoch 7/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 65.0573 - val_loss: 65.0227
# Epoch 8/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 64.0076 - val_loss: 64.9435
# Epoch 9/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 62.9125 - val_loss: 64.7214
# Epoch 10/1000
# 44/47 [===========================>..] - ETA: 0s - loss: 62.6849roc-auc_val: 0.7691
# 47/47 [==============================] - 15s 316ms/step - loss: 62.4140 - val_loss: 64.5716
# Epoch 11/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 60.8212 - val_loss: 64.2570
# Epoch 12/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 60.4817 - val_loss: 63.7009
# Epoch 13/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 59.6618 - val_loss: 63.2957
# Epoch 14/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 58.9532 - val_loss: 63.1175
# Epoch 15/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 58.8213 - val_loss: 62.9716
# Epoch 16/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 58.8317 - val_loss: 62.8810
# Epoch 17/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 57.8099 - val_loss: 62.6723
# Epoch 18/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 57.1466 - val_loss: 62.5939
# Epoch 19/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 56.3592 - val_loss: 62.6219
# Epoch 20/1000
# 47/47 [==============================] - ETA: 0s - loss: 56.5493roc-auc_val: 0.7826
# 47/47 [==============================] - 15s 313ms/step - loss: 56.5493 - val_loss: 62.4465
# Epoch 21/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 56.1814 - val_loss: 62.3274
# Epoch 22/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 56.7160 - val_loss: 62.1475
# Epoch 23/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 56.1089 - val_loss: 62.1146
# Epoch 24/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 54.6434 - val_loss: 62.1097
# Epoch 25/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 54.8479 - val_loss: 61.9619
# Epoch 26/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 54.5502 - val_loss: 61.7989
# Epoch 27/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 54.7049 - val_loss: 61.8433
# Epoch 28/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 53.9548 - val_loss: 61.6194
# Epoch 29/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 53.5928 - val_loss: 61.6681
# Epoch 30/1000
# 40/47 [========================>.....] - ETA: 0s - loss: 53.6214roc-auc_val: 0.7887
# 47/47 [==============================] - 15s 325ms/step - loss: 53.5816 - val_loss: 61.6939
# Epoch 31/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 53.4600 - val_loss: 61.7293
# Epoch 32/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 52.7195 - val_loss: 61.6431
# Epoch 33/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 52.1308 - val_loss: 61.6295
# Epoch 34/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 52.6520 - val_loss: 61.5101
# Epoch 35/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 52.3397 - val_loss: 61.5014
# Epoch 36/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 52.2494 - val_loss: 61.4926
# Epoch 37/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 51.7407 - val_loss: 61.3041
# Epoch 38/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 52.6996 - val_loss: 61.3868
# Epoch 39/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 51.2620 - val_loss: 61.4142
# Epoch 40/1000
# 46/47 [============================>.] - ETA: 0s - loss: 51.3187roc-auc_val: 0.7908
# 47/47 [==============================] - 15s 318ms/step - loss: 51.1202 - val_loss: 61.4298
# Epoch 41/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 51.7576 - val_loss: 61.3256
# Epoch 42/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 51.9374 - val_loss: 61.4273
# Epoch 43/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 49.9707 - val_loss: 61.2627
# Epoch 44/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 50.7197 - val_loss: 61.3567
# Epoch 45/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 50.3495 - val_loss: 61.3461
# Epoch 46/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 50.7244 - val_loss: 61.2898
# Epoch 47/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 49.4462 - val_loss: 61.2014
# Epoch 48/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 50.1986 - val_loss: 61.2563
# Epoch 49/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 50.0334 - val_loss: 61.2027
# Epoch 50/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 49.5086roc-auc_val: 0.7927
# 47/47 [==============================] - 15s 317ms/step - loss: 49.4215 - val_loss: 61.1896
# Epoch 51/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 49.5574 - val_loss: 61.1967
# Epoch 52/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 49.7999 - val_loss: 61.1917
# Epoch 53/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 49.4410 - val_loss: 61.1692
# Epoch 54/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 48.9938 - val_loss: 61.1149
# Epoch 55/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 49.1416 - val_loss: 61.1537
# Epoch 56/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 49.2485 - val_loss: 61.0927
# Epoch 57/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 49.4725 - val_loss: 61.1185
# Epoch 58/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 49.1775 - val_loss: 61.0964
# Epoch 59/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 48.3829 - val_loss: 61.0681
# Epoch 60/1000
# 46/47 [============================>.] - ETA: 0s - loss: 48.8457roc-auc_val: 0.794
# 47/47 [==============================] - 15s 315ms/step - loss: 48.6693 - val_loss: 61.1030
# Epoch 61/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 48.7081 - val_loss: 61.0736
# Epoch 62/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 48.7001 - val_loss: 61.1034
# Epoch 63/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 48.4217 - val_loss: 61.0971
# Epoch 64/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 48.1129 - val_loss: 61.1586
# Epoch 65/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 47.8960 - val_loss: 61.1554
# Epoch 66/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 47.8669 - val_loss: 61.1777
# Epoch 67/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 48.1495 - val_loss: 61.1662
# Epoch 68/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 47.6717 - val_loss: 61.0954
# Epoch 69/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 47.6625 - val_loss: 61.2109
# Epoch 70/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 47.8564roc-auc_val: 0.795
# 47/47 [==============================] - 15s 317ms/step - loss: 47.7663 - val_loss: 61.1375
# Epoch 71/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 47.6375 - val_loss: 61.0740
# Epoch 72/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 48.1370 - val_loss: 61.0570
# Epoch 73/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.5284 - val_loss: 61.0555
# Epoch 74/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 47.1356 - val_loss: 61.0593
# Epoch 75/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 47.3479 - val_loss: 61.0080
# Epoch 76/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 47.3958 - val_loss: 61.0519
# Epoch 77/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.8654 - val_loss: 61.0901
# Epoch 78/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 47.5949 - val_loss: 61.1101
# Epoch 79/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.2689 - val_loss: 61.1606
# Epoch 80/1000
# 46/47 [============================>.] - ETA: 0s - loss: 46.7873roc-auc_val: 0.7954
# 47/47 [==============================] - 15s 313ms/step - loss: 46.6245 - val_loss: 61.1881
# Epoch 81/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 46.7194 - val_loss: 61.1848
# Epoch 82/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.5051 - val_loss: 61.1881
# Epoch 83/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.0640 - val_loss: 61.1917
# Epoch 84/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.4777 - val_loss: 61.1688
# Epoch 85/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.0831 - val_loss: 61.1681
# Epoch 86/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.3682 - val_loss: 61.2037
# Epoch 87/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.6841 - val_loss: 61.1539
# Epoch 88/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 45.8966 - val_loss: 61.2147
# Epoch 89/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.1804 - val_loss: 61.2164
# Epoch 90/1000
# 45/47 [===========================>..] - ETA: 0s - loss: 45.9478roc-auc_val: 0.796
# 47/47 [==============================] - 15s 315ms/step - loss: 45.8149 - val_loss: 61.1956
# Epoch 91/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 45.5014 - val_loss: 61.2341
# Epoch 92/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 44.9859 - val_loss: 61.2089
# Epoch 93/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 45.6434 - val_loss: 61.1725
# Epoch 94/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 45.3355 - val_loss: 61.1319
# Epoch 95/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 46.2615 - val_loss: 61.2071
# Epoch 96/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 45.6689 - val_loss: 61.2397
# Epoch 97/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 45.4059 - val_loss: 61.2943
# Epoch 98/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 45.4292 - val_loss: 61.3573
# Epoch 99/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 45.0948 - val_loss: 61.3019
# Epoch 100/1000
# 44/47 [===========================>..] - ETA: 0s - loss: 45.3325roc-auc_val: 0.7964
# 47/47 [==============================] - 15s 316ms/step - loss: 45.0527 - val_loss: 61.2406
# Epoch 101/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 45.0686 - val_loss: 61.2138
# Epoch 102/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.4025 - val_loss: 61.2474
# Epoch 103/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.5273 - val_loss: 61.2953
# Epoch 104/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 45.2787 - val_loss: 61.3055
# Epoch 105/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.4229 - val_loss: 61.3333
# Epoch 106/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.7943 - val_loss: 61.3544
# Epoch 107/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.4502 - val_loss: 61.3816
# Epoch 108/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.2251 - val_loss: 61.4075
# Epoch 109/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.7553 - val_loss: 61.4478
# Epoch 110/1000
# 46/47 [============================>.] - ETA: 0s - loss: 44.3954roc-auc_val: 0.7961
# 47/47 [==============================] - 15s 316ms/step - loss: 44.2298 - val_loss: 61.4823
# Epoch 111/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.8002 - val_loss: 61.4973
# Epoch 112/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.6943 - val_loss: 61.5212
# Epoch 113/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.7981 - val_loss: 61.5596
# Epoch 114/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.3702 - val_loss: 61.4808
# Epoch 115/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.2078 - val_loss: 61.4879
# Epoch 116/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 43.8225 - val_loss: 61.4838
# Epoch 117/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 44.0795 - val_loss: 61.5029
# Epoch 118/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 43.7666 - val_loss: 61.5267
# Epoch 119/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.2231 - val_loss: 61.5339
# Epoch 120/1000
# 47/47 [==============================] - ETA: 0s - loss: 43.5925roc-auc_val: 0.7965
# 47/47 [==============================] - 15s 326ms/step - loss: 43.5925 - val_loss: 61.5575
# Epoch 121/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 43.9539 - val_loss: 61.5424
# Epoch 122/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 43.7664 - val_loss: 61.5340
# Epoch 123/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 43.5996 - val_loss: 61.5802
# Epoch 124/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 43.9621 - val_loss: 61.5787
# Epoch 125/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 44.4811 - val_loss: 61.6809

# %%
import seaborn as sns
from matplotlib import pyplot as plt
for i in dk.keys():
  sns.distplot(dk[i])
  plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
